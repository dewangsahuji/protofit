# %% [markdown]
# Good choice! MediaPipe is lightweight and efficient for real-time pose tracking.
#
# ### **Next Steps:**
# 1. **Set Up MediaPipe & OpenCV**
#    - Install necessary libraries:
#      ```bash
#      pip install mediapipe opencv-python numpy
#      ```
#    - Capture live webcam feed
#
# 2. **Detect Key Landmarks for Each Exercise**
#    - **Bicep Curls:** Track elbow and shoulder angles
#    - **Squats:** Monitor knee and hip angles
#    - **Push-ups:** Analyze elbow and shoulder alignment
#
# 3. **Implement Rep Counting Logic**
#    - Identify full range of motion
#    - Count valid reps based on angle thresholds
#
# 4. **Provide Real-time Feedback**
#    - Display **"Good Form"** or **"Adjust Position"** messages
#
# Would you like a base script to get started with MediaPipe Pose detection? 🚀

# %%
import cv2
import mediapipe as mp
import numpy as np

# Function to calculate the angle between three points (for joint angle calculations)
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Midpoint (joint)
    c = np.array(c)  # End point
    
    # Calculate the angle using arctan2 function
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    # Adjust angle to stay within 0-180 degrees
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# Initialize MediaPipe Pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Open the webcam
cap = cv2.VideoCapture(0)

# Select exercise to track
exercise = "bicep curl"  # Change this to "squat" or "pushup" as needed
count = 0  # Counter for repetitions
position = None  # To track movement direction

while cap.isOpened():
    ret, frame = cap.read()
    frame = cv2.flip(frame, 1)  # Flip image horizontally for better visualization
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert to RGB for MediaPipe
    results = pose.process(image)  # Process image with pose detection
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)  # Convert back to BGR for OpenCV display
    
    if results.pose_landmarks:
        landmarks = results.pose_landmarks.landmark  # Get pose landmarks
        
        # Detect and analyze key points for different exercises
        if exercise == "bicep curl":
            # Get coordinates of key joints
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, 
                     landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, 
                     landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            # Calculate elbow angle
            angle = calculate_angle(shoulder, elbow, wrist)
            
            # Rep counting logic
            if angle > 140:
                position = "down"
            if angle < 40 and position == "down":
                position = "up"
                count += 1  # Increment rep count
            
            # Provide feedback based on form
            feedback = "Good Form" if 30 <= angle <= 150 else "Fix Arm Position"
        
        elif exercise == "squat":
            # Get coordinates of key joints
            hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                   landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, 
                    landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
            ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, 
                     landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            
            # Calculate knee angle
            angle = calculate_angle(hip, knee, ankle)
            
            # Rep counting logic
            if angle > 160:
                position = "up"
            if angle < 90 and position == "up":
                position = "down"
                count += 1  # Increment rep count
            
            # Provide feedback based on form
            feedback = "Good Form" if 80 <= angle <= 170 else "Fix Knee Position"
        
        elif exercise == "pushup":
            # Get coordinates of key joints
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, 
                     landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, 
                     landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            # Calculate elbow angle
            angle = calculate_angle(shoulder, elbow, wrist)
            
            # Rep counting logic
            if angle > 160:
                position = "up"
            if angle < 90 and position == "up":
                position = "down"
                count += 1  # Increment rep count
            
            # Provide feedback based on form
            feedback = "Good Form" if 80 <= angle <= 170 else "Fix Elbow Position"
        
        # Draw pose landmarks on the image
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        
        # Display repetition count and feedback on the screen
        cv2.putText(image, f"Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
        cv2.putText(image, feedback, (30, 90), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
    
    # Show the image with pose tracking
    cv2.imshow("Fitoproto - AI Rep Counter", image)
    
    # Exit when 'q' key is pressed
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

# Release the webcam and close all windows
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Live Exercise Feedback and angle detection

# %%
import cv2
import mediapipe as mp
import numpy as np

# Function to calculate the angle between three points (for joint angle calculations)
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Midpoint (joint)
    c = np.array(c)  # End point
    
    # Calculate the angle using arctan2 function
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    # Adjust angle to stay within 0-180 degrees
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# Initialize MediaPipe Pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Open the webcam
cap = cv2.VideoCapture(0)

def draw_concentration_bar(image, count):
    bar_height = int(400 * (count % 10) / 10)  # Simple visualization based on reps
    cv2.rectangle(image, (50, 450 - bar_height), (100, 450), (0, 255, 0), -1)
    cv2.rectangle(image, (50, 50), (100, 450), (255, 255, 255), 2)

def select_exercise():
    print("Select an exercise:")
    print("1. Bicep Curl")
    print("2. Squat")
    print("3. Pushup")
    choice = input("Enter 1, 2, or 3: ")
    if choice == "1":
        bicep_curl()
    elif choice == "2":
        squat()
    elif choice == "3":
        pushup()
    else:
        print("Invalid choice. Please restart and enter a valid number.")

def bicep_curl():
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            angle = calculate_angle(shoulder, elbow, wrist)
            
            if angle > 140:
                position = "down"
            if angle < 40 and position == "down":
                position = "up"
                count += 1
            
            feedback = "Good form!" if 30 < angle < 140 else "Adjust your arm position."
            
            cv2.putText(image, f"Bicep Curl Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        draw_concentration_bar(image, count)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        cv2.imshow("Bicep Curl", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

def squat():
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark
            hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
            ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
            
            angle = calculate_angle(hip, knee, ankle)
            
            if angle > 160:
                position = "up"
            if angle < 90 and position == "up":
                position = "down"
                count += 1
            
            feedback = "Good depth!" if 80 < angle < 160 else "Go lower!"
            
            cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        draw_concentration_bar(image, count)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        cv2.imshow("Squat", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

def pushup():
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark
            shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            
            angle = calculate_angle(shoulder, elbow, wrist)
            
            if angle > 160:
                position = "up"
            if angle < 90 and position == "up":
                position = "down"
                count += 1
            
            feedback = "Good form!" if 80 < angle < 160 else "Keep your core tight!"
            
            cv2.putText(image, f"Pushup Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        draw_concentration_bar(image, count)
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        cv2.imshow("Pushup", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

select_exercise()
# Out:
# Select an exercise:
# 1. Bicep Curl
# 2. Squat
# 3. Pushup
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Input video output

# %%
import cv2
import mediapipe as mp
import numpy as np

# Function to calculate the angle between three points (for joint angle calculations)
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Midpoint (joint)
    c = np.array(c)  # End point
    
    # Calculate the angle using arctan2 function
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    # Adjust angle to stay within 0-180 degrees
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# Initialize MediaPipe Pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Function to draw a simple concentration bar
def draw_concentration_bar(image, count):
    bar_height = int(400 * (count % 10) / 10)  # Simple visualization based on reps
    cv2.rectangle(image, (50, 450 - bar_height), (100, 450), (0, 255, 0), -1)
    cv2.rectangle(image, (50, 50), (100, 450), (255, 255, 255), 2)

# Function to select input source (Webcam or Video file)
def select_input_source():
    print("Select input source:")
    print("1. Live Webcam")
    print("2. Video File")
    choice = input("Enter 1 or 2: ")
    if choice == "1":
        return cv2.VideoCapture(0)  # Open webcam
    elif choice == "2":
        video_path = input("Enter video file path: ")
        return cv2.VideoCapture(video_path)  # Open video file
    else:
        print("Invalid choice. Defaulting to webcam.")
        return cv2.VideoCapture(0)

# Function to select exercise type
def select_exercise(cap):
    print("Select an exercise:")
    print("1. Bicep Curl")
    print("2. Squat")
    print("3. Pushup")
    choice = input("Enter 1, 2, or 3: ")
    if choice == "1":
        bicep_curl(cap)
    elif choice == "2":
        squat(cap)
    elif choice == "3":
        pushup(cap)
    else:
        print("Invalid choice. Please restart and enter a valid number.")

# Function to process video frames and track reps
def process_video(cap, exercise_type):
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.flip(frame, 1)  # Mirror the frame
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        if results.pose_landmarks:
            landmarks = results.pose_landmarks.landmark
            
            # Define joints for different exercises
            if exercise_type == "bicep_curl":
                joint1, joint2, joint3 = [mp_pose.PoseLandmark.LEFT_SHOULDER, mp_pose.PoseLandmark.LEFT_ELBOW, mp_pose.PoseLandmark.LEFT_WRIST]
            elif exercise_type == "squat":
                joint1, joint2, joint3 = [mp_pose.PoseLandmark.LEFT_HIP, mp_pose.PoseLandmark.LEFT_KNEE, mp_pose.PoseLandmark.LEFT_ANKLE]
            elif exercise_type == "pushup":
                joint1, joint2, joint3 = [mp_pose.PoseLandmark.LEFT_SHOULDER, mp_pose.PoseLandmark.LEFT_ELBOW, mp_pose.PoseLandmark.LEFT_WRIST]
            
            # Get joint positions
            p1 = [landmarks[joint1.value].x, landmarks[joint1.value].y]
            p2 = [landmarks[joint2.value].x, landmarks[joint2.value].y]
            p3 = [landmarks[joint3.value].x, landmarks[joint3.value].y]
            
            # Calculate joint angle
            angle = calculate_angle(p1, p2, p3)
            
            # Rep counting logic based on exercise type
            if exercise_type == "bicep_curl":
                if angle > 140:
                    position = "down"
                if angle < 40 and position == "down":
                    position = "up"
                    count += 1
                feedback = "Good form!" if 30 < angle < 140 else "Adjust your arm position."
            
            elif exercise_type == "squat":
                if angle > 160:
                    position = "up"
                if angle < 90 and position == "up":
                    position = "down"
                    count += 1
                feedback = "Good depth!" if 80 < angle < 160 else "Go lower!"
            
            elif exercise_type == "pushup":
                if angle > 160:
                    position = "up"
                if angle < 90 and position == "up":
                    position = "down"
                    count += 1
                feedback = "Good form!" if 80 < angle < 160 else "Keep your core tight!"
            
            # Display rep count and feedback
            cv2.putText(image, f"Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
            cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        
        # Draw concentration bar
        draw_concentration_bar(image, count)
        
        # Draw landmarks on image
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
        
        # Show the processed frame
        cv2.imshow(exercise_type.capitalize(), image)
        
        # Press 'q' to quit
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# Functions to call process_video with specific exercises
def bicep_curl(cap):
    process_video(cap, "bicep_curl")

def squat(cap):
    process_video(cap, "squat")

def pushup(cap):
    process_video(cap, "pushup")

# Start program
cap = select_input_source()
select_exercise(cap)
# Out:
# Select input source:
# 1. Live Webcam
# 2. Video File
# Invalid choice. Defaulting to webcam.
# Select an exercise:
# 1. Bicep Curl
# 2. Squat
# 3. Pushup
# Invalid choice. Please restart and enter a valid number.

# %% [markdown]
# ## Live Updated

# %%
import cv2
import mediapipe as mp
import numpy as np
import csv
import datetime
import time


# Function to log exercise reps in CSV
def log_reps(exercise_name, count):
    filename = "exercise_log.csv"
    
    # Check if the file exists, if not, add headers
    try:
        with open(filename, 'x', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["Date", "Time", "Exercise", "Reps"])
    except FileExistsError:
        pass  # File already exists, no need to write headers
    
    # Append new data
    with open(filename, 'a', newline='') as f:
        writer = csv.writer(f)
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d,%H:%M:%S")
        writer.writerow([timestamp, exercise_name, count])
    
    print(f"✅ Saved {count} reps of {exercise_name} to exercise_log.csv")

# to close the program much better 
def cleanup():
    cap.release()
    cv2.destroyAllWindows()
    exit()  # Immediate program termination


# Function to calculate the angle between three points (for joint angle calculations)
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Midpoint (joint)
    c = np.array(c)  # End point
    
    # Calculate the angle using arctan2 function
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    # Adjust angle to stay within 0-180 degrees
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# initialize MediaPipe Pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# open the webcam
cap = cv2.VideoCapture(0)

# def draw_concentration_bar(image, count):
#     bar_height = int(368 * (count % 12) / 10)  # Simple visualization based on reps
#     cv2.rectangle(image, (50, 450 - bar_height), (100, 450), (0, 255, 0), -1)
#     cv2.rectangle(image, (50, 50), (100, 450), (255, 255, 255), 2)

def select_exercise():
    print("Select an exercise:")
    print("1. Bicep Curl")
    print("2. Squat")
    print("3. Pushup")
    choice = input("Enter 1, 2, or 3: ")
    if choice == "1":
        bicep_curl()
    elif choice == "2":
        squat()
    elif choice == "3":
        pushup()
    else:
        print("Invalid choice. Please restart and enter a valid number.")

# to fix the issue in to much quick response
#  Updated Code with Delayed Feedback Switch
# Initialize smoothing variables

smoothed_fill_ratio = 0  # Store the smoothed value
alpha = 0.1  # Smoothing factor (Higher = Faster updates, Lower = Smoother)

def draw_concentration_bar(image, angle):
    """
    Draws a smoothed concentration bar based on squat depth.
    Uses Exponential Moving Average (EMA) for smooth transitions.
    """

    global smoothed_fill_ratio

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  # X position
    bar_y = 100  # Y position (top)
    bar_height = 200  # Max height
    bar_width = 30  # Width

    # Normalize angle to fill ratio (160° → 0%, 80° → 100%)
    target_fill_ratio = max(0, min(1, (160 - angle) / 80))  

    # Apply smoothing (Exponential Moving Average)
    # Adjust smoothing factor to make bar update faster
    alpha = 0.25  # Increased from 0.1 to 0.25 for a quicker response
    smoothed_fill_ratio = alpha * target_fill_ratio + (1 - alpha) * smoothed_fill_ratio

    # Compute filled height
    fill_height = int(smoothed_fill_ratio * bar_height)  

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not deep enough)
    elif 90 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent)
    else:
        color = (0, 255, 0)  # Green (Perfect squat)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion (smoothed)
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw labels
    cv2.putText(image, "Depth", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

# Global variable for bar smoothing
smoothed_fill_ratio = 0  

def draw_concentration_bar_biceps(image, angle):
    """Draws a smoothed concentration bar based on curl depth using EMA."""
    global smoothed_fill_ratio

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  
    bar_y = 100  
    bar_height = 200  
    bar_width = 30  

    # Normalize angle to fill ratio (150° → 0%, 30° → 100%)
    target_fill_ratio = max(0, min(1, (150 - angle) / 120))  

    # Apply smoothing (Exponential Moving Average)
    alpha = 0.25  # Smoothing factor
    smoothed_fill_ratio = alpha * target_fill_ratio + (1 - alpha) * smoothed_fill_ratio

    # Compute filled height
    fill_height = int(smoothed_fill_ratio * bar_height)

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not curled enough)
    elif 70 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent curl)
    else:
        color = (0, 255, 0)  # Green (Perfect curl)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion (smoothed)
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw labels
    cv2.putText(image, "Curl", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

def bicep_curl():
    """Tracks bicep curls and counts reps."""
    count = 0
    position = "down"

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame = cv2.flip(frame, 1)
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = pose.process(image)
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                if results.pose_landmarks:
                    landmarks = results.pose_landmarks.landmark
                    
                    # Get keypoints for right arm
                    r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, 
                                landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                    r_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, 
                             landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                    r_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, 
                             landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
                    
                    # add key pint for left also 
                    l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                    l_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                    l_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
                    #right angle 
                    r_angle = calculate_angle(r_shoulder, r_elbow, r_wrist)
                    #left angle
                    l_angle = calculate_angle(l_shoulder, l_elbow, l_wrist)

                    # DEBUG: Print values
                    print(f"Angle: {r_angle:.2f}, Position: {position}")

                    # Check bicep curl position logic 
                    #for both left and right hand
                    if r_angle > 140 and l_angle > 140:
                        position = "down"

                    if r_angle < 50 and l_angle < 50 and position == "down":
                        position = "up"
                        count += 1
                        print(f"✅ Curl Counted! Total: {count}")  

                    # Provide feedback
                    if r_angle > 140 and l_angle > 140:
                        feedback = "Extend your arm!"
                    elif r_angle < 50 :
                        feedback = "Full curl!"
                    else:
                        feedback = "Good form!"

                    # Display feedback
                    cv2.putText(image, f"Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

                    # Draw the concentration bar
                    draw_concentration_bar_biceps(image,  (r_angle + l_angle) / 2)

            except Exception as e:
                print(f"Error: {e}")

            # Draw landmarks
            if results.pose_landmarks:
                mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            cv2.imshow("Bicep Curl", image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                log_reps("Bicep curl",count)
                cleanup()
                break

    # cap.release()
    # cv2.destroyAllWindows()


def draw_concentration_bar_squat(image, angle):
    """
    Draws a concentration bar on the screen based on the squat depth (angle).
    - More filled when squatting lower.
    - Color changes based on depth.
    """

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  # X position of the bar
    bar_y = 100  # Y position (top)
    bar_height = 200  # Max height
    bar_width = 30  # Width

    # Normalize angle to fill the bar
    fill_ratio = max(0, min(1, (160 - angle) / 80))  # 160° (empty) → 80° (full)
    fill_height = int(fill_ratio * bar_height)  # Compute filled height

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not deep enough)
    elif 90 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent)
    else:
        color = (0, 255, 0)  # Green (Perfect squat)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw text labels
    cv2.putText(image, "Depth", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

def squat():
    count = 0
    position = "up"
    shoulder_initial_y = None
    last_feedback = "Start your exercise"
    last_feedback_time = time.time()
    feedback_delay = 1.5

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark

                hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                       landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
                ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, 
                         landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
                            landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

                angle = calculate_angle(hip, knee, ankle)

                if position == "up" and shoulder_initial_y is None:
                    shoulder_initial_y = shoulder[1]

                print(f"Angle: {angle:.2f}, Position: {position}")

                if angle > 160:
                    position = "up"
                    shoulder_initial_y = shoulder[1]

                if angle < 90 and position == "up" and shoulder[1] > shoulder_initial_y + 0.02:
                    position = "down"
                    count += 1
                    print(f"✅ Squat Counted! Total: {count}")

                new_feedback = last_feedback
                if angle > 160:
                    new_feedback = "Stand tall!"
                elif angle < 90:
                    new_feedback = "Squat low!"
                else:
                    new_feedback = "Good depth!"

                if time.time() - last_feedback_time > feedback_delay:
                    last_feedback = new_feedback
                    last_feedback_time = time.time()

                # Draw smoothed concentration bar
                draw_concentration_bar_squat(image, angle)

                cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, last_feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Squat", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            log_reps("Squats",count)
            cleanup()
            break

    # cap.release()
    # cv2.destroyAllWindows()


## solved by adding the shouder points 
## wrong counting


def pushup():
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

                angle = calculate_angle(shoulder, elbow, wrist)

                if angle > 160:
                    position = "up"
                if angle < 90 and position == "up":
                    position = "down"
                    count += 1
                
                feedback = "Good form!" if 80 < angle < 160 else "Keep your core tight!"
                
                cv2.putText(image, f"Pushup Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        draw_concentration_bar(image, count)
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Pushup", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            log_reps("Pushup", count)
            cleanup()


## solved by adding the shouder points 

# def squat():
#     count = 0
#     position = "up"
#     shoulder_initial_y = None  # Stores the reference height of the shoulder

#     while cap.isOpened():
#         ret, frame = cap.read()
#         if not ret:
#             break

#         frame = cv2.flip(frame, 1)
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         results = pose.process(image)
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

#         try:
#             if results.pose_landmarks:
#                 landmarks = results.pose_landmarks.landmark

#                 # Get keypoints
#                 hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
#                        landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#                 knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, 
#                         landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#                 ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, 
#                          landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
#                 shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
#                             landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

#                 angle = calculate_angle(hip, knee, ankle)

#                 # Initialize shoulder reference height when standing straight
#                 if position == "up" and shoulder_initial_y is None:
#                     shoulder_initial_y = shoulder[1]

#                 # DEBUG: Print values
#                 print(f"Angle: {angle:.2f}, Shoulder Y: {shoulder[1]:.2f}, Initial Y: {shoulder_initial_y}, Position: {position}")

#                 # Check squat position logic
#                 if angle > 160:  # Standing position
#                     position = "up"
#                     shoulder_initial_y = shoulder[1]  # Reset shoulder reference when standing

#                 if angle < 90 and position == "up" and shoulder[1] > shoulder_initial_y + 0.02:  
#                     # Ensure the shoulder moves down before counting the squat
#                     position = "down"
#                     count += 1
#                     print(f"✅ Squat Counted! Total: {count}")  # Debugging line

#                 # Provide feedback
#                 if angle > 160:
#                     feedback = "Stand tall!"
#                 elif angle < 90:
#                     feedback = "Squat low!"
#                 else:
#                     feedback = "Good depth!"

#                 # Display feedback
#                 cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
#                 cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

#         except Exception as e:
#             print(f"Error: {e}")

#         # Draw landmarks
#         if results.pose_landmarks:
#             mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

#         cv2.imshow("Squat", image)
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break

#     cap.release()
#     cv2.destroyAllWindows()

select_exercise()
# Out:
# Select an exercise:
# 1. Bicep Curl
# 2. Squat
# 3. Pushup
# Angle: 167.29, Position: down
# Angle: 165.54, Position: down
# Angle: 165.67, Position: down
# Angle: 164.13, Position: down
# Angle: 163.37, Position: down
# Angle: 163.96, Position: down
# Angle: 163.28, Position: down
# Angle: 163.24, Position: down
# Angle: 163.18, Position: down
# Angle: 161.93, Position: down
# Angle: 163.30, Position: down
# Angle: 164.58, Position: down
# Angle: 164.05, Position: down
# Angle: 164.73, Position: down
# Angle: 165.30, Position: down
# Angle: 165.26, Position: down
# Angle: 164.83, Position: down
# Angle: 165.74, Position: down
# Angle: 166.84, Position: down
# Angle: 168.19, Position: down
# Angle: 168.54, Position: down
# Angle: 168.80, Position: down
# Angle: 167.99, Position: down
# Angle: 167.00, Position: down
# Angle: 166.53, Position: down
# Angle: 166.83, Position: down
# Angle: 166.92, Position: down
# Angle: 166.21, Position: down
# Angle: 165.32, Position: down
# Angle: 165.40, Position: down
# Angle: 165.77, Position: down
# Angle: 166.53, Position: down
# Angle: 166.96, Position: down
# Angle: 167.74, Position: down
# Angle: 167.68, Position: down
# Angle: 168.17, Position: down
# Angle: 168.15, Position: down
# Angle: 168.30, Position: down
# Angle: 166.56, Position: down
# Angle: 165.65, Position: down
# Angle: 164.14, Position: down
# Angle: 162.40, Position: down
# Angle: 164.28, Position: down
# Angle: 165.03, Position: down
# Angle: 14.67, Position: down
# Angle: 34.55, Position: down
# ✅ Curl Counted! Total: 1
# Angle: 33.38, Position: up
# Angle: 33.65, Position: up
# Angle: 31.36, Position: up
# Angle: 34.13, Position: up
# Angle: 34.31, Position: up
# Angle: 30.77, Position: up
# Angle: 23.28, Position: up
# Angle: 1.24, Position: up
# Angle: 161.03, Position: up
# Angle: 158.21, Position: up
# Angle: 157.54, Position: up
# Angle: 159.32, Position: down
# Angle: 158.94, Position: down
# Angle: 159.00, Position: down
# Angle: 159.75, Position: down
# Angle: 164.98, Position: down
# Angle: 169.98, Position: down
# Angle: 157.78, Position: down
# Angle: 140.48, Position: down
# Angle: 178.33, Position: down
# Angle: 171.57, Position: down
# Angle: 168.15, Position: down
# Angle: 166.57, Position: down
# Angle: 165.92, Position: down
# Angle: 165.77, Position: down
# Angle: 165.93, Position: down
# Angle: 165.91, Position: down
# Angle: 167.32, Position: down
# Angle: 171.10, Position: down
# Angle: 171.07, Position: down
# Angle: 171.24, Position: down
# Angle: 170.11, Position: down
# Angle: 169.91, Position: down
# Angle: 169.79, Position: down
# Angle: 166.72, Position: down
# Angle: 165.08, Position: down
# Angle: 164.59, Position: down
# Angle: 163.64, Position: down
# Angle: 163.21, Position: down
# Angle: 160.75, Position: down
# Angle: 160.87, Position: down
# Angle: 160.76, Position: down
# Angle: 161.51, Position: down
# Angle: 163.24, Position: down
# Angle: 167.56, Position: down
# Angle: 168.86, Position: down
# Angle: 167.88, Position: down
# Angle: 167.82, Position: down
# Angle: 166.61, Position: down
# Angle: 166.77, Position: down
# Angle: 166.28, Position: down
# Angle: 165.15, Position: down
# Angle: 163.09, Position: down
# Angle: 162.61, Position: down
# Angle: 158.90, Position: down
# Angle: 152.92, Position: down
# Angle: 152.60, Position: down
# Angle: 143.18, Position: down
# Angle: 142.15, Position: down
# Angle: 136.77, Position: down
# Angle: 92.43, Position: down
# Angle: 102.61, Position: down
# Angle: 145.06, Position: down
# Angle: 149.07, Position: down
# Angle: 143.31, Position: down
# Angle: 141.12, Position: down
# Angle: 149.36, Position: down
# Angle: 166.57, Position: down
# Angle: 176.20, Position: down
# Angle: 178.76, Position: down
# Angle: 176.66, Position: down
# Angle: 175.86, Position: down
# Angle: 172.24, Position: down
# Angle: 173.51, Position: down
# Angle: 172.31, Position: down
# Angle: 170.34, Position: down
# Angle: 170.22, Position: down
# Angle: 170.13, Position: down
# Angle: 168.73, Position: down
# Angle: 171.20, Position: down
# Angle: 171.52, Position: down
# Angle: 168.80, Position: down
# Angle: 168.29, Position: down
# Angle: 169.57, Position: down
# Angle: 170.36, Position: down
# Angle: 171.62, Position: down
# Angle: 172.81, Position: down
# Angle: 172.19, Position: down
# Angle: 172.88, Position: down
# Angle: 172.72, Position: down
# Angle: 172.41, Position: down
# Angle: 172.16, Position: down
# Angle: 172.02, Position: down
# Angle: 171.88, Position: down
# Angle: 172.31, Position: down
# Angle: 172.00, Position: down
# Angle: 171.61, Position: down
# Angle: 171.81, Position: down
# Angle: 170.99, Position: down
# Angle: 164.58, Position: down
# Angle: 137.44, Position: down
# Angle: 29.21, Position: down
# ✅ Curl Counted! Total: 2
# Angle: 23.49, Position: up
# Angle: 23.44, Position: up
# Angle: 17.60, Position: up
# Angle: 4.80, Position: up
# Angle: 3.58, Position: up
# Angle: 1.48, Position: up
# Angle: 0.06, Position: up
# Angle: 0.01, Position: up
# Angle: 0.69, Position: up
# Angle: 0.47, Position: up
# Angle: 0.48, Position: up
# Angle: 0.45, Position: up
# Angle: 0.26, Position: up
# Angle: 0.39, Position: up
# Angle: 0.13, Position: up
# Angle: 0.29, Position: up
# Angle: 0.22, Position: up
# Angle: 0.45, Position: up
# Angle: 0.06, Position: up
# Angle: 12.03, Position: up
# Angle: 132.41, Position: up
# Angle: 119.70, Position: up
# Angle: 132.27, Position: up
# Angle: 163.80, Position: up
# Angle: 178.15, Position: down
# Angle: 179.98, Position: down
# Angle: 179.87, Position: down
# Angle: 179.59, Position: down
# Angle: 178.82, Position: down
# Angle: 179.09, Position: down
# Angle: 177.90, Position: down
# Angle: 177.73, Position: down
# Angle: 176.96, Position: down
# Angle: 176.19, Position: down
# Angle: 175.89, Position: down
# Angle: 175.53, Position: down
# Angle: 175.46, Position: down
# Angle: 175.49, Position: down
# Angle: 175.80, Position: down
# Angle: 172.82, Position: down
# Angle: 172.53, Position: down
# Angle: 154.18, Position: down
# Angle: 126.65, Position: down
# Angle: 121.10, Position: down
# Angle: 95.96, Position: down
# Angle: 32.98, Position: down
# ✅ Curl Counted! Total: 3
# Angle: 7.23, Position: up
# Angle: 2.19, Position: up
# Angle: 1.52, Position: up
# Angle: 1.24, Position: up
# Angle: 1.26, Position: up
# Angle: 1.63, Position: up
# Angle: 1.68, Position: up
# Angle: 1.86, Position: up
# Angle: 1.88, Position: up
# Angle: 1.97, Position: up
# Angle: 1.98, Position: up
# Angle: 2.09, Position: up
# Angle: 2.18, Position: up
# Angle: 2.15, Position: up
# Angle: 2.07, Position: up
# Angle: 2.03, Position: up
# Angle: 2.02, Position: up
# Angle: 1.95, Position: up
# Angle: 1.57, Position: up
# Angle: 34.51, Position: up
# Angle: 44.55, Position: up
# Angle: 47.69, Position: up
# Angle: 99.29, Position: up
# Angle: 135.59, Position: up
# Angle: 132.50, Position: up
# Angle: 162.72, Position: up
# Angle: 179.83, Position: down
# Angle: 178.99, Position: down
# Angle: 179.31, Position: down
# Angle: 179.66, Position: down
# Angle: 179.73, Position: down
# Angle: 178.60, Position: down
# Angle: 177.90, Position: down
# Angle: 177.55, Position: down
# Angle: 177.51, Position: down
# Angle: 177.07, Position: down
# Angle: 176.85, Position: down
# Angle: 176.71, Position: down
# Angle: 176.68, Position: down
# Angle: 164.43, Position: down
# Angle: 148.37, Position: down
# Angle: 158.23, Position: down
# Angle: 134.72, Position: down
# Angle: 46.90, Position: down
# ✅ Curl Counted! Total: 4
# Angle: 17.05, Position: up
# Angle: 8.12, Position: up
# Angle: 8.97, Position: up
# Angle: 9.62, Position: up
# Angle: 5.91, Position: up
# Angle: 3.27, Position: up
# Angle: 2.00, Position: up
# Angle: 1.86, Position: up
# Angle: 1.27, Position: up
# Angle: 1.11, Position: up
# Angle: 1.38, Position: up
# Angle: 0.86, Position: up
# Angle: 0.59, Position: up
# Angle: 1.52, Position: up
# Angle: 7.07, Position: up
# Angle: 123.69, Position: up
# Angle: 131.94, Position: up
# Angle: 174.77, Position: up
# Angle: 177.93, Position: up
# Angle: 177.70, Position: up
# Angle: 179.94, Position: up
# Angle: 178.74, Position: up
# Angle: 179.48, Position: up
# Angle: 179.02, Position: down
# Angle: 177.97, Position: down
# Angle: 177.01, Position: down
# Angle: 176.71, Position: down
# Angle: 179.15, Position: down
# Angle: 177.16, Position: down
# Angle: 176.09, Position: down
# Angle: 175.89, Position: down
# Angle: 175.90, Position: down
# Angle: 175.94, Position: down
# Angle: 175.81, Position: down
# Angle: 175.76, Position: down
# Angle: 175.79, Position: down
# Angle: 175.63, Position: down
# Angle: 175.60, Position: down
# Angle: 176.29, Position: down
# Angle: 177.37, Position: down
# Angle: 177.96, Position: down
# Angle: 177.70, Position: down
# Angle: 177.49, Position: down
# Angle: 177.15, Position: down
# Angle: 176.58, Position: down
# Angle: 176.40, Position: down
# Angle: 176.37, Position: down
# Angle: 176.02, Position: down
# Angle: 175.78, Position: down
# Angle: 175.43, Position: down
# Angle: 174.37, Position: down
# Angle: 173.87, Position: down
# Angle: 173.96, Position: down
# Angle: 173.28, Position: down
# Angle: 173.54, Position: down
# Angle: 173.50, Position: down
# Angle: 173.52, Position: down
# Angle: 174.05, Position: down
# Angle: 174.24, Position: down
# Angle: 175.16, Position: down
# Angle: 175.78, Position: down
# Angle: 175.78, Position: down
# Angle: 175.84, Position: down
# Angle: 175.83, Position: down
# Angle: 178.66, Position: down
# Angle: 177.93, Position: down
# Angle: 176.89, Position: down
# Angle: 175.33, Position: down
# Angle: 174.16, Position: down
# Angle: 173.56, Position: down
# Angle: 172.41, Position: down
# Angle: 171.49, Position: down
# Angle: 170.54, Position: down
# Angle: 169.06, Position: down
# Angle: 159.70, Position: down
# Angle: 159.15, Position: down
# Angle: 162.75, Position: down
# Angle: 167.26, Position: down
# Angle: 174.01, Position: down
# Angle: 162.76, Position: down
# Angle: 157.72, Position: down
# Angle: 146.51, Position: down
# Angle: 137.33, Position: down
# Angle: 157.84, Position: down
# Angle: 167.39, Position: down
# Angle: 0.12, Position: down
# Angle: 1.77, Position: down
# Angle: 149.05, Position: down
# Angle: 152.10, Position: down
# Angle: 142.20, Position: down
# Angle: 104.70, Position: down
# Angle: 160.34, Position: down
# Angle: 170.77, Position: down
# Angle: 175.00, Position: down
# Angle: 177.24, Position: down
# Angle: 152.87, Position: down
# Angle: 172.53, Position: down
# Angle: 178.83, Position: down
# Angle: 176.57, Position: down
# Angle: 175.74, Position: down
# Angle: 178.00, Position: down
# Angle: 179.23, Position: down
# Angle: 179.13, Position: down
# Angle: 176.98, Position: down
# Angle: 175.36, Position: down
# Angle: 174.71, Position: down
# Angle: 175.08, Position: down
# Angle: 175.41, Position: down
# Angle: 175.65, Position: down
# Angle: 179.01, Position: down
# Angle: 179.59, Position: down
# Angle: 179.14, Position: down
# Angle: 177.34, Position: down
# Angle: 177.63, Position: down
# Angle: 177.99, Position: down
# Angle: 178.61, Position: down
# Angle: 178.34, Position: down
# Angle: 178.43, Position: down
# Angle: 166.99, Position: down
# Angle: 160.61, Position: down
# Angle: 144.05, Position: down
# Angle: 137.31, Position: down
# Angle: 137.77, Position: down
# Angle: 0.46, Position: down
# ✅ Curl Counted! Total: 5
# Angle: 0.19, Position: up
# Angle: 0.24, Position: up
# Angle: 0.19, Position: up
# Angle: 0.29, Position: up
# Angle: 0.20, Position: up
# Angle: 0.35, Position: up
# Angle: 0.02, Position: up
# Angle: 0.25, Position: up
# Angle: 0.53, Position: up
# Angle: 0.86, Position: up
# Angle: 1.29, Position: up
# Angle: 1.42, Position: up
# Angle: 0.30, Position: up
# Angle: 61.69, Position: up
# Angle: 167.87, Position: up
# Angle: 174.22, Position: down
# Angle: 173.02, Position: down
# Angle: 172.48, Position: down
# Angle: 173.98, Position: down
# Angle: 175.18, Position: down
# Angle: 175.77, Position: down
# Angle: 178.36, Position: down
# Angle: 179.14, Position: down
# Angle: 178.17, Position: down
# Angle: 176.85, Position: down
# Angle: 176.20, Position: down
# Angle: 176.07, Position: down
# Angle: 176.09, Position: down
# Angle: 175.72, Position: down
# Angle: 175.54, Position: down
# Angle: 169.57, Position: down
# Angle: 158.34, Position: down
# Angle: 155.87, Position: down
# Angle: 117.61, Position: down
# Angle: 97.07, Position: down
# Angle: 22.35, Position: down
# ✅ Curl Counted! Total: 6
# Angle: 7.45, Position: up
# Angle: 6.18, Position: up
# Angle: 4.35, Position: up
# Angle: 4.25, Position: up
# Angle: 3.91, Position: up
# Angle: 3.91, Position: up
# Angle: 3.87, Position: up
# Angle: 3.87, Position: up
# Angle: 3.63, Position: up
# Angle: 3.37, Position: up
# Angle: 3.25, Position: up
# Angle: 3.06, Position: up
# Angle: 3.26, Position: up
# Angle: 5.21, Position: up
# Angle: 6.38, Position: up
# Angle: 5.02, Position: up
# Angle: 3.68, Position: up
# Angle: 136.52, Position: up
# Angle: 160.49, Position: up
# Angle: 179.67, Position: down
# Angle: 179.18, Position: down
# Angle: 179.84, Position: down
# Angle: 177.90, Position: down
# Angle: 177.10, Position: down
# Angle: 176.34, Position: down
# Angle: 175.84, Position: down
# Angle: 175.26, Position: down
# Angle: 175.00, Position: down
# Angle: 174.72, Position: down
# Angle: 174.35, Position: down
# Angle: 174.85, Position: down
# Angle: 173.47, Position: down
# Angle: 173.32, Position: down
# Angle: 159.59, Position: down
# Angle: 156.16, Position: down
# Angle: 161.66, Position: down
# Angle: 71.83, Position: down
# Angle: 4.47, Position: down
# ✅ Curl Counted! Total: 7
# Angle: 2.92, Position: up
# Angle: 1.93, Position: up
# Angle: 1.84, Position: up
# Angle: 2.22, Position: up
# Angle: 2.25, Position: up
# Angle: 2.33, Position: up
# Angle: 2.13, Position: up
# Angle: 2.00, Position: up
# Angle: 1.98, Position: up
# Angle: 2.00, Position: up
# Angle: 2.12, Position: up
# Angle: 1.88, Position: up
# Angle: 1.51, Position: up
# Angle: 1.23, Position: up
# Angle: 1.11, Position: up
# Angle: 5.59, Position: up
# Angle: 145.50, Position: up
# Angle: 150.93, Position: up
# Angle: 155.20, Position: up
# Angle: 179.10, Position: down
# Angle: 177.88, Position: down
# Angle: 179.43, Position: down
# Angle: 178.10, Position: down
# Angle: 177.31, Position: down
# Angle: 176.72, Position: down
# Angle: 175.98, Position: down
# Angle: 175.77, Position: down
# Angle: 175.04, Position: down
# Angle: 174.69, Position: down
# Angle: 174.73, Position: down
# Angle: 175.03, Position: down
# Angle: 174.71, Position: down
# Angle: 171.54, Position: down
# Angle: 163.36, Position: down
# Angle: 158.20, Position: down
# Angle: 160.87, Position: down
# Angle: 117.99, Position: down
# Angle: 19.55, Position: down
# ✅ Curl Counted! Total: 8
# Angle: 16.74, Position: up
# Angle: 11.31, Position: up
# Angle: 9.09, Position: up
# Angle: 8.74, Position: up
# Angle: 7.72, Position: up
# Angle: 7.51, Position: up
# Angle: 7.80, Position: up
# Angle: 7.73, Position: up
# Angle: 9.73, Position: up
# Angle: 10.94, Position: up
# Angle: 20.56, Position: up
# Angle: 35.69, Position: up
# Angle: 37.53, Position: up
# Angle: 48.02, Position: up
# Angle: 62.34, Position: up
# Angle: 61.39, Position: up
# Angle: 92.12, Position: up
# Angle: 124.73, Position: up
# Angle: 152.64, Position: up
# Angle: 170.54, Position: down
# Angle: 174.38, Position: down
# Angle: 175.48, Position: down
# Angle: 174.39, Position: down
# Angle: 177.70, Position: down
# Angle: 178.87, Position: down
# Angle: 178.35, Position: down
# Angle: 176.29, Position: down
# Angle: 176.46, Position: down
# Angle: 175.31, Position: down
# Angle: 173.88, Position: down
# Angle: 173.10, Position: down
# Angle: 172.17, Position: down
# Angle: 171.99, Position: down
# Angle: 171.43, Position: down
# Angle: 170.20, Position: down
# Angle: 170.48, Position: down
# Angle: 171.51, Position: down
# Angle: 173.11, Position: down
# Angle: 170.81, Position: down
# Angle: 170.58, Position: down
# Angle: 169.48, Position: down
# Angle: 169.71, Position: down
# Angle: 169.25, Position: down
# Angle: 169.35, Position: down
# Angle: 169.06, Position: down
# Angle: 169.13, Position: down
# Angle: 165.18, Position: down
# Angle: 164.22, Position: down
# Angle: 64.25, Position: down
# Angle: 21.64, Position: down
# Angle: 96.60, Position: down
# Angle: 119.50, Position: down
# Angle: 161.02, Position: down
# Angle: 166.34, Position: down
# Angle: 168.94, Position: down
# Angle: 172.55, Position: down
# Angle: 174.88, Position: down
# Angle: 174.14, Position: down
# Angle: 170.15, Position: down
# Angle: 169.61, Position: down
# Angle: 168.18, Position: down
# Angle: 165.33, Position: down
# Angle: 164.24, Position: down
# Angle: 166.31, Position: down
# Angle: 172.97, Position: down
# Angle: 171.30, Position: down
# Angle: 171.49, Position: down
# Angle: 178.58, Position: down
# Angle: 179.47, Position: down
# Angle: 177.64, Position: down
# Angle: 174.45, Position: down
# Angle: 171.98, Position: down
# Angle: 172.65, Position: down
# Angle: 171.81, Position: down
# Angle: 173.02, Position: down
# Angle: 172.15, Position: down
# Angle: 172.68, Position: down
# Angle: 172.59, Position: down
# ✅ Saved 8 reps of Bicep curl to exercise_log.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Finished

# %%
import cv2
import mediapipe as mp
import numpy as np
import csv
import datetime
import time


# Function to log exercise reps in CSV
def log_reps(exercise_name, count):
    filename = "exercise_log.csv"
    
    # Check if the file exists, if not, add headers
    try:
        with open(filename, 'x', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["Date", "Time", "Exercise", "Reps"])
    except FileExistsError:
        pass  # File already exists, no need to write headers
    
    # Append new data
    with open(filename, 'a', newline='') as f:
        writer = csv.writer(f)
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d,%H:%M:%S")
        writer.writerow([timestamp, exercise_name, count])
    
    print(f"✅ Saved {count} reps of {exercise_name} to exercise_log.csv")

# to close the program much better 
def cleanup():
    cap.release()
    cv2.destroyAllWindows()
    exit()  # Immediate program termination


# Function to calculate the angle between three points (for joint angle calculations)
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Midpoint (joint)
    c = np.array(c)  # End point
    
    # Calculate the angle using arctan2 function
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    # Adjust angle to stay within 0-180 degrees
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# initialize MediaPipe Pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# open the webcam
cap = cv2.VideoCapture(0)

# def draw_concentration_bar(image, count):
#     bar_height = int(368 * (count % 12) / 10)  # Simple visualization based on reps
#     cv2.rectangle(image, (50, 450 - bar_height), (100, 450), (0, 255, 0), -1)
#     cv2.rectangle(image, (50, 50), (100, 450), (255, 255, 255), 2)

def select_exercise():
    print("Select an exercise:")
    print("1. Bicep Curl")
    print("2. Squat")
    print("3. Pushup")
    choice = input("Enter 1, 2, or 3: ")
    if choice == "1":
        bicep_curl()
    elif choice == "2":
        squat()
    elif choice == "3":
        pushup()
    else:
        print("Invalid choice. Please restart and enter a valid number.")

# to fix the issue in to much quick response
#  Updated Code with Delayed Feedback Switch
# Initialize smoothing variables

smoothed_fill_ratio = 0  # Store the smoothed value
alpha = 0.1  # Smoothing factor (Higher = Faster updates, Lower = Smoother)

def draw_concentration_bar(image, angle):
    """
    Draws a smoothed concentration bar based on squat depth.
    Uses Exponential Moving Average (EMA) for smooth transitions.
    """

    global smoothed_fill_ratio

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  # X position
    bar_y = 100  # Y position (top)
    bar_height = 200  # Max height
    bar_width = 30  # Width

    # Normalize angle to fill ratio (160° → 0%, 80° → 100%)
    target_fill_ratio = max(0, min(1, (160 - angle) / 80))  

    # Apply smoothing (Exponential Moving Average)
    # Adjust smoothing factor to make bar update faster
    alpha = 0.25  # Increased from 0.1 to 0.25 for a quicker response
    smoothed_fill_ratio = alpha * target_fill_ratio + (1 - alpha) * smoothed_fill_ratio

    # Compute filled height
    fill_height = int(smoothed_fill_ratio * bar_height)  

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not deep enough)
    elif 90 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent)
    else:
        color = (0, 255, 0)  # Green (Perfect squat)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion (smoothed)
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw labels
    cv2.putText(image, "Depth", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

# Global variable for bar smoothing
smoothed_fill_ratio = 0  

def draw_concentration_bar_biceps(image, angle):
    """Draws a smoothed concentration bar based on curl depth using EMA."""
    global smoothed_fill_ratio

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  
    bar_y = 100  
    bar_height = 200  
    bar_width = 30  

    # Normalize angle to fill ratio (150° → 0%, 30° → 100%)
    target_fill_ratio = max(0, min(1, (150 - angle) / 120))  

    # Apply smoothing (Exponential Moving Average)
    alpha = 0.25  # Smoothing factor
    smoothed_fill_ratio = alpha * target_fill_ratio + (1 - alpha) * smoothed_fill_ratio

    # Compute filled height
    fill_height = int(smoothed_fill_ratio * bar_height)

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not curled enough)
    elif 70 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent curl)
    else:
        color = (0, 255, 0)  # Green (Perfect curl)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion (smoothed)
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw labels
    cv2.putText(image, "Curl", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

def bicep_curl():
    """Tracks bicep curls and counts reps."""
    count = 0
    position = "down"

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame = cv2.flip(frame, 1)
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = pose.process(image)
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                if results.pose_landmarks:
                    landmarks = results.pose_landmarks.landmark
                    
                    # Get keypoints for right arm
                    r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, 
                                landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                    r_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, 
                             landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                    r_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, 
                             landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
                    
                    # add key pint for left also 
                    l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                    l_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                    l_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
                    #right angle 
                    r_angle = calculate_angle(r_shoulder, r_elbow, r_wrist)
                    #left angle
                    l_angle = calculate_angle(l_shoulder, l_elbow, l_wrist)

                    # DEBUG: Print values
                    print(f"Angle: {r_angle:.2f}, Position: {position}")

                    # Check bicep curl position logic 
                    #for both left and right hand
                    if r_angle > 140 and l_angle > 140:
                        position = "down"

                    if r_angle < 50 and l_angle < 50 and position == "down":
                        position = "up"
                        count += 1
                        print(f"✅ Curl Counted! Total: {count}")  

                    # Provide feedback
                    if r_angle > 140 and l_angle > 140:
                        feedback = "Extend your arm!"
                    elif r_angle < 50 :
                        feedback = "Full curl!"
                    else:
                        feedback = "Good form!"

                    # Display feedback
                    cv2.putText(image, f"Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

                    # Draw the concentration bar
                    draw_concentration_bar_biceps(image,  (r_angle + l_angle) / 2)

            except Exception as e:
                print(f"Error: {e}")

            # Draw landmarks
            if results.pose_landmarks:
                mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            cv2.imshow("Bicep Curl", image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                log_reps("Bicep curl",count)
                cleanup()
                break

    # cap.release()
    # cv2.destroyAllWindows()


def draw_concentration_bar_squat(image, angle):
    """
    Draws a concentration bar on the screen based on the squat depth (angle).
    - More filled when squatting lower.
    - Color changes based on depth.
    """

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  # X position of the bar
    bar_y = 100  # Y position (top)
    bar_height = 200  # Max height
    bar_width = 30  # Width

    # Normalize angle to fill the bar
    fill_ratio = max(0, min(1, (160 - angle) / 80))  # 160° (empty) → 80° (full)
    fill_height = int(fill_ratio * bar_height)  # Compute filled height

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not deep enough)
    elif 90 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent)
    else:
        color = (0, 255, 0)  # Green (Perfect squat)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw text labels
    cv2.putText(image, "Depth", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

def squat():
    count = 0
    position = "up"
    shoulder_initial_y = None
    last_feedback = "Start your exercise"
    last_feedback_time = time.time()
    feedback_delay = 1.5

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark

                hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                       landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
                ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, 
                         landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
                            landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

                angle = calculate_angle(hip, knee, ankle)

                if position == "up" and shoulder_initial_y is None:
                    shoulder_initial_y = shoulder[1]

                print(f"Angle: {angle:.2f}, Position: {position}")

                if angle > 160:
                    position = "up"
                    shoulder_initial_y = shoulder[1]

                if angle < 90 and position == "up" and shoulder[1] > shoulder_initial_y + 0.02:
                    position = "down"
                    count += 1
                    print(f"✅ Squat Counted! Total: {count}")

                new_feedback = last_feedback
                if angle > 160:
                    new_feedback = "Stand tall!"
                elif angle < 90:
                    new_feedback = "Squat low!"
                else:
                    new_feedback = "Good depth!"

                if time.time() - last_feedback_time > feedback_delay:
                    last_feedback = new_feedback
                    last_feedback_time = time.time()

                # Draw smoothed concentration bar
                draw_concentration_bar_squat(image, angle)

                cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, last_feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Squat", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            log_reps("Squats",count)
            cleanup()
            break

    # cap.release()
    # cv2.destroyAllWindows()


## solved by adding the shouder points 
## wrong counting


def pushup():
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

                angle = calculate_angle(shoulder, elbow, wrist)

                if angle > 160:
                    position = "up"
                if angle < 90 and position == "up":
                    position = "down"
                    count += 1
                
                feedback = "Good form!" if 80 < angle < 160 else "Keep your core tight!"
                
                cv2.putText(image, f"Pushup Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        draw_concentration_bar(image, count)
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Pushup", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            log_reps("Pushup", count)
            cleanup()


select_exercise()
# Out:
# Select an exercise:
# 1. Bicep Curl
# 2. Squat
# 3. Pushup
# Angle: 177.36, Position: down
# Angle: 176.51, Position: down
# Angle: 178.22, Position: down
# Angle: 178.77, Position: down
# Angle: 178.30, Position: down
# Angle: 177.68, Position: down
# Angle: 178.79, Position: down
# Angle: 179.69, Position: down
# Angle: 178.62, Position: down
# Angle: 177.55, Position: down
# Angle: 176.70, Position: down
# Angle: 177.09, Position: down
# Angle: 175.09, Position: down
# Angle: 173.11, Position: down
# Angle: 173.34, Position: down
# Angle: 179.54, Position: down
# Angle: 178.88, Position: down
# Angle: 178.42, Position: down
# Angle: 178.52, Position: down
# Angle: 173.98, Position: down
# Angle: 176.87, Position: down
# Angle: 175.07, Position: down
# Angle: 177.89, Position: down
# Angle: 173.92, Position: down
# Angle: 170.45, Position: down
# Angle: 166.59, Position: down
# Angle: 163.45, Position: down
# Angle: 164.46, Position: down
# Angle: 172.89, Position: down
# Angle: 168.77, Position: down
# Angle: 169.40, Position: down
# Angle: 171.73, Position: down
# Angle: 170.96, Position: down
# Angle: 171.18, Position: down
# Angle: 170.14, Position: down
# Angle: 169.40, Position: down
# Angle: 167.88, Position: down
# Angle: 165.43, Position: down
# Angle: 163.32, Position: down
# Angle: 159.69, Position: down
# Angle: 148.65, Position: down
# Angle: 150.88, Position: down
# Angle: 157.74, Position: down
# Angle: 144.50, Position: down
# Angle: 177.84, Position: down
# Angle: 40.01, Position: down
# ✅ Curl Counted! Total: 1
# Angle: 113.10, Position: up
# Angle: 137.76, Position: up
# Angle: 161.72, Position: up
# Angle: 179.74, Position: down
# Angle: 178.85, Position: down
# Angle: 173.01, Position: down
# Angle: 167.96, Position: down
# Angle: 174.47, Position: down
# Angle: 159.56, Position: down
# Angle: 165.46, Position: down
# Angle: 174.86, Position: down
# Angle: 170.40, Position: down
# Angle: 165.09, Position: down
# Angle: 164.35, Position: down
# Angle: 166.18, Position: down
# Angle: 156.22, Position: down
# Angle: 161.40, Position: down
# Angle: 160.30, Position: down
# Angle: 161.61, Position: down
# Angle: 160.08, Position: down
# Angle: 159.54, Position: down
# Angle: 163.23, Position: down
# Angle: 165.12, Position: down
# Angle: 167.31, Position: down
# Angle: 168.30, Position: down
# Angle: 166.82, Position: down
# Angle: 167.65, Position: down
# Angle: 167.17, Position: down
# Angle: 168.32, Position: down
# Angle: 176.87, Position: down
# Angle: 178.89, Position: down
# Angle: 178.58, Position: down
# Angle: 178.94, Position: down
# Angle: 175.75, Position: down
# Angle: 175.85, Position: down
# Angle: 175.91, Position: down
# Angle: 179.85, Position: down
# Angle: 179.45, Position: down
# Angle: 177.53, Position: down
# Angle: 174.55, Position: down
# Angle: 178.17, Position: down
# Angle: 178.27, Position: down
# Angle: 177.74, Position: down
# Angle: 175.40, Position: down
# Angle: 175.30, Position: down
# Angle: 175.63, Position: down
# Angle: 177.75, Position: down
# Angle: 177.86, Position: down
# Angle: 177.74, Position: down
# Angle: 177.66, Position: down
# Angle: 175.52, Position: down
# Angle: 173.79, Position: down
# Angle: 174.74, Position: down
# Angle: 177.22, Position: down
# Angle: 178.41, Position: down
# Angle: 178.99, Position: down
# Angle: 178.64, Position: down
# Angle: 178.18, Position: down
# Angle: 178.81, Position: down
# Angle: 178.52, Position: down
# Angle: 177.95, Position: down
# Angle: 177.30, Position: down
# Angle: 177.29, Position: down
# Angle: 176.61, Position: down
# Angle: 176.13, Position: down
# Angle: 175.99, Position: down
# Angle: 176.38, Position: down
# Angle: 174.52, Position: down
# Angle: 174.02, Position: down
# Angle: 173.63, Position: down
# Angle: 166.17, Position: down
# Angle: 162.71, Position: down
# Angle: 165.25, Position: down
# Angle: 165.99, Position: down
# Angle: 167.17, Position: down
# Angle: 166.80, Position: down
# Angle: 167.31, Position: down
# Angle: 167.49, Position: down
# Angle: 156.25, Position: down
# Angle: 160.82, Position: down
# Angle: 162.38, Position: down
# Angle: 163.68, Position: down
# Angle: 164.91, Position: down
# Angle: 166.23, Position: down
# Angle: 167.22, Position: down
# Angle: 168.93, Position: down
# Angle: 168.93, Position: down
# Angle: 169.22, Position: down
# Angle: 168.69, Position: down
# Angle: 167.99, Position: down
# Angle: 166.94, Position: down
# Angle: 167.13, Position: down
# Angle: 167.45, Position: down
# Angle: 168.83, Position: down
# Angle: 163.55, Position: down
# Angle: 161.50, Position: down
# Angle: 161.72, Position: down
# Angle: 160.96, Position: down
# Angle: 161.90, Position: down
# Angle: 162.31, Position: down
# Angle: 162.37, Position: down
# Angle: 170.36, Position: down
# Angle: 178.46, Position: down
# Angle: 177.59, Position: down
# Angle: 175.68, Position: down
# Angle: 175.91, Position: down
# Angle: 170.25, Position: down
# Angle: 166.74, Position: down
# Angle: 168.66, Position: down
# Angle: 168.93, Position: down
# Angle: 169.49, Position: down
# Angle: 168.43, Position: down
# Angle: 150.75, Position: down
# Angle: 177.09, Position: down
# Angle: 175.62, Position: down
# Angle: 167.19, Position: down
# Angle: 167.78, Position: down
# Angle: 172.03, Position: down
# Angle: 43.80, Position: down
# Angle: 59.95, Position: down
# Angle: 171.53, Position: down
# Angle: 171.35, Position: down
# Angle: 174.39, Position: down
# Angle: 175.74, Position: down
# Angle: 179.27, Position: down
# Angle: 177.32, Position: down
# Angle: 175.47, Position: down
# Angle: 174.91, Position: down
# Angle: 174.46, Position: down
# Angle: 175.82, Position: down
# Angle: 176.51, Position: down
# Angle: 177.44, Position: down
# Angle: 174.71, Position: down
# Angle: 174.82, Position: down
# Angle: 174.67, Position: down
# Angle: 174.81, Position: down
# Angle: 169.51, Position: down
# Angle: 170.91, Position: down
# Angle: 172.02, Position: down
# Angle: 172.50, Position: down
# Angle: 168.75, Position: down
# Angle: 163.67, Position: down
# Angle: 162.36, Position: down
# Angle: 163.27, Position: down
# Angle: 160.11, Position: down
# Angle: 162.39, Position: down
# Angle: 164.54, Position: down
# Angle: 165.18, Position: down
# Angle: 170.18, Position: down
# Angle: 168.89, Position: down
# Angle: 168.34, Position: down
# Angle: 167.52, Position: down
# Angle: 167.42, Position: down
# Angle: 166.02, Position: down
# Angle: 165.93, Position: down
# Angle: 162.70, Position: down
# Angle: 162.11, Position: down
# Angle: 162.54, Position: down
# Angle: 161.29, Position: down
# Angle: 161.25, Position: down
# Angle: 162.54, Position: down
# Angle: 166.07, Position: down
# Angle: 95.49, Position: down
# Angle: 42.51, Position: down
# Angle: 163.26, Position: down
# Angle: 119.41, Position: down
# Angle: 123.39, Position: down
# Angle: 135.14, Position: down
# Angle: 118.96, Position: down
# Angle: 175.39, Position: down
# Angle: 179.21, Position: down
# Angle: 173.98, Position: down
# Angle: 172.25, Position: down
# Angle: 117.63, Position: down
# Angle: 128.02, Position: down
# Angle: 138.09, Position: down
# Angle: 136.36, Position: down
# Angle: 129.35, Position: down
# Angle: 122.17, Position: down
# Angle: 117.48, Position: down
# Angle: 116.87, Position: down
# Angle: 107.76, Position: down
# Angle: 167.79, Position: down
# Angle: 162.36, Position: down
# Angle: 163.79, Position: down
# Angle: 167.02, Position: down
# Angle: 176.02, Position: down
# Angle: 177.81, Position: down
# Angle: 178.13, Position: down
# Angle: 176.34, Position: down
# Angle: 179.61, Position: down
# Angle: 175.44, Position: down
# Angle: 173.27, Position: down
# Angle: 173.45, Position: down
# Angle: 176.91, Position: down
# Angle: 178.89, Position: down
# Angle: 175.46, Position: down
# Angle: 172.26, Position: down
# Angle: 174.63, Position: down
# Angle: 174.19, Position: down
# Angle: 177.57, Position: down
# Angle: 179.38, Position: down
# Angle: 176.80, Position: down
# Angle: 179.68, Position: down
# Angle: 175.94, Position: down
# Angle: 179.21, Position: down
# Angle: 172.41, Position: down
# Angle: 175.12, Position: down
# Angle: 172.57, Position: down
# Angle: 173.91, Position: down
# Angle: 178.19, Position: down
# Angle: 177.14, Position: down
# Angle: 174.89, Position: down
# Angle: 179.82, Position: down
# Angle: 178.77, Position: down
# Angle: 179.64, Position: down
# Angle: 179.52, Position: down
# Angle: 179.60, Position: down
# Angle: 179.91, Position: down
# Angle: 175.96, Position: down
# Angle: 176.50, Position: down
# Angle: 177.52, Position: down
# Angle: 177.64, Position: down
# Angle: 174.72, Position: down
# Angle: 174.44, Position: down
# Angle: 175.12, Position: down
# Angle: 175.28, Position: down
# Angle: 177.05, Position: down
# Angle: 177.62, Position: down
# Angle: 177.18, Position: down
# Angle: 178.58, Position: down
# Angle: 174.73, Position: down
# Angle: 173.74, Position: down
# Angle: 173.49, Position: down
# Angle: 174.79, Position: down
# Angle: 177.46, Position: down
# Angle: 178.52, Position: down
# Angle: 179.70, Position: down
# Angle: 179.75, Position: down
# Angle: 179.38, Position: down
# Angle: 179.71, Position: down
# Angle: 179.57, Position: down
# Angle: 178.90, Position: down
# Angle: 176.39, Position: down
# Angle: 175.33, Position: down
# Angle: 175.23, Position: down
# Angle: 175.17, Position: down
# Angle: 174.16, Position: down
# Angle: 174.33, Position: down
# Angle: 174.73, Position: down
# Angle: 174.50, Position: down
# Angle: 172.56, Position: down
# Angle: 173.47, Position: down
# Angle: 174.02, Position: down
# Angle: 173.10, Position: down
# Angle: 173.30, Position: down
# Angle: 174.52, Position: down
# Angle: 174.93, Position: down
# Angle: 171.82, Position: down
# Angle: 170.99, Position: down
# Angle: 170.39, Position: down
# Angle: 168.10, Position: down
# Angle: 167.25, Position: down
# Angle: 167.39, Position: down
# Angle: 167.66, Position: down
# Angle: 168.31, Position: down
# Angle: 169.48, Position: down
# Angle: 170.60, Position: down
# Angle: 172.41, Position: down
# Angle: 173.03, Position: down
# Angle: 173.79, Position: down
# Angle: 173.89, Position: down
# Angle: 174.33, Position: down
# Angle: 174.46, Position: down
# Angle: 174.09, Position: down
# Angle: 174.01, Position: down
# Angle: 173.93, Position: down
# Angle: 173.84, Position: down
# Angle: 173.69, Position: down
# Angle: 173.57, Position: down
# Angle: 173.30, Position: down
# Angle: 173.22, Position: down
# Angle: 172.73, Position: down
# Angle: 172.56, Position: down
# Angle: 172.60, Position: down
# Angle: 172.50, Position: down
# Angle: 172.40, Position: down
# Angle: 171.45, Position: down
# Angle: 170.31, Position: down
# Angle: 169.63, Position: down
# Angle: 169.74, Position: down
# Angle: 170.25, Position: down
# Angle: 170.36, Position: down
# Angle: 169.82, Position: down
# Angle: 170.10, Position: down
# Angle: 170.26, Position: down
# Angle: 170.67, Position: down
# Angle: 171.47, Position: down
# Angle: 171.42, Position: down
# Angle: 172.57, Position: down
# Angle: 172.53, Position: down
# Angle: 171.80, Position: down
# Angle: 171.29, Position: down
# Angle: 170.57, Position: down
# Angle: 170.00, Position: down
# Angle: 169.80, Position: down
# Angle: 174.46, Position: down
# Angle: 172.39, Position: down
# Angle: 172.06, Position: down
# Angle: 173.88, Position: down
# Angle: 174.77, Position: down
# Angle: 174.79, Position: down
# Angle: 172.95, Position: down
# Angle: 173.65, Position: down
# Angle: 174.05, Position: down
# Angle: 173.05, Position: down
# Angle: 172.02, Position: down
# Angle: 171.26, Position: down
# Angle: 170.92, Position: down
# Angle: 170.65, Position: down
# Angle: 170.66, Position: down
# Angle: 170.45, Position: down
# Angle: 174.12, Position: down
# Angle: 176.69, Position: down
# Angle: 177.00, Position: down
# Angle: 176.08, Position: down
# Angle: 175.63, Position: down
# Angle: 178.55, Position: down
# Angle: 178.75, Position: down
# Angle: 179.11, Position: down
# Angle: 179.96, Position: down
# Angle: 179.99, Position: down
# Angle: 179.06, Position: down
# Angle: 177.24, Position: down
# Angle: 178.31, Position: down
# Angle: 179.76, Position: down
# Angle: 179.44, Position: down
# Angle: 179.04, Position: down
# Angle: 178.89, Position: down
# Angle: 177.45, Position: down
# Angle: 176.64, Position: down
# Angle: 176.21, Position: down
# Angle: 175.90, Position: down
# Angle: 174.79, Position: down
# Angle: 174.72, Position: down
# Angle: 173.96, Position: down
# Angle: 173.57, Position: down
# Angle: 173.23, Position: down
# Angle: 172.63, Position: down
# Angle: 172.85, Position: down
# Angle: 172.77, Position: down
# Angle: 173.15, Position: down
# Angle: 172.97, Position: down
# Angle: 173.37, Position: down
# Angle: 172.56, Position: down
# Angle: 173.27, Position: down
# Angle: 173.08, Position: down
# Angle: 174.90, Position: down
# Angle: 173.98, Position: down
# Angle: 174.74, Position: down
# Angle: 175.25, Position: down
# Angle: 175.86, Position: down
# Angle: 175.94, Position: down
# Angle: 176.02, Position: down
# Angle: 176.50, Position: down
# Angle: 176.88, Position: down
# Angle: 177.12, Position: down
# Angle: 178.41, Position: down
# Angle: 179.90, Position: down
# Angle: 179.47, Position: down
# Angle: 179.38, Position: down
# Angle: 179.49, Position: down
# Angle: 179.51, Position: down
# Angle: 179.61, Position: down
# Angle: 179.63, Position: down
# Angle: 177.21, Position: down
# Angle: 176.89, Position: down
# Angle: 176.52, Position: down
# Angle: 176.90, Position: down
# Angle: 176.99, Position: down
# Angle: 176.77, Position: down
# Angle: 176.06, Position: down
# Angle: 173.38, Position: down
# Angle: 175.41, Position: down
# Angle: 176.97, Position: down
# Angle: 178.94, Position: down
# Angle: 177.83, Position: down
# Angle: 177.33, Position: down
# Angle: 172.07, Position: down
# Angle: 167.95, Position: down
# Angle: 170.51, Position: down
# Angle: 175.29, Position: down
# Angle: 177.55, Position: down
# Angle: 178.36, Position: down
# Angle: 180.00, Position: down
# Angle: 179.71, Position: down
# Angle: 179.39, Position: down
# Angle: 179.66, Position: down
# Angle: 178.60, Position: down
# Angle: 179.39, Position: down
# Angle: 173.75, Position: down
# Angle: 178.43, Position: down
# Angle: 178.27, Position: down
# Angle: 176.38, Position: down
# Angle: 174.51, Position: down
# Angle: 177.84, Position: down
# Angle: 179.59, Position: down
# Angle: 168.66, Position: down
# Angle: 170.49, Position: down
# Angle: 168.81, Position: down
# Angle: 169.73, Position: down
# Angle: 172.84, Position: down
# Angle: 173.24, Position: down
# Angle: 172.16, Position: down
# Angle: 172.36, Position: down
# Angle: 175.98, Position: down
# Angle: 178.51, Position: down
# Angle: 176.29, Position: down
# Angle: 175.37, Position: down
# Angle: 162.53, Position: down
# Angle: 163.46, Position: down
# Angle: 163.86, Position: down
# Angle: 164.71, Position: down
# Angle: 159.66, Position: down
# Angle: 160.43, Position: down
# Angle: 167.82, Position: down
# Angle: 168.80, Position: down
# Angle: 164.39, Position: down
# Angle: 164.19, Position: down
# Angle: 165.05, Position: down
# Angle: 168.83, Position: down
# Angle: 168.33, Position: down
# Angle: 168.43, Position: down
# Angle: 172.30, Position: down
# Angle: 177.94, Position: down
# Angle: 178.38, Position: down
# Angle: 178.87, Position: down
# Angle: 178.69, Position: down
# Angle: 178.29, Position: down
# Angle: 178.67, Position: down
# Angle: 178.79, Position: down
# Angle: 179.02, Position: down
# Angle: 179.13, Position: down
# Angle: 178.66, Position: down
# Angle: 179.51, Position: down
# Angle: 179.53, Position: down
# Angle: 179.45, Position: down
# Angle: 175.34, Position: down
# Angle: 176.81, Position: down
# Angle: 176.51, Position: down
# Angle: 178.94, Position: down
# Angle: 176.94, Position: down
# Angle: 176.01, Position: down
# Angle: 177.06, Position: down
# Angle: 177.16, Position: down
# Angle: 176.39, Position: down
# Angle: 176.42, Position: down
# Angle: 179.18, Position: down
# Angle: 175.72, Position: down
# Angle: 175.49, Position: down
# Angle: 175.26, Position: down
# Angle: 175.36, Position: down
# Angle: 177.33, Position: down
# Angle: 178.19, Position: down
# Angle: 178.66, Position: down
# Angle: 179.25, Position: down
# Angle: 179.95, Position: down
# Angle: 173.99, Position: down
# Angle: 168.34, Position: down
# Angle: 165.12, Position: down
# Angle: 163.80, Position: down
# Angle: 163.10, Position: down
# Angle: 153.25, Position: down
# Angle: 152.25, Position: down
# Angle: 161.92, Position: down
# Angle: 169.46, Position: down
# Angle: 167.31, Position: down
# Angle: 175.59, Position: down
# Angle: 174.26, Position: down
# Angle: 175.76, Position: down
# Angle: 176.67, Position: down
# Angle: 178.45, Position: down
# Angle: 175.89, Position: down
# Angle: 179.80, Position: down
# Angle: 178.02, Position: down
# Angle: 175.82, Position: down
# Angle: 176.12, Position: down
# Angle: 178.58, Position: down
# Angle: 179.58, Position: down
# Angle: 179.09, Position: down
# Angle: 177.62, Position: down
# Angle: 178.24, Position: down
# Angle: 176.38, Position: down
# Angle: 175.94, Position: down
# Angle: 172.56, Position: down
# Angle: 167.65, Position: down
# Angle: 164.17, Position: down
# Angle: 165.74, Position: down
# Angle: 160.49, Position: down
# Angle: 162.54, Position: down
# Angle: 162.40, Position: down
# Angle: 163.40, Position: down
# Angle: 163.19, Position: down
# Angle: 167.41, Position: down
# Angle: 168.28, Position: down
# Angle: 170.84, Position: down
# Angle: 172.23, Position: down
# Angle: 174.04, Position: down
# Angle: 160.39, Position: down
# Angle: 175.47, Position: down
# Angle: 176.02, Position: down
# Angle: 176.64, Position: down
# Angle: 178.62, Position: down
# Angle: 175.13, Position: down
# Angle: 173.43, Position: down
# Angle: 173.36, Position: down
# Angle: 173.00, Position: down
# Angle: 178.84, Position: down
# Angle: 169.18, Position: down
# Angle: 168.01, Position: down
# Angle: 167.76, Position: down
# Angle: 160.31, Position: down
# Angle: 156.38, Position: down
# Angle: 157.79, Position: down
# Angle: 158.06, Position: down
# Angle: 151.67, Position: down
# Angle: 158.09, Position: down
# Angle: 161.04, Position: down
# Angle: 160.59, Position: down
# Angle: 160.95, Position: down
# Angle: 161.03, Position: down
# Angle: 160.99, Position: down
# Angle: 161.35, Position: down
# Angle: 161.46, Position: down
# Angle: 162.00, Position: down
# Angle: 162.80, Position: down
# Angle: 162.85, Position: down
# Angle: 163.26, Position: down
# Angle: 163.21, Position: down
# Angle: 162.80, Position: down
# Angle: 162.65, Position: down
# Angle: 163.05, Position: down
# Angle: 163.21, Position: down
# Angle: 163.64, Position: down
# Angle: 163.10, Position: down
# Angle: 162.90, Position: down
# Angle: 161.85, Position: down
# Angle: 163.15, Position: down
# Angle: 161.16, Position: down
# Angle: 160.22, Position: down
# Angle: 160.50, Position: down
# Angle: 160.81, Position: down
# Angle: 162.07, Position: down
# Angle: 162.98, Position: down
# Angle: 169.91, Position: down
# Angle: 170.32, Position: down
# Angle: 176.11, Position: down
# Angle: 176.64, Position: down
# Angle: 169.74, Position: down
# Angle: 137.28, Position: down
# Angle: 145.70, Position: down
# Angle: 153.81, Position: down
# Angle: 169.69, Position: down
# Angle: 164.93, Position: down
# Angle: 168.52, Position: down
# Angle: 178.96, Position: down
# Angle: 175.91, Position: down
# Angle: 173.79, Position: down
# Angle: 175.19, Position: down
# Angle: 174.38, Position: down
# Angle: 172.87, Position: down
# Angle: 165.81, Position: down
# Angle: 161.31, Position: down
# Angle: 157.15, Position: down
# Angle: 157.09, Position: down
# Angle: 152.37, Position: down
# Angle: 156.82, Position: down
# Angle: 156.07, Position: down
# Angle: 33.52, Position: down
# Angle: 9.62, Position: down
# Angle: 3.67, Position: down
# Angle: 4.49, Position: down
# Angle: 6.26, Position: down
# Angle: 8.42, Position: down
# Angle: 4.25, Position: down
# Angle: 2.75, Position: down
# Angle: 0.52, Position: down
# Angle: 20.25, Position: down
# Angle: 140.02, Position: down
# Angle: 156.32, Position: down
# Angle: 143.28, Position: down
# Angle: 153.72, Position: down
# Angle: 158.80, Position: down
# Angle: 156.41, Position: down
# Angle: 161.04, Position: down
# Angle: 170.66, Position: down
# Angle: 169.79, Position: down
# Angle: 170.37, Position: down
# Angle: 169.94, Position: down
# Angle: 170.50, Position: down
# Angle: 169.88, Position: down
# Angle: 170.00, Position: down
# Angle: 177.80, Position: down
# Angle: 176.41, Position: down
# Angle: 176.24, Position: down
# Angle: 174.04, Position: down
# Angle: 165.67, Position: down
# Angle: 151.45, Position: down
# Angle: 153.34, Position: down
# Angle: 148.74, Position: down
# Angle: 152.47, Position: down
# Angle: 153.10, Position: down
# Angle: 130.23, Position: down
# Angle: 105.42, Position: down
# Angle: 18.39, Position: down
# Angle: 0.92, Position: down
# Angle: 6.21, Position: down
# Angle: 1.73, Position: down
# Angle: 0.35, Position: down
# Angle: 16.93, Position: down
# Angle: 3.45, Position: down
# Angle: 3.13, Position: down
# ✅ Curl Counted! Total: 2
# Angle: 0.84, Position: up
# Angle: 15.13, Position: up
# Angle: 20.15, Position: up
# Angle: 20.98, Position: up
# Angle: 8.24, Position: up
# Angle: 3.46, Position: up
# Angle: 15.22, Position: up
# Angle: 138.10, Position: up
# Angle: 149.34, Position: up
# Angle: 152.63, Position: up
# Angle: 162.67, Position: up
# Angle: 170.01, Position: up
# Angle: 168.45, Position: up
# Angle: 171.75, Position: up
# Angle: 172.15, Position: up
# Angle: 171.25, Position: up
# Angle: 170.93, Position: up
# Angle: 170.52, Position: up
# Angle: 169.74, Position: up
# Angle: 170.80, Position: up
# Angle: 168.53, Position: up
# Angle: 168.82, Position: down
# Angle: 167.50, Position: down
# Angle: 165.83, Position: down
# Angle: 166.75, Position: down
# Angle: 167.71, Position: down
# Angle: 167.44, Position: down
# Angle: 167.63, Position: down
# Angle: 166.90, Position: down
# Angle: 170.45, Position: down
# Angle: 174.94, Position: down
# Angle: 172.72, Position: down
# Angle: 171.38, Position: down
# Angle: 169.55, Position: down
# Angle: 170.15, Position: down
# Angle: 166.70, Position: down
# Angle: 166.53, Position: down
# Angle: 165.03, Position: down
# Angle: 175.61, Position: down
# Angle: 179.60, Position: down
# Angle: 178.36, Position: down
# Angle: 175.42, Position: down
# Angle: 178.82, Position: down
# Angle: 166.15, Position: down
# Angle: 166.22, Position: down
# Angle: 166.37, Position: down
# Angle: 166.24, Position: down
# Angle: 163.74, Position: down
# Angle: 162.04, Position: down
# Angle: 163.91, Position: down
# Angle: 162.35, Position: down
# Angle: 164.07, Position: down
# Angle: 162.33, Position: down
# Angle: 162.78, Position: down
# Angle: 164.32, Position: down
# Angle: 166.76, Position: down
# Angle: 165.67, Position: down
# Angle: 164.85, Position: down
# Angle: 164.38, Position: down
# Angle: 160.86, Position: down
# Angle: 158.68, Position: down
# Angle: 158.86, Position: down
# Angle: 158.55, Position: down
# Angle: 159.33, Position: down
# Angle: 158.72, Position: down
# Angle: 158.59, Position: down
# Angle: 158.27, Position: down
# Angle: 158.29, Position: down
# Angle: 159.82, Position: down
# Angle: 159.89, Position: down
# Angle: 160.17, Position: down
# Angle: 160.80, Position: down
# Angle: 161.06, Position: down
# Angle: 159.79, Position: down
# Angle: 158.59, Position: down
# Angle: 159.73, Position: down
# Angle: 160.56, Position: down
# Angle: 164.15, Position: down
# Angle: 165.31, Position: down
# Angle: 166.29, Position: down
# Angle: 165.37, Position: down
# Angle: 169.23, Position: down
# Angle: 172.11, Position: down
# Angle: 172.67, Position: down
# Angle: 166.85, Position: down
# Angle: 165.89, Position: down
# Angle: 166.49, Position: down
# Angle: 172.50, Position: down
# Angle: 175.96, Position: down
# Angle: 171.63, Position: down
# Angle: 171.02, Position: down
# Angle: 171.40, Position: down
# Angle: 161.99, Position: down
# Angle: 167.80, Position: down
# Angle: 172.49, Position: down
# Angle: 177.17, Position: down
# Angle: 171.69, Position: down
# Angle: 176.91, Position: down
# Angle: 175.34, Position: down
# Angle: 177.32, Position: down
# Angle: 173.99, Position: down
# Angle: 178.07, Position: down
# Angle: 174.84, Position: down
# Angle: 179.34, Position: down
# Angle: 172.33, Position: down
# Angle: 175.08, Position: down
# Angle: 176.90, Position: down
# Angle: 177.53, Position: down
# Angle: 168.19, Position: down
# Angle: 155.54, Position: down
# Angle: 155.75, Position: down
# Angle: 156.52, Position: down
# Angle: 145.19, Position: down
# Angle: 145.66, Position: down
# Angle: 150.93, Position: down
# Angle: 50.40, Position: down
# Angle: 65.81, Position: down
# Angle: 54.77, Position: down
# Angle: 60.91, Position: down
# Angle: 74.91, Position: down
# Angle: 72.62, Position: down
# Angle: 64.71, Position: down
# Angle: 80.25, Position: down
# Angle: 60.83, Position: down
# Angle: 49.96, Position: down
# Angle: 66.01, Position: down
# Angle: 157.63, Position: down
# Angle: 174.87, Position: down
# Angle: 177.18, Position: down
# Angle: 174.74, Position: down
# Angle: 176.24, Position: down
# Angle: 173.37, Position: down
# Angle: 169.94, Position: down
# Angle: 126.80, Position: down
# Angle: 141.57, Position: down
# Angle: 155.07, Position: down
# Angle: 159.67, Position: down
# Angle: 172.82, Position: down
# Angle: 179.60, Position: down
# Angle: 95.89, Position: down
# Angle: 114.45, Position: down
# Angle: 110.83, Position: down
# Angle: 91.28, Position: down
# Angle: 81.50, Position: down
# Angle: 88.92, Position: down
# Angle: 68.39, Position: down
# Angle: 149.67, Position: down
# Angle: 151.05, Position: down
# Angle: 175.70, Position: down
# Angle: 94.01, Position: down
# Angle: 88.83, Position: down
# Angle: 87.31, Position: down
# Angle: 80.23, Position: down
# Angle: 85.42, Position: down
# Angle: 90.13, Position: down
# Angle: 91.07, Position: down
# Angle: 96.98, Position: down
# Angle: 100.08, Position: down
# Angle: 97.70, Position: down
# Angle: 98.81, Position: down
# Angle: 97.38, Position: down
# Angle: 96.02, Position: down
# Angle: 90.65, Position: down
# Angle: 90.87, Position: down
# Angle: 91.35, Position: down
# Angle: 93.30, Position: down
# Angle: 91.81, Position: down
# Angle: 89.01, Position: down
# Angle: 83.70, Position: down
# Angle: 84.72, Position: down
# Angle: 82.42, Position: down
# Angle: 83.78, Position: down
# Angle: 84.66, Position: down
# Angle: 81.42, Position: down
# Angle: 79.26, Position: down
# Angle: 78.83, Position: down
# Angle: 52.14, Position: down
# Angle: 31.11, Position: down
# ✅ Curl Counted! Total: 3
# Angle: 7.75, Position: up
# Angle: 167.30, Position: up
# Angle: 177.38, Position: up
# Angle: 179.66, Position: up
# Angle: 174.63, Position: up
# Angle: 115.95, Position: down
# Angle: 95.86, Position: down
# Angle: 95.02, Position: down
# Angle: 113.83, Position: down
# Angle: 137.75, Position: down
# Angle: 130.19, Position: down
# Angle: 128.34, Position: down
# Angle: 119.48, Position: down
# Angle: 121.07, Position: down
# Angle: 116.58, Position: down
# Angle: 122.28, Position: down
# Angle: 133.84, Position: down
# Angle: 136.05, Position: down
# Angle: 142.83, Position: down
# Angle: 139.69, Position: down
# Angle: 124.21, Position: down
# Angle: 89.05, Position: down
# Angle: 31.95, Position: down
# Angle: 56.94, Position: down
# Angle: 16.46, Position: down
# Angle: 78.50, Position: down
# Angle: 137.03, Position: down
# Angle: 131.84, Position: down
# Angle: 112.92, Position: down
# Angle: 134.44, Position: down
# Angle: 139.82, Position: down
# Angle: 123.66, Position: down
# Angle: 116.47, Position: down
# Angle: 55.41, Position: down
# Angle: 15.16, Position: down
# Angle: 89.65, Position: down
# Angle: 147.85, Position: down
# Angle: 166.26, Position: down
# Angle: 106.56, Position: down
# Angle: 114.13, Position: down
# Angle: 161.47, Position: down
# Angle: 155.10, Position: down
# Angle: 158.25, Position: down
# Angle: 154.40, Position: down
# Angle: 161.03, Position: down
# Angle: 161.09, Position: down
# Angle: 150.61, Position: down
# Angle: 157.16, Position: down
# Angle: 153.95, Position: down
# Angle: 157.60, Position: down
# Angle: 165.02, Position: down
# Angle: 164.56, Position: down
# Angle: 169.74, Position: down
# Angle: 159.83, Position: down
# Angle: 167.50, Position: down
# Angle: 158.65, Position: down
# Angle: 84.07, Position: down
# Angle: 78.34, Position: down
# Angle: 80.50, Position: down
# Angle: 77.30, Position: down
# Angle: 74.28, Position: down
# Angle: 88.76, Position: down
# Angle: 57.46, Position: down
# Angle: 31.99, Position: down
# ✅ Curl Counted! Total: 4
# Angle: 4.81, Position: up
# Angle: 41.32, Position: up
# Angle: 61.08, Position: up
# Angle: 79.10, Position: up
# Angle: 81.42, Position: up
# Angle: 45.06, Position: up
# Angle: 60.96, Position: up
# Angle: 130.63, Position: up
# Angle: 109.35, Position: up
# Angle: 60.42, Position: up
# Angle: 52.60, Position: up
# Angle: 150.82, Position: up
# Angle: 160.94, Position: down
# Angle: 166.15, Position: down
# Angle: 179.29, Position: down
# Angle: 166.45, Position: down
# Angle: 157.23, Position: down
# Angle: 165.29, Position: down
# Angle: 165.02, Position: down
# Angle: 158.83, Position: down
# Angle: 79.02, Position: down
# Angle: 105.72, Position: down
# Angle: 174.63, Position: down
# Angle: 154.39, Position: down
# Angle: 153.31, Position: down
# Angle: 129.68, Position: down
# Angle: 105.81, Position: down
# Angle: 101.58, Position: down
# Angle: 114.55, Position: down
# Angle: 100.81, Position: down
# Angle: 115.69, Position: down
# Angle: 174.68, Position: down
# Angle: 168.93, Position: down
# Angle: 171.05, Position: down
# Angle: 167.97, Position: down
# Angle: 171.42, Position: down
# Angle: 140.91, Position: down
# Angle: 149.07, Position: down
# Angle: 157.95, Position: down
# Angle: 138.11, Position: down
# Angle: 101.54, Position: down
# Angle: 109.09, Position: down
# Angle: 168.54, Position: down
# Angle: 172.26, Position: down
# Angle: 134.38, Position: down
# Angle: 126.98, Position: down
# Angle: 77.32, Position: down
# Angle: 89.03, Position: down
# Angle: 156.97, Position: down
# Angle: 164.05, Position: down
# Angle: 166.57, Position: down
# Angle: 171.76, Position: down
# Angle: 172.72, Position: down
# Angle: 170.82, Position: down
# Angle: 88.05, Position: down
# Angle: 157.49, Position: down
# Angle: 177.86, Position: down
# Angle: 172.95, Position: down
# Angle: 180.00, Position: down
# Angle: 174.21, Position: down
# Angle: 179.96, Position: down
# Angle: 174.23, Position: down
# Angle: 176.81, Position: down
# Angle: 158.98, Position: down
# Angle: 162.14, Position: down
# Angle: 165.25, Position: down
# Angle: 77.25, Position: down
# Angle: 172.35, Position: down
# Angle: 169.51, Position: down
# Angle: 173.87, Position: down
# Angle: 173.87, Position: down
# Angle: 171.92, Position: down
# Angle: 168.67, Position: down
# Angle: 166.96, Position: down
# Angle: 162.97, Position: down
# Angle: 165.44, Position: down
# Angle: 161.17, Position: down
# Angle: 165.61, Position: down
# Angle: 167.35, Position: down
# Angle: 170.16, Position: down
# Angle: 171.07, Position: down
# Angle: 116.82, Position: down
# Angle: 160.75, Position: down
# Angle: 151.87, Position: down
# Angle: 14.98, Position: down
# Angle: 166.11, Position: down
# Angle: 166.57, Position: down
# Angle: 168.02, Position: down
# Angle: 170.14, Position: down
# Angle: 163.91, Position: down
# Angle: 162.82, Position: down
# Angle: 146.50, Position: down
# Angle: 171.12, Position: down
# Angle: 154.40, Position: down
# Angle: 134.39, Position: down
# Angle: 138.19, Position: down
# Angle: 136.24, Position: down
# Angle: 131.21, Position: down
# Angle: 145.67, Position: down
# Angle: 148.15, Position: down
# Angle: 153.98, Position: down
# Angle: 151.19, Position: down
# Angle: 146.67, Position: down
# Angle: 120.47, Position: down
# Angle: 97.18, Position: down
# Angle: 86.61, Position: down
# Angle: 79.88, Position: down
# Angle: 72.65, Position: down
# Angle: 70.76, Position: down
# Angle: 70.02, Position: down
# Angle: 69.21, Position: down
# Angle: 69.31, Position: down
# Angle: 70.64, Position: down
# Angle: 71.46, Position: down
# Angle: 72.55, Position: down
# Angle: 73.98, Position: down
# Angle: 76.83, Position: down
# Angle: 78.97, Position: down
# Angle: 82.62, Position: down
# Angle: 85.23, Position: down
# Angle: 85.31, Position: down
# Angle: 83.68, Position: down
# Angle: 83.68, Position: down
# Angle: 84.52, Position: down
# Angle: 84.72, Position: down
# Angle: 85.41, Position: down
# Angle: 85.87, Position: down
# Angle: 86.33, Position: down
# Angle: 86.33, Position: down
# Angle: 87.95, Position: down
# Angle: 91.98, Position: down
# Angle: 92.22, Position: down
# Angle: 99.16, Position: down
# Angle: 102.21, Position: down
# Angle: 99.63, Position: down
# Angle: 99.42, Position: down
# Angle: 97.77, Position: down
# Angle: 97.62, Position: down
# Angle: 101.68, Position: down
# Angle: 101.11, Position: down
# Angle: 107.27, Position: down
# Angle: 115.52, Position: down
# Angle: 121.32, Position: down
# Angle: 129.09, Position: down
# Angle: 134.66, Position: down
# Angle: 141.31, Position: down
# Angle: 148.81, Position: down
# Angle: 153.83, Position: down
# Angle: 156.99, Position: down
# Angle: 164.08, Position: down
# Angle: 166.26, Position: down
# Angle: 155.74, Position: down
# Angle: 153.82, Position: down
# Angle: 158.58, Position: down
# Angle: 154.40, Position: down
# Angle: 18.58, Position: down
# ✅ Curl Counted! Total: 5
# Angle: 15.07, Position: up
# Angle: 9.28, Position: up
# Angle: 6.38, Position: up
# Angle: 5.41, Position: up
# Angle: 4.65, Position: up
# Angle: 4.18, Position: up
# Angle: 3.11, Position: up
# Angle: 2.26, Position: up
# Angle: 0.93, Position: up
# Angle: 0.80, Position: up
# Angle: 1.12, Position: up
# Angle: 0.90, Position: up
# Angle: 0.96, Position: up
# Angle: 0.75, Position: up
# Angle: 0.17, Position: up
# Angle: 0.08, Position: up
# Angle: 2.59, Position: up
# Angle: 5.25, Position: up
# Angle: 8.73, Position: up
# Angle: 24.40, Position: up
# Angle: 154.52, Position: up
# Angle: 161.01, Position: up
# Angle: 164.45, Position: up
# Angle: 166.71, Position: up
# Angle: 169.85, Position: up
# Angle: 170.80, Position: up
# Angle: 170.82, Position: up
# Angle: 170.50, Position: up
# Angle: 170.13, Position: up
# Angle: 170.36, Position: down
# Angle: 170.62, Position: down
# Angle: 171.16, Position: down
# Angle: 171.51, Position: down
# Angle: 172.27, Position: down
# Angle: 172.80, Position: down
# Angle: 173.79, Position: down
# Angle: 174.49, Position: down
# Angle: 171.60, Position: down
# Angle: 169.40, Position: down
# Angle: 166.47, Position: down
# Angle: 147.81, Position: down
# Angle: 150.37, Position: down
# Angle: 147.37, Position: down
# Angle: 123.81, Position: down
# Angle: 5.40, Position: down
# Angle: 13.79, Position: down
# ✅ Curl Counted! Total: 6
# Angle: 11.53, Position: up
# Angle: 10.12, Position: up
# Angle: 8.61, Position: up
# Angle: 7.34, Position: up
# Angle: 6.70, Position: up
# Angle: 5.43, Position: up
# Angle: 5.07, Position: up
# Angle: 3.99, Position: up
# Angle: 4.00, Position: up
# Angle: 4.06, Position: up
# Angle: 3.93, Position: up
# Angle: 3.95, Position: up
# Angle: 4.06, Position: up
# Angle: 4.22, Position: up
# Angle: 4.67, Position: up
# Angle: 4.71, Position: up
# Angle: 4.66, Position: up
# Angle: 4.61, Position: up
# Angle: 4.58, Position: up
# Angle: 4.36, Position: up
# Angle: 4.01, Position: up
# Angle: 3.78, Position: up
# Angle: 3.15, Position: up
# Angle: 3.09, Position: up
# Angle: 3.56, Position: up
# Angle: 3.75, Position: up
# Angle: 3.98, Position: up
# Angle: 4.11, Position: up
# Angle: 5.91, Position: up
# Angle: 9.74, Position: up
# Angle: 14.88, Position: up
# Angle: 125.86, Position: up
# Angle: 174.54, Position: up
# Angle: 176.33, Position: up
# Angle: 179.36, Position: up
# Angle: 174.19, Position: up
# Angle: 172.31, Position: up
# Angle: 172.00, Position: up
# Angle: 173.29, Position: up
# Angle: 172.99, Position: up
# Angle: 172.86, Position: up
# Angle: 173.96, Position: down
# Angle: 174.70, Position: down
# Angle: 175.44, Position: down
# Angle: 175.24, Position: down
# Angle: 175.26, Position: down
# Angle: 175.91, Position: down
# Angle: 175.65, Position: down
# Angle: 175.65, Position: down
# Angle: 175.09, Position: down
# Angle: 175.97, Position: down
# Angle: 173.49, Position: down
# Angle: 174.34, Position: down
# Angle: 171.68, Position: down
# Angle: 169.64, Position: down
# Angle: 163.34, Position: down
# Angle: 160.32, Position: down
# Angle: 179.16, Position: down
# Angle: 114.58, Position: down
# Angle: 52.80, Position: down
# Angle: 38.41, Position: down
# ✅ Curl Counted! Total: 7
# Angle: 31.25, Position: up
# Angle: 26.92, Position: up
# Angle: 23.74, Position: up
# Angle: 21.75, Position: up
# Angle: 18.70, Position: up
# Angle: 15.61, Position: up
# Angle: 14.74, Position: up
# Angle: 14.57, Position: up
# Angle: 13.90, Position: up
# Angle: 12.75, Position: up
# Angle: 12.26, Position: up
# Angle: 11.75, Position: up
# Angle: 11.27, Position: up
# Angle: 10.90, Position: up
# Angle: 9.98, Position: up
# Angle: 7.94, Position: up
# Angle: 7.16, Position: up
# Angle: 6.53, Position: up
# Angle: 5.73, Position: up
# Angle: 5.22, Position: up
# Angle: 5.01, Position: up
# Angle: 5.03, Position: up
# Angle: 5.12, Position: up
# Angle: 5.03, Position: up
# Angle: 5.03, Position: up
# Angle: 5.02, Position: up
# Angle: 4.76, Position: up
# Angle: 4.65, Position: up
# Angle: 4.86, Position: up
# Angle: 9.63, Position: up
# Angle: 65.11, Position: up
# Angle: 171.57, Position: up
# Angle: 166.29, Position: up
# Angle: 168.68, Position: up
# Angle: 173.79, Position: up
# Angle: 172.39, Position: up
# Angle: 174.52, Position: up
# Angle: 179.86, Position: up
# Angle: 178.68, Position: down
# Angle: 176.36, Position: down
# Angle: 174.80, Position: down
# Angle: 173.06, Position: down
# Angle: 172.96, Position: down
# Angle: 167.35, Position: down
# Angle: 172.55, Position: down
# Angle: 175.87, Position: down
# Angle: 173.90, Position: down
# Angle: 177.80, Position: down
# Angle: 175.62, Position: down
# Angle: 178.43, Position: down
# Angle: 179.50, Position: down
# Angle: 179.50, Position: down
# Angle: 176.51, Position: down
# Angle: 177.38, Position: down
# Angle: 178.58, Position: down
# Angle: 178.54, Position: down
# Angle: 179.88, Position: down
# Angle: 179.36, Position: down
# Angle: 179.69, Position: down
# Angle: 178.58, Position: down
# Angle: 179.98, Position: down
# Angle: 177.73, Position: down
# Angle: 177.73, Position: down
# Angle: 175.94, Position: down
# Angle: 176.75, Position: down
# Angle: 176.16, Position: down
# Angle: 175.83, Position: down
# Angle: 176.51, Position: down
# Angle: 176.35, Position: down
# Angle: 175.55, Position: down
# Angle: 175.32, Position: down
# Angle: 179.42, Position: down
# Angle: 175.69, Position: down
# Angle: 169.15, Position: down
# Angle: 173.01, Position: down
# Angle: 173.54, Position: down
# Angle: 173.93, Position: down
# Angle: 170.84, Position: down
# Angle: 179.14, Position: down
# Angle: 177.54, Position: down
# Angle: 177.72, Position: down
# Angle: 176.03, Position: down
# Angle: 174.26, Position: down
# Angle: 174.38, Position: down
# Angle: 175.86, Position: down
# Angle: 174.97, Position: down
# Angle: 159.07, Position: down
# Angle: 154.35, Position: down
# Angle: 151.03, Position: down
# Angle: 159.21, Position: down
# Angle: 175.14, Position: down
# Angle: 179.02, Position: down
# Angle: 177.25, Position: down
# Angle: 177.03, Position: down
# Angle: 179.34, Position: down
# Angle: 177.88, Position: down
# Angle: 177.20, Position: down
# Angle: 178.00, Position: down
# Angle: 175.22, Position: down
# Angle: 177.10, Position: down
# Angle: 179.85, Position: down
# Angle: 178.52, Position: down
# Angle: 173.75, Position: down
# Angle: 172.60, Position: down
# Angle: 175.88, Position: down
# Angle: 177.44, Position: down
# Angle: 171.38, Position: down
# Angle: 177.09, Position: down
# Angle: 177.14, Position: down
# Angle: 133.15, Position: down
# Angle: 105.83, Position: down
# Angle: 121.74, Position: down
# Angle: 148.75, Position: down
# Angle: 149.61, Position: down
# Angle: 168.38, Position: down
# Angle: 60.00, Position: down
# Angle: 87.71, Position: down
# Angle: 26.09, Position: down
# ✅ Curl Counted! Total: 8
# Angle: 40.36, Position: up
# Angle: 112.40, Position: up
# Angle: 107.98, Position: up
# Angle: 113.33, Position: up
# Angle: 96.02, Position: up
# Angle: 2.50, Position: up
# Angle: 12.99, Position: up
# Angle: 14.58, Position: up
# Angle: 19.72, Position: up
# Angle: 23.56, Position: up
# Angle: 27.17, Position: up
# Angle: 29.78, Position: up
# Angle: 27.27, Position: up
# Angle: 26.13, Position: up
# Angle: 21.78, Position: up
# Angle: 18.84, Position: up
# Angle: 17.76, Position: up
# Angle: 16.56, Position: up
# Angle: 24.79, Position: up
# Angle: 97.75, Position: up
# Angle: 24.21, Position: up
# Angle: 135.32, Position: up
# Angle: 157.11, Position: up
# Angle: 159.83, Position: up
# Angle: 161.14, Position: up
# Angle: 168.74, Position: up
# Angle: 179.33, Position: up
# Angle: 174.72, Position: up
# Angle: 178.17, Position: up
# Angle: 178.43, Position: up
# Angle: 173.50, Position: up
# Angle: 176.08, Position: up
# Angle: 176.29, Position: up
# Angle: 176.05, Position: up
# Angle: 175.53, Position: up
# Angle: 175.64, Position: up
# Angle: 175.54, Position: up
# Angle: 173.89, Position: up
# Angle: 176.02, Position: up
# Angle: 177.03, Position: up
# Angle: 179.82, Position: up
# Angle: 179.30, Position: up
# Angle: 178.78, Position: up
# Angle: 178.83, Position: up
# Angle: 175.70, Position: up
# Angle: 174.41, Position: up
# Angle: 167.88, Position: up
# Angle: 166.53, Position: up
# Angle: 167.30, Position: up
# Angle: 164.77, Position: up
# Angle: 158.91, Position: up
# Angle: 155.47, Position: up
# Angle: 156.53, Position: up
# Angle: 165.25, Position: up
# Angle: 173.51, Position: up
# Angle: 177.23, Position: up
# Angle: 175.19, Position: up
# Angle: 177.01, Position: up
# Angle: 168.82, Position: up
# Angle: 173.03, Position: up
# Angle: 175.36, Position: up
# Angle: 171.51, Position: up
# Angle: 172.47, Position: up
# Angle: 168.79, Position: up
# Angle: 163.28, Position: up
# Angle: 164.70, Position: up
# Angle: 165.59, Position: up
# Angle: 166.29, Position: up
# Angle: 169.69, Position: up
# Angle: 171.78, Position: up
# Angle: 165.68, Position: up
# Angle: 164.81, Position: up
# Angle: 166.12, Position: up
# Angle: 164.01, Position: up
# Angle: 168.57, Position: up
# Angle: 171.19, Position: up
# Angle: 171.47, Position: up
# Angle: 171.92, Position: up
# Angle: 172.16, Position: up
# Angle: 172.05, Position: up
# Angle: 171.11, Position: up
# Angle: 172.54, Position: up
# Angle: 172.39, Position: up
# Angle: 171.66, Position: up
# Angle: 171.88, Position: up
# Angle: 172.07, Position: up
# Angle: 172.98, Position: up
# Angle: 171.27, Position: up
# Angle: 165.21, Position: up
# Angle: 166.07, Position: up
# Angle: 164.39, Position: up
# Angle: 159.95, Position: up
# Angle: 154.78, Position: up
# Angle: 145.06, Position: up
# Angle: 143.63, Position: up
# Angle: 153.35, Position: up
# Angle: 148.24, Position: up
# Angle: 133.82, Position: up
# Angle: 120.72, Position: up
# Angle: 103.15, Position: up
# Angle: 113.17, Position: up
# Angle: 107.59, Position: up
# Angle: 136.58, Position: up
# Angle: 153.16, Position: up
# Angle: 156.52, Position: up
# Angle: 173.69, Position: up
# Angle: 175.26, Position: up
# Angle: 175.28, Position: up
# Angle: 175.63, Position: up
# Angle: 174.35, Position: up
# Angle: 175.90, Position: up
# Angle: 168.66, Position: up
# Angle: 170.65, Position: up
# Angle: 170.72, Position: up
# Angle: 170.35, Position: up
# Angle: 171.82, Position: up
# Angle: 173.19, Position: up
# Angle: 174.87, Position: up
# Angle: 174.65, Position: up
# Angle: 173.61, Position: up
# Angle: 174.76, Position: up
# Angle: 175.00, Position: up
# Angle: 174.75, Position: up
# Angle: 175.06, Position: up
# Angle: 174.88, Position: up
# Angle: 174.56, Position: up
# Angle: 175.57, Position: up
# Angle: 175.81, Position: up
# Angle: 175.79, Position: up
# Angle: 175.85, Position: up
# Angle: 175.96, Position: up
# Angle: 176.41, Position: up
# Angle: 176.78, Position: up
# Angle: 179.55, Position: up
# Angle: 179.89, Position: up
# Angle: 179.47, Position: up
# Angle: 178.04, Position: up
# Angle: 178.03, Position: up
# Angle: 171.57, Position: up
# Angle: 172.55, Position: up
# Angle: 171.35, Position: up
# Angle: 172.39, Position: up
# Angle: 173.46, Position: up
# Angle: 179.48, Position: up
# Angle: 174.19, Position: up
# Angle: 173.74, Position: up
# Angle: 170.82, Position: up
# Angle: 169.74, Position: up
# Angle: 170.78, Position: up
# Angle: 171.11, Position: up
# Angle: 170.96, Position: up
# Angle: 170.18, Position: up
# Angle: 168.88, Position: up
# Angle: 166.62, Position: up
# Angle: 166.70, Position: up
# Angle: 166.95, Position: up
# Angle: 166.46, Position: up
# Angle: 165.05, Position: up
# Angle: 164.57, Position: up
# Angle: 164.67, Position: up
# Angle: 165.39, Position: up
# Angle: 168.05, Position: up
# Angle: 169.45, Position: up
# Angle: 171.35, Position: up
# Angle: 171.88, Position: up
# Angle: 176.62, Position: up
# Angle: 177.51, Position: up
# Angle: 179.64, Position: up
# Angle: 177.47, Position: up
# Angle: 167.75, Position: up
# Angle: 167.45, Position: up
# Angle: 155.29, Position: up
# Angle: 162.47, Position: up
# Angle: 172.01, Position: up
# Angle: 172.99, Position: up
# Angle: 176.07, Position: up
# Angle: 175.44, Position: up
# Angle: 175.96, Position: up
# Angle: 174.56, Position: up
# Angle: 174.01, Position: up
# Angle: 175.38, Position: up
# Angle: 176.11, Position: up
# Angle: 176.76, Position: up
# Angle: 176.54, Position: up
# Angle: 175.18, Position: up
# Angle: 178.09, Position: up
# Angle: 178.23, Position: up
# Angle: 177.83, Position: up
# Angle: 170.64, Position: up
# Angle: 164.05, Position: up
# Angle: 157.16, Position: up
# Angle: 130.58, Position: up
# Angle: 117.81, Position: up
# Angle: 94.58, Position: up
# Angle: 79.51, Position: up
# Angle: 68.90, Position: up
# Angle: 61.22, Position: up
# Angle: 52.70, Position: up
# Angle: 49.85, Position: up
# Angle: 47.72, Position: up
# Angle: 44.09, Position: up
# Angle: 42.58, Position: up
# Angle: 41.41, Position: up
# Angle: 38.85, Position: up
# Angle: 36.84, Position: up
# Angle: 28.91, Position: up
# Angle: 29.01, Position: up
# Angle: 28.93, Position: up
# Angle: 28.24, Position: up
# Angle: 29.89, Position: up
# Angle: 30.69, Position: up
# Angle: 30.21, Position: up
# Angle: 30.10, Position: up
# Angle: 31.41, Position: up
# Angle: 30.93, Position: up
# Angle: 29.47, Position: up
# Angle: 30.19, Position: up
# Angle: 29.91, Position: up
# Angle: 27.15, Position: up
# Angle: 25.34, Position: up
# Angle: 21.46, Position: up
# Angle: 18.75, Position: up
# Angle: 18.15, Position: up
# Angle: 16.18, Position: up
# Angle: 8.43, Position: up
# Angle: 1.16, Position: up
# Angle: 8.79, Position: up
# Angle: 14.16, Position: up
# Angle: 20.95, Position: up
# Angle: 37.65, Position: up
# Angle: 49.99, Position: up
# Angle: 177.03, Position: up
# Angle: 171.82, Position: up
# Angle: 170.35, Position: up
# Angle: 168.70, Position: up
# Angle: 165.55, Position: up
# Angle: 165.77, Position: up
# Angle: 168.21, Position: up
# Angle: 170.68, Position: up
# Angle: 171.37, Position: up
# Angle: 178.72, Position: up
# Angle: 179.51, Position: up
# Angle: 178.25, Position: up
# Angle: 178.69, Position: up
# Angle: 176.68, Position: up
# Angle: 177.34, Position: up
# Angle: 178.33, Position: up
# Angle: 179.05, Position: up
# Angle: 179.54, Position: up
# Angle: 177.19, Position: up
# Angle: 178.36, Position: up
# Angle: 178.84, Position: up
# Angle: 179.84, Position: up
# Angle: 176.82, Position: up
# Angle: 177.73, Position: up
# Angle: 168.64, Position: up
# Angle: 171.25, Position: up
# Angle: 172.48, Position: up
# Angle: 172.95, Position: up
# Angle: 174.26, Position: up
# Angle: 172.78, Position: up
# Angle: 173.96, Position: up
# Angle: 179.22, Position: up
# Angle: 178.20, Position: up
# Angle: 172.35, Position: up
# Angle: 172.92, Position: up
# Angle: 174.98, Position: up
# Angle: 174.70, Position: up
# Angle: 174.05, Position: up
# Angle: 173.70, Position: up
# Angle: 175.25, Position: up
# Angle: 175.84, Position: up
# Angle: 177.48, Position: up
# Angle: 177.18, Position: up
# Angle: 177.12, Position: up
# Angle: 178.52, Position: up
# Angle: 178.74, Position: up
# Angle: 179.09, Position: up
# Angle: 178.48, Position: up
# Angle: 177.68, Position: up
# Angle: 177.50, Position: up
# Angle: 177.04, Position: up
# Angle: 174.44, Position: up
# Angle: 172.45, Position: up
# Angle: 171.59, Position: up
# Angle: 176.76, Position: up
# Angle: 175.21, Position: up
# Angle: 175.16, Position: up
# Angle: 175.40, Position: up
# Angle: 176.77, Position: up
# Angle: 176.71, Position: up
# Angle: 175.76, Position: up
# Angle: 177.10, Position: up
# Angle: 177.19, Position: up
# Angle: 177.47, Position: up
# Angle: 177.44, Position: up
# Angle: 178.56, Position: up
# Angle: 175.42, Position: up
# Angle: 176.05, Position: up
# Angle: 175.97, Position: up
# Angle: 179.65, Position: up
# Angle: 177.80, Position: up
# Angle: 177.49, Position: up
# Angle: 174.21, Position: up
# Angle: 177.95, Position: up
# Angle: 165.02, Position: up
# Angle: 162.40, Position: up
# Angle: 165.91, Position: up
# Angle: 179.96, Position: up
# Angle: 174.20, Position: up
# Angle: 173.93, Position: up
# Angle: 120.74, Position: up
# Angle: 10.69, Position: up
# Angle: 173.00, Position: up
# Angle: 178.15, Position: up
# Angle: 168.11, Position: up
# Angle: 169.55, Position: up
# Angle: 173.38, Position: up
# Angle: 170.34, Position: up
# Angle: 168.94, Position: up
# Angle: 169.89, Position: up
# Angle: 170.29, Position: up
# Angle: 175.19, Position: up
# Angle: 177.31, Position: up
# Angle: 179.49, Position: up
# Angle: 174.75, Position: up
# Angle: 171.62, Position: up
# Angle: 173.98, Position: up
# Angle: 178.65, Position: up
# Angle: 178.07, Position: up
# Angle: 177.24, Position: up
# Angle: 178.85, Position: up
# Angle: 155.33, Position: up
# Angle: 148.16, Position: up
# Angle: 137.68, Position: up
# Angle: 125.31, Position: up
# Angle: 169.89, Position: up
# Angle: 166.59, Position: up
# Angle: 166.65, Position: up
# Angle: 179.02, Position: up
# Angle: 171.64, Position: up
# Angle: 137.97, Position: up
# Angle: 55.06, Position: up
# Angle: 16.11, Position: up
# Angle: 18.18, Position: up
# Angle: 21.43, Position: up
# Angle: 22.69, Position: up
# Angle: 14.71, Position: up
# Angle: 59.16, Position: up
# Angle: 65.03, Position: up
# Angle: 86.94, Position: up
# Angle: 145.57, Position: up
# Angle: 154.59, Position: up
# Angle: 156.37, Position: up
# Angle: 142.20, Position: up
# Angle: 139.77, Position: up
# Angle: 133.95, Position: up
# Angle: 130.20, Position: up
# Angle: 130.48, Position: up
# Angle: 127.32, Position: up
# Angle: 125.58, Position: up
# Angle: 118.67, Position: up
# Angle: 125.73, Position: up
# Angle: 130.04, Position: up
# Angle: 138.25, Position: up
# Angle: 137.00, Position: up
# Angle: 136.20, Position: up
# Angle: 137.48, Position: up
# Angle: 139.15, Position: up
# Angle: 141.28, Position: up
# Angle: 146.09, Position: up
# Angle: 146.76, Position: up
# Angle: 152.95, Position: up
# Angle: 157.57, Position: up
# Angle: 161.36, Position: up
# Angle: 161.39, Position: up
# Angle: 163.49, Position: up
# Angle: 163.63, Position: up
# Angle: 165.54, Position: up
# Angle: 164.11, Position: up
# Angle: 163.24, Position: up
# Angle: 163.28, Position: up
# Angle: 165.86, Position: up
# Angle: 165.61, Position: up
# Angle: 168.91, Position: up
# Angle: 170.79, Position: up
# Angle: 171.06, Position: up
# Angle: 170.58, Position: up
# Angle: 170.48, Position: up
# Angle: 172.59, Position: up
# Angle: 173.56, Position: up
# Angle: 162.88, Position: up
# Angle: 163.16, Position: up
# Angle: 166.45, Position: up
# Angle: 167.98, Position: up
# Angle: 167.06, Position: up
# Angle: 167.21, Position: up
# Angle: 165.49, Position: up
# Angle: 149.29, Position: up
# Angle: 157.00, Position: up
# Angle: 159.08, Position: up
# Angle: 161.54, Position: up
# Angle: 164.17, Position: up
# Angle: 163.95, Position: up
# Angle: 169.20, Position: up
# Angle: 170.18, Position: up
# Angle: 174.44, Position: up
# Angle: 178.85, Position: up
# Angle: 178.29, Position: up
# Angle: 179.66, Position: up
# Angle: 177.19, Position: up
# Angle: 175.09, Position: up
# Angle: 170.40, Position: up
# Angle: 171.62, Position: up
# Angle: 155.92, Position: up
# Angle: 163.82, Position: up
# Angle: 166.06, Position: up
# Angle: 170.17, Position: up
# Angle: 168.85, Position: up
# Angle: 171.51, Position: up
# Angle: 160.32, Position: up
# Angle: 174.24, Position: up
# Angle: 163.40, Position: up
# Angle: 148.99, Position: up
# Angle: 36.46, Position: up
# Angle: 34.01, Position: up
# Angle: 5.25, Position: up
# Angle: 9.70, Position: up
# Angle: 8.38, Position: up
# Angle: 10.48, Position: up
# Angle: 9.50, Position: up
# Angle: 7.34, Position: up
# Angle: 14.87, Position: up
# Angle: 13.94, Position: up
# Angle: 2.46, Position: up
# Angle: 116.31, Position: up
# Angle: 134.29, Position: up
# Angle: 108.91, Position: up
# Angle: 88.75, Position: up
# Angle: 68.40, Position: up
# Angle: 52.65, Position: up
# Angle: 50.21, Position: up
# Angle: 49.63, Position: up
# Angle: 47.63, Position: up
# Angle: 48.05, Position: up
# Angle: 45.81, Position: up
# Angle: 43.58, Position: up
# Angle: 41.96, Position: up
# Angle: 39.73, Position: up
# Angle: 40.50, Position: up
# Angle: 41.41, Position: up
# Angle: 46.50, Position: up
# Angle: 47.44, Position: up
# Angle: 47.16, Position: up
# Angle: 47.52, Position: up
# Angle: 48.72, Position: up
# Angle: 45.00, Position: up
# Angle: 38.41, Position: up
# Angle: 34.94, Position: up
# Angle: 27.69, Position: up
# Angle: 20.82, Position: up
# Angle: 16.11, Position: up
# Angle: 7.13, Position: up
# Angle: 13.00, Position: up
# Angle: 37.70, Position: up
# Angle: 56.31, Position: up
# Angle: 50.41, Position: up
# Angle: 93.06, Position: up
# Angle: 117.08, Position: up
# Angle: 133.22, Position: up
# Angle: 12.43, Position: up
# Angle: 17.27, Position: up
# Angle: 13.90, Position: up
# Angle: 17.14, Position: up
# Angle: 14.76, Position: up
# Angle: 14.95, Position: up
# Angle: 14.63, Position: up
# Angle: 16.20, Position: up
# Angle: 19.02, Position: up
# Angle: 21.01, Position: up
# Angle: 22.17, Position: up
# Angle: 21.67, Position: up
# Angle: 25.53, Position: up
# Angle: 29.94, Position: up
# Angle: 51.15, Position: up
# Angle: 78.19, Position: up
# Angle: 86.74, Position: up
# Angle: 86.49, Position: up
# Angle: 82.04, Position: up
# Angle: 79.13, Position: up
# Angle: 78.52, Position: up
# Angle: 72.90, Position: up
# Angle: 51.69, Position: up
# Angle: 4.54, Position: up
# Angle: 31.67, Position: up
# Angle: 56.05, Position: up
# Angle: 38.65, Position: up
# Angle: 23.94, Position: up
# Angle: 16.63, Position: up
# Angle: 16.97, Position: up
# Angle: 20.10, Position: up
# Angle: 18.06, Position: up
# Angle: 18.48, Position: up
# Angle: 18.73, Position: up
# Angle: 18.12, Position: up
# Angle: 17.89, Position: up
# Angle: 19.07, Position: up
# Angle: 19.91, Position: up
# Angle: 19.25, Position: up
# Angle: 20.23, Position: up
# Angle: 21.63, Position: up
# Angle: 23.74, Position: up
# Angle: 24.93, Position: up
# Angle: 25.83, Position: up
# Angle: 25.03, Position: up
# Angle: 28.75, Position: up
# Angle: 31.80, Position: up
# Angle: 32.80, Position: up
# Angle: 35.85, Position: up
# Angle: 31.85, Position: up
# Angle: 27.40, Position: up
# Angle: 24.93, Position: up
# Angle: 22.27, Position: up
# Angle: 18.71, Position: up
# Angle: 14.63, Position: up
# Angle: 10.51, Position: up
# Angle: 2.04, Position: up
# Angle: 5.47, Position: up
# Angle: 8.23, Position: up
# Angle: 9.71, Position: up
# Angle: 12.69, Position: up
# Angle: 19.39, Position: up
# Angle: 24.44, Position: up
# Angle: 34.55, Position: up
# Angle: 41.09, Position: up
# Angle: 42.81, Position: up
# Angle: 38.97, Position: up
# Angle: 30.22, Position: up
# Angle: 28.94, Position: up
# Angle: 29.60, Position: up
# Angle: 30.80, Position: up
# Angle: 30.75, Position: up
# Angle: 31.97, Position: up
# Angle: 32.76, Position: up
# Angle: 36.92, Position: up
# Angle: 39.19, Position: up
# Angle: 44.00, Position: up
# Angle: 48.14, Position: up
# Angle: 50.14, Position: up
# Angle: 51.06, Position: up
# Angle: 49.96, Position: up
# Angle: 48.70, Position: up
# Angle: 47.45, Position: up
# Angle: 46.43, Position: up
# Angle: 43.49, Position: up
# Angle: 40.62, Position: up
# Angle: 33.05, Position: up
# Angle: 32.61, Position: up
# Angle: 32.90, Position: up
# Angle: 31.68, Position: up
# Angle: 38.83, Position: up
# Angle: 40.09, Position: up
# Angle: 34.09, Position: up
# Angle: 34.21, Position: up
# Angle: 37.12, Position: up
# Angle: 38.28, Position: up
# Angle: 38.87, Position: up
# Angle: 55.02, Position: up
# Angle: 121.62, Position: up
# Angle: 135.14, Position: up
# Angle: 103.48, Position: up
# Angle: 146.80, Position: up
# Angle: 163.84, Position: down
# Angle: 156.32, Position: down
# Angle: 97.44, Position: down
# Angle: 95.43, Position: down
# Angle: 85.31, Position: down
# Angle: 75.67, Position: down
# Angle: 63.19, Position: down
# Angle: 56.25, Position: down
# Angle: 55.59, Position: down
# Angle: 55.21, Position: down
# Angle: 52.29, Position: down
# Angle: 47.35, Position: down
# Angle: 31.44, Position: down
# Angle: 34.24, Position: down
# Angle: 23.94, Position: down
# Angle: 31.47, Position: down
# Angle: 31.87, Position: down
# Angle: 33.31, Position: down
# Angle: 32.96, Position: down
# Angle: 33.80, Position: down
# Angle: 32.08, Position: down
# Angle: 30.78, Position: down
# Angle: 25.56, Position: down
# Angle: 22.79, Position: down
# Angle: 19.82, Position: down
# Angle: 19.42, Position: down
# Angle: 20.17, Position: down
# Angle: 17.84, Position: down
# Angle: 15.87, Position: down
# Angle: 18.73, Position: down
# Angle: 27.15, Position: down
# Angle: 29.66, Position: down
# Angle: 29.65, Position: down
# Angle: 24.35, Position: down
# Angle: 21.00, Position: down
# Angle: 19.15, Position: down
# Angle: 20.39, Position: down
# Angle: 25.45, Position: down
# Angle: 29.43, Position: down
# Angle: 31.67, Position: down
# Angle: 34.33, Position: down
# Angle: 33.73, Position: down
# Angle: 35.26, Position: down
# Angle: 35.89, Position: down
# Angle: 37.97, Position: down
# Angle: 39.30, Position: down
# Angle: 40.50, Position: down
# Angle: 41.86, Position: down
# Angle: 44.23, Position: down
# Angle: 45.32, Position: down
# Angle: 46.89, Position: down
# Angle: 48.07, Position: down
# Angle: 49.08, Position: down
# Angle: 50.70, Position: down
# Angle: 50.64, Position: down
# Angle: 50.79, Position: down
# Angle: 50.91, Position: down
# Angle: 51.18, Position: down
# Angle: 51.43, Position: down
# Angle: 51.70, Position: down
# Angle: 50.27, Position: down
# Angle: 49.81, Position: down
# Angle: 47.45, Position: down
# Angle: 44.19, Position: down
# Angle: 48.24, Position: down
# ✅ Curl Counted! Total: 9
# Angle: 49.23, Position: up
# Angle: 44.28, Position: up
# Angle: 94.39, Position: up
# Angle: 131.95, Position: up
# Angle: 140.51, Position: up
# Angle: 150.13, Position: up
# Angle: 155.69, Position: up
# Angle: 165.65, Position: up
# Angle: 170.70, Position: up
# Angle: 177.03, Position: up
# Angle: 179.72, Position: up
# Angle: 177.82, Position: up
# Angle: 176.57, Position: up
# Angle: 175.94, Position: up
# Angle: 175.73, Position: up
# Angle: 176.52, Position: up
# Angle: 175.79, Position: up
# Angle: 176.33, Position: up
# Angle: 177.04, Position: up
# Angle: 178.51, Position: up
# Angle: 179.77, Position: down
# Angle: 176.87, Position: down
# Angle: 174.97, Position: down
# Angle: 174.94, Position: down
# Angle: 174.32, Position: down
# Angle: 172.74, Position: down
# Angle: 172.19, Position: down
# Angle: 169.55, Position: down
# Angle: 170.33, Position: down
# Angle: 170.35, Position: down
# Angle: 169.61, Position: down
# Angle: 169.26, Position: down
# Angle: 170.20, Position: down
# Angle: 170.52, Position: down
# Angle: 171.61, Position: down
# Angle: 170.91, Position: down
# Angle: 170.71, Position: down
# Angle: 170.46, Position: down
# Angle: 170.46, Position: down
# Angle: 171.29, Position: down
# Angle: 171.27, Position: down
# Angle: 171.17, Position: down
# Angle: 171.27, Position: down
# Angle: 171.21, Position: down
# Angle: 172.18, Position: down
# Angle: 173.42, Position: down
# Angle: 173.76, Position: down
# Angle: 175.27, Position: down
# Angle: 176.82, Position: down
# Angle: 177.86, Position: down
# Angle: 179.29, Position: down
# Angle: 179.28, Position: down
# Angle: 178.95, Position: down
# Angle: 179.85, Position: down
# Angle: 179.80, Position: down
# Angle: 179.58, Position: down
# Angle: 179.68, Position: down
# Angle: 179.79, Position: down
# Angle: 179.91, Position: down
# Angle: 179.91, Position: down
# Angle: 179.84, Position: down
# Angle: 179.69, Position: down
# Angle: 177.44, Position: down
# Angle: 175.30, Position: down
# Angle: 171.80, Position: down
# Angle: 164.27, Position: down
# Angle: 151.36, Position: down
# Angle: 137.00, Position: down
# Angle: 122.56, Position: down
# Angle: 119.87, Position: down
# Angle: 114.96, Position: down
# Angle: 112.38, Position: down
# Angle: 110.76, Position: down
# Angle: 99.59, Position: down
# Angle: 103.43, Position: down
# Angle: 114.71, Position: down
# Angle: 139.25, Position: down
# Angle: 145.95, Position: down
# Angle: 148.32, Position: down
# Angle: 152.03, Position: down
# Angle: 152.51, Position: down
# Angle: 155.66, Position: down
# Angle: 158.17, Position: down
# Angle: 161.57, Position: down
# Angle: 162.78, Position: down
# Angle: 165.41, Position: down
# Angle: 166.65, Position: down
# Angle: 167.27, Position: down
# Angle: 168.76, Position: down
# Angle: 170.46, Position: down
# Angle: 171.28, Position: down
# Angle: 171.56, Position: down
# Angle: 170.89, Position: down
# Angle: 169.54, Position: down
# Angle: 165.22, Position: down
# Angle: 160.63, Position: down
# Angle: 154.80, Position: down
# Angle: 140.55, Position: down
# Angle: 118.73, Position: down
# Angle: 63.16, Position: down
# Angle: 23.73, Position: down
# Angle: 17.79, Position: down
# Angle: 17.56, Position: down
# Angle: 18.86, Position: down
# Angle: 29.89, Position: down
# Angle: 74.28, Position: down
# Angle: 140.50, Position: down
# Angle: 146.23, Position: down
# Angle: 149.04, Position: down
# Angle: 152.90, Position: down
# Angle: 158.54, Position: down
# Angle: 163.29, Position: down
# Angle: 165.83, Position: down
# Angle: 170.44, Position: down
# Angle: 172.29, Position: down
# Angle: 172.71, Position: down
# Angle: 171.84, Position: down
# Angle: 171.91, Position: down
# Angle: 171.68, Position: down
# Angle: 171.25, Position: down
# Angle: 171.63, Position: down
# Angle: 171.63, Position: down
# Angle: 171.38, Position: down
# Angle: 170.25, Position: down
# Angle: 169.05, Position: down
# Angle: 167.26, Position: down
# Angle: 164.84, Position: down
# Angle: 161.03, Position: down
# Angle: 159.33, Position: down
# Angle: 156.16, Position: down
# Angle: 152.58, Position: down
# Angle: 150.77, Position: down
# Angle: 146.84, Position: down
# Angle: 122.19, Position: down
# Angle: 111.64, Position: down
# Angle: 104.38, Position: down
# Angle: 100.02, Position: down
# Angle: 95.50, Position: down
# Angle: 90.83, Position: down
# Angle: 88.06, Position: down
# Angle: 87.14, Position: down
# Angle: 86.81, Position: down
# Angle: 87.21, Position: down
# Angle: 86.69, Position: down
# Angle: 85.96, Position: down
# Angle: 84.18, Position: down
# Angle: 84.07, Position: down
# Angle: 84.20, Position: down
# Angle: 83.66, Position: down
# Angle: 82.64, Position: down
# Angle: 81.13, Position: down
# Angle: 80.79, Position: down
# Angle: 80.30, Position: down
# Angle: 79.94, Position: down
# Angle: 81.08, Position: down
# Angle: 84.99, Position: down
# Angle: 86.32, Position: down
# Angle: 87.78, Position: down
# Angle: 85.90, Position: down
# Angle: 84.46, Position: down
# Angle: 82.60, Position: down
# Angle: 81.60, Position: down
# Angle: 81.88, Position: down
# Angle: 81.98, Position: down
# Angle: 80.95, Position: down
# Angle: 82.69, Position: down
# Angle: 82.59, Position: down
# Angle: 81.82, Position: down
# Angle: 82.22, Position: down
# Angle: 82.29, Position: down
# Angle: 80.67, Position: down
# Angle: 80.31, Position: down
# Angle: 81.21, Position: down
# Angle: 81.45, Position: down
# Angle: 83.71, Position: down
# Angle: 84.77, Position: down
# Angle: 86.09, Position: down
# Angle: 90.01, Position: down
# Angle: 90.79, Position: down
# Angle: 92.21, Position: down
# Angle: 93.74, Position: down
# Angle: 93.40, Position: down
# Angle: 93.14, Position: down
# Angle: 96.94, Position: down
# Angle: 99.11, Position: down
# Angle: 106.08, Position: down
# Angle: 109.34, Position: down
# Angle: 124.50, Position: down
# Angle: 135.44, Position: down
# Angle: 145.63, Position: down
# Angle: 148.01, Position: down
# Angle: 152.68, Position: down
# Angle: 151.81, Position: down
# Angle: 156.76, Position: down
# Angle: 157.81, Position: down
# Angle: 156.92, Position: down
# Angle: 155.87, Position: down
# Angle: 154.22, Position: down
# Angle: 156.65, Position: down
# Angle: 158.05, Position: down
# Angle: 154.52, Position: down
# Angle: 160.44, Position: down
# Angle: 158.50, Position: down
# Angle: 145.25, Position: down
# Angle: 153.33, Position: down
# Angle: 159.93, Position: down
# Angle: 162.20, Position: down
# Angle: 160.86, Position: down
# Angle: 158.51, Position: down
# Angle: 156.78, Position: down
# Angle: 156.00, Position: down
# Angle: 158.81, Position: down
# Angle: 152.14, Position: down
# Angle: 157.41, Position: down
# Angle: 168.63, Position: down
# Angle: 168.19, Position: down
# Angle: 171.57, Position: down
# Angle: 172.90, Position: down
# Angle: 169.80, Position: down
# Angle: 171.86, Position: down
# Angle: 178.60, Position: down
# Angle: 178.30, Position: down
# Angle: 177.77, Position: down
# Angle: 175.22, Position: down
# Angle: 178.49, Position: down
# Angle: 175.91, Position: down
# Angle: 173.06, Position: down
# Angle: 147.11, Position: down
# Angle: 158.90, Position: down
# ✅ Saved 9 reps of Bicep curl to exercise_log.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Trying

# %%
import cv2
import mediapipe as mp
import numpy as np
import csv
import datetime
import time


# Function to log exercise reps in CSV
def log_reps(exercise_name, count):
    filename = "exercise_log.csv"
    
    # Check if the file exists, if not, add headers
    try:
        with open(filename, 'x', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(["Date", "Time", "Exercise", "Reps"])
    except FileExistsError:
        pass  # File already exists, no need to write headers
    
    # Append new data
    with open(filename, 'a', newline='') as f:
        writer = csv.writer(f)
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d,%H:%M:%S")
        writer.writerow([timestamp, exercise_name, count])
    
    print(f"✅ Saved {count} reps of {exercise_name} to exercise_log.csv")

# to close the program much better 
def cleanup():
    cap.release()
    cv2.destroyAllWindows()
    exit()  # Immediate program termination


# Function to calculate the angle between three points (for joint angle calculations)
def calculate_angle(a, b, c):
    a = np.array(a)  # First point
    b = np.array(b)  # Midpoint (joint)
    c = np.array(c)  # End point
    
    # Calculate the angle using arctan2 function
    radians = np.arctan2(c[1] - b[1], c[0] - b[0]) - np.arctan2(a[1] - b[1], a[0] - b[0])
    angle = np.abs(radians * 180.0 / np.pi)
    
    # Adjust angle to stay within 0-180 degrees
    if angle > 180.0:
        angle = 360 - angle
    
    return angle

# initialize MediaPipe Pose model
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()
mp_drawing = mp.solutions.drawing_utils

# Initialize webcam
cap = cv2.VideoCapture(0)

# Get video frame width and height
frame_width = int(cap.get(3))
frame_height = int(cap.get(4))
fps = 20  # Adjust FPS as needed

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'MP4V')  # Use 'MP4V' for .mp4
out = cv2.VideoWriter("output.mp4", fourcc, fps, (frame_width, frame_height))
# open the webcam
cap = cv2.VideoCapture(0)

# def draw_concentration_bar(image, count):
#     bar_height = int(368 * (count % 12) / 10)  # Simple visualization based on reps
#     cv2.rectangle(image, (50, 450 - bar_height), (100, 450), (0, 255, 0), -1)
#     cv2.rectangle(image, (50, 50), (100, 450), (255, 255, 255), 2)

def select_exercise():
    print("Select an exercise:")
    print("1. Bicep Curl")
    print("2. Squat")
    print("3. Pushup")
    choice = input("Enter 1, 2, or 3: ")
    if choice == "1":
        bicep_curl()
    elif choice == "2":
        squat()
    elif choice == "3":
        pushup()
    else:
        print("Invalid choice. Please restart and enter a valid number.")

# to fix the issue in to much quick response
#  Updated Code with Delayed Feedback Switch
# Initialize smoothing variables

smoothed_fill_ratio = 0  # Store the smoothed value
alpha = 0.1  # Smoothing factor (Higher = Faster updates, Lower = Smoother)

def draw_concentration_bar(image, angle):
    """
    Draws a smoothed concentration bar based on squat depth.
    Uses Exponential Moving Average (EMA) for smooth transitions.
    """

    global smoothed_fill_ratio

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  # X position
    bar_y = 100  # Y position (top)
    bar_height = 200  # Max height
    bar_width = 30  # Width

    # Normalize angle to fill ratio (160° → 0%, 80° → 100%)
    target_fill_ratio = max(0, min(1, (160 - angle) / 80))  

    # Apply smoothing (Exponential Moving Average)
    # Adjust smoothing factor to make bar update faster
    alpha = 0.25  # Increased from 0.1 to 0.25 for a quicker response
    smoothed_fill_ratio = alpha * target_fill_ratio + (1 - alpha) * smoothed_fill_ratio

    # Compute filled height
    fill_height = int(smoothed_fill_ratio * bar_height)  

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not deep enough)
    elif 90 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent)
    else:
        color = (0, 255, 0)  # Green (Perfect squat)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion (smoothed)
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw labels
    cv2.putText(image, "Depth", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

# Global variable for bar smoothing
smoothed_fill_ratio = 0  

def draw_concentration_bar_biceps(image, angle):
    """Draws a smoothed concentration bar based on curl depth using EMA."""
    global smoothed_fill_ratio

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  
    bar_y = 100  
    bar_height = 200  
    bar_width = 30  

    # Normalize angle to fill ratio (150° → 0%, 30° → 100%)
    target_fill_ratio = max(0, min(1, (150 - angle) / 120))  

    # Apply smoothing (Exponential Moving Average)
    alpha = 0.25  # Smoothing factor
    smoothed_fill_ratio = alpha * target_fill_ratio + (1 - alpha) * smoothed_fill_ratio

    # Compute filled height
    fill_height = int(smoothed_fill_ratio * bar_height)

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not curled enough)
    elif 70 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent curl)
    else:
        color = (0, 255, 0)  # Green (Perfect curl)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion (smoothed)
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw labels
    cv2.putText(image, "Curl", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

def bicep_curl():
    """Tracks bicep curls and counts reps."""
    count = 0
    position = "down"

    with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break

            frame = cv2.flip(frame, 1)
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            results = pose.process(image)
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            try:
                if results.pose_landmarks:
                    landmarks = results.pose_landmarks.landmark
                    
                    # Get keypoints for right arm
                    r_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x, 
                                landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
                    r_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x, 
                             landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
                    r_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x, 
                             landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
                    
                    # add key pint for left also 
                    l_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                    l_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                    l_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,
                                  landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
                    #right angle 
                    r_angle = calculate_angle(r_shoulder, r_elbow, r_wrist)
                    #left angle
                    l_angle = calculate_angle(l_shoulder, l_elbow, l_wrist)

                    # DEBUG: Print values
                    print(f"Angle: {r_angle:.2f}, Position: {position}")

                    # Check bicep curl position logic 
                    #for both left and right hand
                    if r_angle > 140 and l_angle > 140:
                        position = "down"

                    if r_angle < 50 and l_angle < 50 and position == "down":
                        position = "up"
                        count += 1
                        print(f"✅ Curl Counted! Total: {count}")  

                    # Provide feedback
                    if r_angle > 140 and l_angle > 140:
                        feedback = "Extend your arm!"
                    elif r_angle < 50 :
                        feedback = "Full curl!"
                    else:
                        feedback = "Good form!"

                    # Display feedback
                    cv2.putText(image, f"Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                    cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

                    # Draw the concentration bar
                    draw_concentration_bar_biceps(image,  (r_angle + l_angle) / 2)

            except Exception as e:
                print(f"Error: {e}")

            # Draw landmarks
            if results.pose_landmarks:
                mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            cv2.imshow("Bicep Curl", image)
            if cv2.waitKey(10) & 0xFF == ord('q'):
                log_reps("Bicep curl",count)
                cleanup()
                break

    # cap.release()
    # cv2.destroyAllWindows()


def draw_concentration_bar_squat(image, angle):
    """
    Draws a concentration bar on the screen based on the squat depth (angle).
    - More filled when squatting lower.
    - Color changes based on depth.
    """

    h, w, _ = image.shape  # Get image dimensions

    # Define bar properties
    bar_x = 50  # X position of the bar
    bar_y = 100  # Y position (top)
    bar_height = 200  # Max height
    bar_width = 30  # Width

    # Normalize angle to fill the bar
    fill_ratio = max(0, min(1, (160 - angle) / 80))  # 160° (empty) → 80° (full)
    fill_height = int(fill_ratio * bar_height)  # Compute filled height

    # Choose color based on depth
    if angle > 140:
        color = (0, 0, 255)  # Red (Not deep enough)
    elif 90 <= angle <= 140:
        color = (0, 255, 255)  # Yellow (Decent)
    else:
        color = (0, 255, 0)  # Green (Perfect squat)

    # Draw empty bar (background)
    cv2.rectangle(image, (bar_x, bar_y), (bar_x + bar_width, bar_y + bar_height), (200, 200, 200), 2)

    # Draw filled portion
    cv2.rectangle(image, (bar_x, bar_y + (bar_height - fill_height)), (bar_x + bar_width, bar_y + bar_height), color, -1)

    # Draw text labels
    cv2.putText(image, "Depth", (bar_x - 10, bar_y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 255, 255), 1)
    cv2.putText(image, "Low", (bar_x + 40, bar_y + bar_height), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 1)
    cv2.putText(image, "High", (bar_x + 40, bar_y), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)

def squat():
    count = 0
    position = "up"
    shoulder_initial_y = None
    last_feedback = "Start your exercise"
    last_feedback_time = time.time()
    feedback_delay = 1.5

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark

                hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                       landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
                ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, 
                         landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
                            landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

                angle = calculate_angle(hip, knee, ankle)

                if position == "up" and shoulder_initial_y is None:
                    shoulder_initial_y = shoulder[1]

                print(f"Angle: {angle:.2f}, Position: {position}")

                if angle > 160:
                    position = "up"
                    shoulder_initial_y = shoulder[1]

                if angle < 90 and position == "up" and shoulder[1] > shoulder_initial_y + 0.02:
                    position = "down"
                    count += 1
                    print(f"✅ Squat Counted! Total: {count}")

                new_feedback = last_feedback
                if angle > 160:
                    new_feedback = "Stand tall!"
                elif angle < 90:
                    new_feedback = "Squat low!"
                else:
                    new_feedback = "Good depth!"

                if time.time() - last_feedback_time > feedback_delay:
                    last_feedback = new_feedback
                    last_feedback_time = time.time()

                # Draw smoothed concentration bar
                draw_concentration_bar_squat(image, angle)

                cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, last_feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Squat", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            log_reps("Squats",count)
            cleanup()
            break

    # cap.release()
    # cv2.destroyAllWindows()


## solved by adding the shouder points 
## wrong counting


def pushup():
    count = 0
    position = None
    while cap.isOpened():
        ret, frame = cap.read()
        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
                elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x, landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
                wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x, landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

                angle = calculate_angle(shoulder, elbow, wrist)

                if angle > 160:
                    position = "up"
                if angle < 90 and position == "up":
                    position = "down"
                    count += 1
                
                feedback = "Good form!" if 80 < angle < 160 else "Keep your core tight!"
                
                cv2.putText(image, f"Pushup Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        draw_concentration_bar(image, count)
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Pushup", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            log_reps("Pushup", count)
            cleanup()


select_exercise()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 58
#      55 mp_drawing = mp.solutions.drawing_utils
#      57 # Initialize webcam
# ---> 58 cap = cv2.VideoCapture(0)
#      60 # Get video frame width and height
#      61 frame_width = int(cap.get(3))
#
# KeyboardInterrupt:

# %%
import cv2
import mediapipe as mp
import numpy as np

# Initialize MediaPipe Pose
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose
pose = mp_pose.Pose()

# Initialize video capture
cap = cv2.VideoCapture(0)

# Function to calculate the angle between three points
def calculate_angle(a, b, c):
    a = np.array(a)  # Hip
    b = np.array(b)  # Knee
    c = np.array(c)  # Ankle

    # Vector calculations
    ba = a - b
    bc = c - b

    # Calculate angle
    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(cosine_angle)
    return np.degrees(angle)

# Squat detection function
def squat():
    count = 0
    position = "up"
    shoulder_initial_y = None  # Stores the reference height of the shoulder

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame = cv2.flip(frame, 1)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(image)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        try:
            if results.pose_landmarks:
                landmarks = results.pose_landmarks.landmark

                # Get keypoints
                hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x, 
                       landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
                knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x, 
                        landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
                ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x, 
                         landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
                shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x, 
                            landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

                angle = calculate_angle(hip, knee, ankle)

                # Initialize shoulder reference height when standing straight
                if position == "up" and shoulder_initial_y is None:
                    shoulder_initial_y = shoulder[1]

                # DEBUG: Print values
                print(f"Angle: {angle:.2f}, Shoulder Y: {shoulder[1]:.2f}, Initial Y: {shoulder_initial_y}, Position: {position}")

                # Check squat position logic
                if angle > 160:  # Standing position
                    position = "up"
                    shoulder_initial_y = shoulder[1]  # Reset shoulder reference when standing

                if angle < 90 and position == "up" and shoulder[1] > shoulder_initial_y + 0.02:  
                    # Ensure the shoulder moves down before counting the squat
                    position = "down"
                    count += 1
                    print(f"✅ Squat Counted! Total: {count}")  # Debugging line

                # Provide feedback
                if angle > 160:
                    feedback = "Stand tall!"
                elif angle < 90:
                    feedback = "Squat low!"
                else:
                    feedback = "Good depth!"

                # Display feedback
                cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
                cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        except Exception as e:
            print(f"Error: {e}")

        # Draw landmarks
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

        cv2.imshow("Squat", image)
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# Run the squat function
squat()
# Out:
# Angle: 177.67, Shoulder Y: 0.67, Initial Y: 0.6740996837615967, Position: up
# Angle: 177.64, Shoulder Y: 0.67, Initial Y: 0.6740996837615967, Position: up
# Angle: 177.63, Shoulder Y: 0.68, Initial Y: 0.67423415184021, Position: up
# Angle: 177.56, Shoulder Y: 0.68, Initial Y: 0.6789358854293823, Position: up
# Angle: 177.16, Shoulder Y: 0.68, Initial Y: 0.6808309555053711, Position: up
# Angle: 176.80, Shoulder Y: 0.68, Initial Y: 0.6822826862335205, Position: up
# Angle: 176.79, Shoulder Y: 0.68, Initial Y: 0.6843658089637756, Position: up
# Angle: 176.48, Shoulder Y: 0.68, Initial Y: 0.6845875978469849, Position: up
# Angle: 176.51, Shoulder Y: 0.68, Initial Y: 0.6763670444488525, Position: up
# Angle: 176.43, Shoulder Y: 0.68, Initial Y: 0.676646888256073, Position: up
# Angle: 176.54, Shoulder Y: 0.68, Initial Y: 0.6769821643829346, Position: up
# Angle: 176.26, Shoulder Y: 0.67, Initial Y: 0.6772587299346924, Position: up
# Angle: 176.16, Shoulder Y: 0.67, Initial Y: 0.6740161776542664, Position: up
# Angle: 176.39, Shoulder Y: 0.67, Initial Y: 0.6741257905960083, Position: up
# Angle: 176.59, Shoulder Y: 0.66, Initial Y: 0.6709896922111511, Position: up
# Angle: 177.21, Shoulder Y: 0.66, Initial Y: 0.6640540361404419, Position: up
# Angle: 177.93, Shoulder Y: 0.66, Initial Y: 0.6642886400222778, Position: up
# Angle: 177.97, Shoulder Y: 0.66, Initial Y: 0.6643540859222412, Position: up
# Angle: 177.99, Shoulder Y: 0.66, Initial Y: 0.6635964512825012, Position: up
# Angle: 177.92, Shoulder Y: 0.66, Initial Y: 0.6636084318161011, Position: up
# Angle: 178.06, Shoulder Y: 0.66, Initial Y: 0.6623013615608215, Position: up
# Angle: 178.23, Shoulder Y: 0.66, Initial Y: 0.6636883616447449, Position: up
# Angle: 178.56, Shoulder Y: 0.66, Initial Y: 0.6634277105331421, Position: up
# Angle: 178.59, Shoulder Y: 0.66, Initial Y: 0.6632707715034485, Position: up
# Angle: 178.72, Shoulder Y: 0.66, Initial Y: 0.6617138981819153, Position: up
# Angle: 178.82, Shoulder Y: 0.66, Initial Y: 0.660815417766571, Position: up
# Angle: 178.52, Shoulder Y: 0.66, Initial Y: 0.6594814658164978, Position: up
# Angle: 178.51, Shoulder Y: 0.65, Initial Y: 0.6572006344795227, Position: up
# Angle: 178.34, Shoulder Y: 0.65, Initial Y: 0.6543280482292175, Position: up
# Angle: 178.13, Shoulder Y: 0.65, Initial Y: 0.6528299450874329, Position: up
# Angle: 178.19, Shoulder Y: 0.65, Initial Y: 0.651498556137085, Position: up
# Angle: 178.17, Shoulder Y: 0.65, Initial Y: 0.6505034565925598, Position: up
# Angle: 178.13, Shoulder Y: 0.65, Initial Y: 0.6499931216239929, Position: up
# Angle: 178.16, Shoulder Y: 0.65, Initial Y: 0.6489810943603516, Position: up
# Angle: 178.32, Shoulder Y: 0.65, Initial Y: 0.6475626826286316, Position: up
# Angle: 178.35, Shoulder Y: 0.65, Initial Y: 0.647293210029602, Position: up
# Angle: 178.36, Shoulder Y: 0.65, Initial Y: 0.6476367712020874, Position: up
# Angle: 178.35, Shoulder Y: 0.65, Initial Y: 0.6480154395103455, Position: up
# Angle: 178.65, Shoulder Y: 0.65, Initial Y: 0.6482803821563721, Position: up
# Angle: 178.71, Shoulder Y: 0.65, Initial Y: 0.6480520963668823, Position: up
# Angle: 178.79, Shoulder Y: 0.65, Initial Y: 0.6481228470802307, Position: up
# Angle: 178.83, Shoulder Y: 0.65, Initial Y: 0.6479113101959229, Position: up
# Angle: 178.87, Shoulder Y: 0.65, Initial Y: 0.6472733616828918, Position: up
# Angle: 178.78, Shoulder Y: 0.65, Initial Y: 0.6473374962806702, Position: up
# Angle: 178.73, Shoulder Y: 0.64, Initial Y: 0.6457822918891907, Position: up
# Angle: 178.70, Shoulder Y: 0.63, Initial Y: 0.639055609703064, Position: up
# Angle: 178.79, Shoulder Y: 0.61, Initial Y: 0.6256629824638367, Position: up
# Angle: 179.39, Shoulder Y: 0.58, Initial Y: 0.6078136563301086, Position: up
# Angle: 179.49, Shoulder Y: 0.56, Initial Y: 0.58431476354599, Position: up
# Angle: 179.74, Shoulder Y: 0.53, Initial Y: 0.5596716403961182, Position: up
# Angle: 179.75, Shoulder Y: 0.49, Initial Y: 0.525888204574585, Position: up
# Angle: 179.82, Shoulder Y: 0.46, Initial Y: 0.4913071393966675, Position: up
# Angle: 179.08, Shoulder Y: 0.40, Initial Y: 0.45912882685661316, Position: up
# Angle: 177.73, Shoulder Y: 0.20, Initial Y: 0.40411001443862915, Position: up
# Angle: 157.77, Shoulder Y: 1.02, Initial Y: 0.1956007182598114, Position: up
# Angle: 177.04, Shoulder Y: 0.92, Initial Y: 0.1956007182598114, Position: up
# Angle: 179.93, Shoulder Y: 0.81, Initial Y: 0.9202482104301453, Position: up
# Angle: 179.20, Shoulder Y: 0.68, Initial Y: 0.8124114871025085, Position: up
# Angle: 179.45, Shoulder Y: 0.50, Initial Y: 0.6796697378158569, Position: up
# Angle: 179.25, Shoulder Y: 0.14, Initial Y: 0.502681314945221, Position: up
# Angle: 179.26, Shoulder Y: 0.20, Initial Y: 0.14462637901306152, Position: up
# Angle: 178.70, Shoulder Y: 0.72, Initial Y: 0.1968180388212204, Position: up
# Angle: 170.30, Shoulder Y: 0.65, Initial Y: 0.7173435091972351, Position: up
# Angle: 132.07, Shoulder Y: 0.56, Initial Y: 0.6545423865318298, Position: up
# Angle: 128.20, Shoulder Y: 0.60, Initial Y: 0.6545423865318298, Position: up
# Angle: 121.53, Shoulder Y: 0.61, Initial Y: 0.6545423865318298, Position: up
# Angle: 154.94, Shoulder Y: 0.59, Initial Y: 0.6545423865318298, Position: up
# Angle: 160.06, Shoulder Y: 0.58, Initial Y: 0.6545423865318298, Position: up
# Angle: 170.04, Shoulder Y: 0.56, Initial Y: 0.5849950313568115, Position: up
# Angle: 168.54, Shoulder Y: 0.58, Initial Y: 0.5647907257080078, Position: up
# Angle: 168.21, Shoulder Y: 0.27, Initial Y: 0.5781710743904114, Position: up
# Angle: 179.77, Shoulder Y: 0.24, Initial Y: 0.27248483896255493, Position: up
# Angle: 169.46, Shoulder Y: 0.21, Initial Y: 0.2362288385629654, Position: up
# Angle: 82.37, Shoulder Y: 0.22, Initial Y: 0.21460893750190735, Position: up
# Angle: 83.66, Shoulder Y: 0.22, Initial Y: 0.21460893750190735, Position: up
# Angle: 82.76, Shoulder Y: 0.22, Initial Y: 0.21460893750190735, Position: up
# Angle: 120.41, Shoulder Y: 0.22, Initial Y: 0.21460893750190735, Position: up
# Angle: 142.43, Shoulder Y: 0.23, Initial Y: 0.21460893750190735, Position: up
# Angle: 132.63, Shoulder Y: 0.23, Initial Y: 0.21460893750190735, Position: up
# Angle: 146.24, Shoulder Y: 0.23, Initial Y: 0.21460893750190735, Position: up
# Angle: 155.91, Shoulder Y: 0.23, Initial Y: 0.21460893750190735, Position: up
# Angle: 169.29, Shoulder Y: 0.23, Initial Y: 0.21460893750190735, Position: up
# Angle: 172.27, Shoulder Y: 0.23, Initial Y: 0.22887207567691803, Position: up
# Angle: 168.48, Shoulder Y: 0.25, Initial Y: 0.22905074059963226, Position: up
# Angle: 161.04, Shoulder Y: 0.25, Initial Y: 0.24508036673069, Position: up
# Angle: 167.47, Shoulder Y: 0.27, Initial Y: 0.25266215205192566, Position: up
# Angle: 169.69, Shoulder Y: 0.27, Initial Y: 0.26682963967323303, Position: up
# Angle: 169.15, Shoulder Y: 0.28, Initial Y: 0.2725253403186798, Position: up
# Angle: 165.76, Shoulder Y: 0.28, Initial Y: 0.275155633687973, Position: up
# Angle: 164.72, Shoulder Y: 0.28, Initial Y: 0.2806920111179352, Position: up
# Angle: 165.37, Shoulder Y: 0.28, Initial Y: 0.28182175755500793, Position: up
# Angle: 168.10, Shoulder Y: 0.29, Initial Y: 0.28348055481910706, Position: up
# Angle: 167.52, Shoulder Y: 0.29, Initial Y: 0.2863613963127136, Position: up
# Angle: 166.56, Shoulder Y: 0.29, Initial Y: 0.286601185798645, Position: up
# Angle: 174.23, Shoulder Y: 0.29, Initial Y: 0.28969818353652954, Position: up
# Angle: 173.82, Shoulder Y: 0.29, Initial Y: 0.29217755794525146, Position: up
# Angle: 174.00, Shoulder Y: 0.29, Initial Y: 0.2926488518714905, Position: up
# Angle: 173.55, Shoulder Y: 0.29, Initial Y: 0.2930217981338501, Position: up
# Angle: 171.65, Shoulder Y: 0.29, Initial Y: 0.29337120056152344, Position: up
# Angle: 170.77, Shoulder Y: 0.30, Initial Y: 0.2931126058101654, Position: up
# Angle: 169.25, Shoulder Y: 0.30, Initial Y: 0.2952413856983185, Position: up
# Angle: 169.22, Shoulder Y: 0.30, Initial Y: 0.2982212007045746, Position: up
# Angle: 170.79, Shoulder Y: 0.31, Initial Y: 0.30280065536499023, Position: up
# Angle: 171.30, Shoulder Y: 0.31, Initial Y: 0.3095856308937073, Position: up
# Angle: 173.55, Shoulder Y: 0.31, Initial Y: 0.31223928928375244, Position: up
# Angle: 174.31, Shoulder Y: 0.31, Initial Y: 0.31205129623413086, Position: up
# Angle: 175.90, Shoulder Y: 0.31, Initial Y: 0.31143346428871155, Position: up
# Angle: 177.35, Shoulder Y: 0.31, Initial Y: 0.3112565577030182, Position: up
# Angle: 179.68, Shoulder Y: 0.31, Initial Y: 0.31098464131355286, Position: up
# Angle: 179.03, Shoulder Y: 0.31, Initial Y: 0.3107692003250122, Position: up
# Angle: 178.58, Shoulder Y: 0.31, Initial Y: 0.31054651737213135, Position: up
# Angle: 178.47, Shoulder Y: 0.31, Initial Y: 0.3108994662761688, Position: up
# Angle: 178.33, Shoulder Y: 0.31, Initial Y: 0.31077468395233154, Position: up
# Angle: 179.21, Shoulder Y: 0.31, Initial Y: 0.3104661703109741, Position: up
# Angle: 178.59, Shoulder Y: 0.31, Initial Y: 0.30950063467025757, Position: up
# Angle: 177.58, Shoulder Y: 0.30, Initial Y: 0.3053678274154663, Position: up
# Angle: 176.67, Shoulder Y: 0.30, Initial Y: 0.3035160005092621, Position: up
# Angle: 175.12, Shoulder Y: 0.30, Initial Y: 0.3024791479110718, Position: up
# Angle: 173.91, Shoulder Y: 0.30, Initial Y: 0.30180466175079346, Position: up
# Angle: 179.01, Shoulder Y: 0.30, Initial Y: 0.30179062485694885, Position: up
# Angle: 179.73, Shoulder Y: 0.30, Initial Y: 0.30163317918777466, Position: up
# Angle: 177.96, Shoulder Y: 0.30, Initial Y: 0.30115875601768494, Position: up
# Angle: 177.20, Shoulder Y: 0.30, Initial Y: 0.30202534794807434, Position: up
# Angle: 177.33, Shoulder Y: 0.30, Initial Y: 0.30228880047798157, Position: up
# Angle: 178.39, Shoulder Y: 0.30, Initial Y: 0.3021582067012787, Position: up
# Angle: 178.37, Shoulder Y: 0.29, Initial Y: 0.2985556423664093, Position: up
# Angle: 177.83, Shoulder Y: 0.28, Initial Y: 0.2914297878742218, Position: up
# Angle: 178.12, Shoulder Y: 0.27, Initial Y: 0.2778770327568054, Position: up
# Angle: 177.74, Shoulder Y: 0.25, Initial Y: 0.2740160822868347, Position: up
# Angle: 178.29, Shoulder Y: 0.24, Initial Y: 0.25303348898887634, Position: up
# Angle: 179.66, Shoulder Y: 0.23, Initial Y: 0.2413882613182068, Position: up
# Angle: 178.29, Shoulder Y: 0.23, Initial Y: 0.23413555324077606, Position: up
# Angle: 177.57, Shoulder Y: 0.23, Initial Y: 0.23255063593387604, Position: up
# Angle: 178.69, Shoulder Y: 0.22, Initial Y: 0.22954502701759338, Position: up
# Angle: 178.94, Shoulder Y: 0.22, Initial Y: 0.2227657586336136, Position: up
# Angle: 179.28, Shoulder Y: 0.22, Initial Y: 0.2189646065235138, Position: up
# Angle: 179.35, Shoulder Y: 0.21, Initial Y: 0.21725665032863617, Position: up
# Angle: 179.35, Shoulder Y: 0.21, Initial Y: 0.21389268338680267, Position: up
# Angle: 178.42, Shoulder Y: 0.19, Initial Y: 0.20836390554904938, Position: up
# Angle: 178.73, Shoulder Y: 0.17, Initial Y: 0.19332733750343323, Position: up
# Angle: 178.28, Shoulder Y: 0.14, Initial Y: 0.17045529186725616, Position: up
# Angle: 178.11, Shoulder Y: 0.12, Initial Y: 0.1426873356103897, Position: up
# Angle: 179.36, Shoulder Y: 0.08, Initial Y: 0.12124314904212952, Position: up
# Angle: 178.48, Shoulder Y: 0.10, Initial Y: 0.07800301164388657, Position: up
# Angle: 178.82, Shoulder Y: 0.12, Initial Y: 0.10428306460380554, Position: up
# Angle: 178.49, Shoulder Y: 0.50, Initial Y: 0.11787906289100647, Position: up
# Angle: 165.24, Shoulder Y: 0.46, Initial Y: 0.5005741119384766, Position: up
# Angle: 178.58, Shoulder Y: 0.24, Initial Y: 0.4591354727745056, Position: up
# Angle: 177.65, Shoulder Y: 0.18, Initial Y: 0.24127313494682312, Position: up
# Angle: 177.88, Shoulder Y: 0.19, Initial Y: 0.17909693717956543, Position: up
# Angle: 179.90, Shoulder Y: 0.13, Initial Y: 0.18786083161830902, Position: up
# Angle: 168.39, Shoulder Y: 0.17, Initial Y: 0.1341007500886917, Position: up
# Angle: 174.51, Shoulder Y: 0.18, Initial Y: 0.1676522046327591, Position: up
# Angle: 166.08, Shoulder Y: 0.18, Initial Y: 0.17900091409683228, Position: up
# Angle: 167.49, Shoulder Y: 0.35, Initial Y: 0.18084260821342468, Position: up
# Angle: 103.90, Shoulder Y: 0.36, Initial Y: 0.34616535902023315, Position: up
# Angle: 140.87, Shoulder Y: 0.36, Initial Y: 0.34616535902023315, Position: up
# Angle: 141.24, Shoulder Y: 0.39, Initial Y: 0.34616535902023315, Position: up
# Angle: 77.47, Shoulder Y: 0.52, Initial Y: 0.34616535902023315, Position: up
# ✅ Squat Counted! Total: 1
# Angle: 47.45, Shoulder Y: 0.47, Initial Y: 0.34616535902023315, Position: down
# Angle: 38.40, Shoulder Y: 0.54, Initial Y: 0.34616535902023315, Position: down
# Angle: 46.64, Shoulder Y: 0.55, Initial Y: 0.34616535902023315, Position: down
# Angle: 174.54, Shoulder Y: 0.52, Initial Y: 0.34616535902023315, Position: down
# Angle: 162.55, Shoulder Y: 0.52, Initial Y: 0.5164463520050049, Position: up
# Angle: 170.51, Shoulder Y: 0.51, Initial Y: 0.5247114300727844, Position: up
# Angle: 179.98, Shoulder Y: 0.50, Initial Y: 0.5071575045585632, Position: up
# Angle: 170.18, Shoulder Y: 0.50, Initial Y: 0.49947258830070496, Position: up
# Angle: 177.07, Shoulder Y: 0.49, Initial Y: 0.4974960684776306, Position: up
# Angle: 173.30, Shoulder Y: 0.49, Initial Y: 0.4939308762550354, Position: up
# Angle: 171.67, Shoulder Y: 0.48, Initial Y: 0.48812392354011536, Position: up
# Angle: 172.19, Shoulder Y: 0.49, Initial Y: 0.47793734073638916, Position: up
# Angle: 176.56, Shoulder Y: 0.48, Initial Y: 0.4891984760761261, Position: up
# Angle: 168.09, Shoulder Y: 0.48, Initial Y: 0.4781002998352051, Position: up
# Angle: 165.91, Shoulder Y: 0.46, Initial Y: 0.480465829372406, Position: up
# Angle: 173.02, Shoulder Y: 0.44, Initial Y: 0.4641539454460144, Position: up
# Angle: 171.19, Shoulder Y: 0.45, Initial Y: 0.44334667921066284, Position: up
# Angle: 173.07, Shoulder Y: 0.45, Initial Y: 0.4465186297893524, Position: up
# Angle: 178.49, Shoulder Y: 0.44, Initial Y: 0.4502967298030853, Position: up
# Angle: 179.58, Shoulder Y: 0.41, Initial Y: 0.44307810068130493, Position: up
# Angle: 173.14, Shoulder Y: 0.42, Initial Y: 0.41189315915107727, Position: up
# Angle: 179.01, Shoulder Y: 0.43, Initial Y: 0.4206027388572693, Position: up
# Angle: 174.46, Shoulder Y: 0.43, Initial Y: 0.4301644563674927, Position: up
# Angle: 176.44, Shoulder Y: 0.44, Initial Y: 0.4322359263896942, Position: up
# Angle: 176.83, Shoulder Y: 0.44, Initial Y: 0.4446672797203064, Position: up
# Angle: 171.40, Shoulder Y: 0.44, Initial Y: 0.44482719898223877, Position: up
# Angle: 172.64, Shoulder Y: 0.45, Initial Y: 0.4439716041088104, Position: up
# Angle: 171.27, Shoulder Y: 0.46, Initial Y: 0.44644686579704285, Position: up
# Angle: 168.42, Shoulder Y: 0.47, Initial Y: 0.4561917185783386, Position: up
# Angle: 162.94, Shoulder Y: 0.48, Initial Y: 0.47044631838798523, Position: up
# Angle: 166.67, Shoulder Y: 0.49, Initial Y: 0.4769570231437683, Position: up
# Angle: 158.80, Shoulder Y: 0.52, Initial Y: 0.4903983175754547, Position: up
# Angle: 15.16, Shoulder Y: 0.52, Initial Y: 0.4903983175754547, Position: up
# ✅ Squat Counted! Total: 2
# Angle: 166.51, Shoulder Y: 0.50, Initial Y: 0.4903983175754547, Position: down
# Angle: 17.60, Shoulder Y: 0.50, Initial Y: 0.50493323802948, Position: up
# Angle: 23.30, Shoulder Y: 0.53, Initial Y: 0.50493323802948, Position: up
# ✅ Squat Counted! Total: 3
# Angle: 18.99, Shoulder Y: 0.54, Initial Y: 0.50493323802948, Position: down
# Angle: 66.01, Shoulder Y: 0.56, Initial Y: 0.50493323802948, Position: down
# Angle: 21.81, Shoulder Y: 0.55, Initial Y: 0.50493323802948, Position: down
# Angle: 20.48, Shoulder Y: 0.54, Initial Y: 0.50493323802948, Position: down
# Angle: 9.71, Shoulder Y: 0.54, Initial Y: 0.50493323802948, Position: down
# Angle: 20.74, Shoulder Y: 0.54, Initial Y: 0.50493323802948, Position: down
# Angle: 9.09, Shoulder Y: 0.53, Initial Y: 0.50493323802948, Position: down
# Angle: 164.57, Shoulder Y: 0.53, Initial Y: 0.50493323802948, Position: down
# Angle: 174.21, Shoulder Y: 0.53, Initial Y: 0.5331314206123352, Position: up
# Angle: 179.66, Shoulder Y: 0.52, Initial Y: 0.5315729379653931, Position: up
# Angle: 174.08, Shoulder Y: 0.52, Initial Y: 0.5193453431129456, Position: up
# Angle: 31.10, Shoulder Y: 0.49, Initial Y: 0.5193308591842651, Position: up
# Angle: 156.05, Shoulder Y: 0.49, Initial Y: 0.5193308591842651, Position: up
# Angle: 175.41, Shoulder Y: 0.49, Initial Y: 0.5193308591842651, Position: up
# Angle: 177.34, Shoulder Y: 0.49, Initial Y: 0.4865628778934479, Position: up
# Angle: 172.94, Shoulder Y: 0.49, Initial Y: 0.4887683689594269, Position: up
# Angle: 56.96, Shoulder Y: 0.53, Initial Y: 0.49473148584365845, Position: up
# ✅ Squat Counted! Total: 4
# Angle: 153.26, Shoulder Y: 0.43, Initial Y: 0.49473148584365845, Position: down
# Angle: 159.54, Shoulder Y: 0.39, Initial Y: 0.49473148584365845, Position: down
# Angle: 175.30, Shoulder Y: 0.27, Initial Y: 0.49473148584365845, Position: down
# Angle: 174.93, Shoulder Y: 0.27, Initial Y: 0.2700424790382385, Position: up
# Angle: 174.99, Shoulder Y: 0.27, Initial Y: 0.27024251222610474, Position: up
# Angle: 175.09, Shoulder Y: 0.27, Initial Y: 0.26990601420402527, Position: up
# Angle: 175.08, Shoulder Y: 0.27, Initial Y: 0.26902133226394653, Position: up
# Angle: 175.19, Shoulder Y: 0.27, Initial Y: 0.2685776650905609, Position: up
# Angle: 175.46, Shoulder Y: 0.27, Initial Y: 0.26864925026893616, Position: up
# Angle: 176.14, Shoulder Y: 0.27, Initial Y: 0.26948124170303345, Position: up
# Angle: 178.94, Shoulder Y: 0.27, Initial Y: 0.27091753482818604, Position: up
# Angle: 179.80, Shoulder Y: 0.27, Initial Y: 0.27107003331184387, Position: up
# Angle: 179.01, Shoulder Y: 0.27, Initial Y: 0.27107566595077515, Position: up
# Angle: 179.06, Shoulder Y: 0.27, Initial Y: 0.27219289541244507, Position: up
# Angle: 178.80, Shoulder Y: 0.27, Initial Y: 0.2721828520298004, Position: up
# Angle: 178.05, Shoulder Y: 0.27, Initial Y: 0.27195245027542114, Position: up
# Angle: 178.14, Shoulder Y: 0.27, Initial Y: 0.27141812443733215, Position: up
# Angle: 177.93, Shoulder Y: 0.27, Initial Y: 0.26995325088500977, Position: up
# Angle: 177.70, Shoulder Y: 0.27, Initial Y: 0.2683770954608917, Position: up
# Angle: 177.20, Shoulder Y: 0.27, Initial Y: 0.26767534017562866, Position: up
# Angle: 177.10, Shoulder Y: 0.27, Initial Y: 0.26692771911621094, Position: up
# Angle: 177.08, Shoulder Y: 0.27, Initial Y: 0.26643094420433044, Position: up
# Angle: 176.90, Shoulder Y: 0.27, Initial Y: 0.26635050773620605, Position: up
# Angle: 175.23, Shoulder Y: 0.27, Initial Y: 0.26638925075531006, Position: up
# Angle: 174.04, Shoulder Y: 0.27, Initial Y: 0.26623380184173584, Position: up
# Angle: 174.43, Shoulder Y: 0.27, Initial Y: 0.26635196805000305, Position: up
# Angle: 173.89, Shoulder Y: 0.27, Initial Y: 0.2663682997226715, Position: up
# Angle: 173.25, Shoulder Y: 0.27, Initial Y: 0.2663750946521759, Position: up
# Angle: 174.07, Shoulder Y: 0.27, Initial Y: 0.2669290006160736, Position: up
# Angle: 174.45, Shoulder Y: 0.27, Initial Y: 0.26732122898101807, Position: up
# Angle: 174.81, Shoulder Y: 0.27, Initial Y: 0.2682798504829407, Position: up
# Angle: 175.35, Shoulder Y: 0.27, Initial Y: 0.26938897371292114, Position: up
# Angle: 175.52, Shoulder Y: 0.27, Initial Y: 0.27044546604156494, Position: up
# Angle: 176.39, Shoulder Y: 0.27, Initial Y: 0.2728997766971588, Position: up
# Angle: 177.31, Shoulder Y: 0.27, Initial Y: 0.27352699637413025, Position: up
# Angle: 177.90, Shoulder Y: 0.27, Initial Y: 0.2735034227371216, Position: up
# Angle: 178.55, Shoulder Y: 0.27, Initial Y: 0.2734285295009613, Position: up
# Angle: 178.83, Shoulder Y: 0.27, Initial Y: 0.27339643239974976, Position: up
# Angle: 179.07, Shoulder Y: 0.27, Initial Y: 0.27289867401123047, Position: up
# Angle: 179.58, Shoulder Y: 0.27, Initial Y: 0.27287447452545166, Position: up
# Angle: 179.93, Shoulder Y: 0.27, Initial Y: 0.27297908067703247, Position: up
# Angle: 179.90, Shoulder Y: 0.27, Initial Y: 0.27338287234306335, Position: up
# Angle: 179.99, Shoulder Y: 0.27, Initial Y: 0.2743728756904602, Position: up
# Angle: 179.78, Shoulder Y: 0.27, Initial Y: 0.2749633491039276, Position: up
# Angle: 179.97, Shoulder Y: 0.28, Initial Y: 0.2749684453010559, Position: up
# Angle: 179.82, Shoulder Y: 0.28, Initial Y: 0.2753632962703705, Position: up
# Angle: 179.55, Shoulder Y: 0.28, Initial Y: 0.2753578722476959, Position: up
# Angle: 178.99, Shoulder Y: 0.27, Initial Y: 0.2751363515853882, Position: up
# Angle: 178.69, Shoulder Y: 0.27, Initial Y: 0.2748708724975586, Position: up
# Angle: 178.66, Shoulder Y: 0.27, Initial Y: 0.2744593620300293, Position: up
# Angle: 178.61, Shoulder Y: 0.27, Initial Y: 0.27444228529930115, Position: up
# Angle: 179.98, Shoulder Y: 0.27, Initial Y: 0.274423211812973, Position: up
# Angle: 179.23, Shoulder Y: 0.27, Initial Y: 0.27329936623573303, Position: up
# Angle: 178.05, Shoulder Y: 0.27, Initial Y: 0.272550493478775, Position: up
# Angle: 177.14, Shoulder Y: 0.27, Initial Y: 0.26993611454963684, Position: up
# Angle: 175.01, Shoulder Y: 0.27, Initial Y: 0.2672877609729767, Position: up
# Angle: 173.35, Shoulder Y: 0.26, Initial Y: 0.2654596269130707, Position: up
# Angle: 172.58, Shoulder Y: 0.26, Initial Y: 0.2636156976222992, Position: up
# Angle: 172.60, Shoulder Y: 0.26, Initial Y: 0.26131492853164673, Position: up
# Angle: 172.76, Shoulder Y: 0.26, Initial Y: 0.25861281156539917, Position: up
# Angle: 173.72, Shoulder Y: 0.26, Initial Y: 0.2569812536239624, Position: up
# Angle: 175.60, Shoulder Y: 0.26, Initial Y: 0.2559657096862793, Position: up
# Angle: 177.94, Shoulder Y: 0.25, Initial Y: 0.2555311620235443, Position: up
# Angle: 179.12, Shoulder Y: 0.25, Initial Y: 0.25471487641334534, Position: up
# Angle: 179.37, Shoulder Y: 0.25, Initial Y: 0.25385481119155884, Position: up
# Angle: 179.27, Shoulder Y: 0.25, Initial Y: 0.2529853582382202, Position: up
# Angle: 179.23, Shoulder Y: 0.25, Initial Y: 0.25140851736068726, Position: up
# Angle: 179.35, Shoulder Y: 0.25, Initial Y: 0.25087669491767883, Position: up
# Angle: 179.96, Shoulder Y: 0.25, Initial Y: 0.2508724331855774, Position: up
# Angle: 179.04, Shoulder Y: 0.25, Initial Y: 0.25215256214141846, Position: up
# Angle: 178.90, Shoulder Y: 0.25, Initial Y: 0.2522898316383362, Position: up
# Angle: 178.96, Shoulder Y: 0.25, Initial Y: 0.2521600127220154, Position: up
# Angle: 179.23, Shoulder Y: 0.26, Initial Y: 0.2534138262271881, Position: up
# Angle: 179.86, Shoulder Y: 0.26, Initial Y: 0.25563350319862366, Position: up
# Angle: 179.85, Shoulder Y: 0.26, Initial Y: 0.2587886452674866, Position: up
# Angle: 179.51, Shoulder Y: 0.26, Initial Y: 0.25922319293022156, Position: up
# Angle: 179.32, Shoulder Y: 0.26, Initial Y: 0.25916025042533875, Position: up
# Angle: 179.22, Shoulder Y: 0.26, Initial Y: 0.25993865728378296, Position: up
# Angle: 178.77, Shoulder Y: 0.26, Initial Y: 0.25978386402130127, Position: up
# Angle: 178.25, Shoulder Y: 0.26, Initial Y: 0.25865334272384644, Position: up
# Angle: 177.96, Shoulder Y: 0.26, Initial Y: 0.2579009532928467, Position: up
# Angle: 177.93, Shoulder Y: 0.26, Initial Y: 0.25697076320648193, Position: up
# Angle: 177.94, Shoulder Y: 0.26, Initial Y: 0.25694936513900757, Position: up
# Angle: 177.84, Shoulder Y: 0.26, Initial Y: 0.2568579912185669, Position: up
# Angle: 177.81, Shoulder Y: 0.26, Initial Y: 0.2569226622581482, Position: up
# Angle: 177.77, Shoulder Y: 0.26, Initial Y: 0.2569367587566376, Position: up
# Angle: 177.65, Shoulder Y: 0.26, Initial Y: 0.25684654712677, Position: up
# Angle: 177.44, Shoulder Y: 0.26, Initial Y: 0.25671645998954773, Position: up
# Angle: 177.27, Shoulder Y: 0.26, Initial Y: 0.2566915452480316, Position: up
# Angle: 177.09, Shoulder Y: 0.26, Initial Y: 0.2566777169704437, Position: up
# Angle: 176.73, Shoulder Y: 0.26, Initial Y: 0.25656235218048096, Position: up
# Angle: 176.48, Shoulder Y: 0.26, Initial Y: 0.2564307153224945, Position: up
# Angle: 176.24, Shoulder Y: 0.26, Initial Y: 0.2560873329639435, Position: up
# Angle: 176.05, Shoulder Y: 0.26, Initial Y: 0.2557544708251953, Position: up
# Angle: 175.81, Shoulder Y: 0.25, Initial Y: 0.2553267180919647, Position: up
# Angle: 175.69, Shoulder Y: 0.25, Initial Y: 0.254961222410202, Position: up
# Angle: 175.63, Shoulder Y: 0.25, Initial Y: 0.2540864050388336, Position: up
# Angle: 175.24, Shoulder Y: 0.25, Initial Y: 0.2537725567817688, Position: up
# Angle: 174.80, Shoulder Y: 0.25, Initial Y: 0.2530025243759155, Position: up
# Angle: 174.68, Shoulder Y: 0.25, Initial Y: 0.25234949588775635, Position: up
# Angle: 173.43, Shoulder Y: 0.25, Initial Y: 0.2518986463546753, Position: up
# Angle: 172.37, Shoulder Y: 0.25, Initial Y: 0.25129398703575134, Position: up
# Angle: 172.72, Shoulder Y: 0.25, Initial Y: 0.2510354816913605, Position: up
# Angle: 174.25, Shoulder Y: 0.25, Initial Y: 0.2515508234500885, Position: up
# Angle: 174.18, Shoulder Y: 0.25, Initial Y: 0.25278642773628235, Position: up
# Angle: 174.56, Shoulder Y: 0.26, Initial Y: 0.2542085349559784, Position: up
# Angle: 174.91, Shoulder Y: 0.26, Initial Y: 0.2552134394645691, Position: up
# Angle: 175.09, Shoulder Y: 0.26, Initial Y: 0.255811482667923, Position: up
# Angle: 175.43, Shoulder Y: 0.26, Initial Y: 0.2568325698375702, Position: up
# Angle: 175.73, Shoulder Y: 0.26, Initial Y: 0.25784891843795776, Position: up
# Angle: 175.69, Shoulder Y: 0.26, Initial Y: 0.2609177529811859, Position: up
# Angle: 175.49, Shoulder Y: 0.26, Initial Y: 0.26217514276504517, Position: up
# Angle: 175.39, Shoulder Y: 0.26, Initial Y: 0.2635056674480438, Position: up
# Angle: 175.38, Shoulder Y: 0.26, Initial Y: 0.2649301588535309, Position: up
# Angle: 175.44, Shoulder Y: 0.26, Initial Y: 0.2648424208164215, Position: up
# Angle: 175.39, Shoulder Y: 0.26, Initial Y: 0.26462531089782715, Position: up
# Angle: 175.39, Shoulder Y: 0.26, Initial Y: 0.2645051181316376, Position: up
# Angle: 175.60, Shoulder Y: 0.26, Initial Y: 0.2643507122993469, Position: up
# Angle: 175.95, Shoulder Y: 0.26, Initial Y: 0.2637510597705841, Position: up
# Angle: 176.37, Shoulder Y: 0.26, Initial Y: 0.2629506289958954, Position: up
# Angle: 176.73, Shoulder Y: 0.26, Initial Y: 0.26134970784187317, Position: up
# Angle: 177.06, Shoulder Y: 0.26, Initial Y: 0.25954678654670715, Position: up
# Angle: 177.39, Shoulder Y: 0.26, Initial Y: 0.25850918889045715, Position: up
# Angle: 177.33, Shoulder Y: 0.26, Initial Y: 0.2582055926322937, Position: up
# Angle: 177.36, Shoulder Y: 0.26, Initial Y: 0.2580813467502594, Position: up
# Angle: 177.32, Shoulder Y: 0.26, Initial Y: 0.25769951939582825, Position: up
# Angle: 177.57, Shoulder Y: 0.26, Initial Y: 0.25770244002342224, Position: up
# Angle: 177.01, Shoulder Y: 0.26, Initial Y: 0.25767117738723755, Position: up
# Angle: 177.00, Shoulder Y: 0.26, Initial Y: 0.25690770149230957, Position: up
# Angle: 176.95, Shoulder Y: 0.26, Initial Y: 0.25660598278045654, Position: up
# Angle: 176.96, Shoulder Y: 0.26, Initial Y: 0.25656452775001526, Position: up
# Angle: 177.12, Shoulder Y: 0.26, Initial Y: 0.25657060742378235, Position: up
# Angle: 177.21, Shoulder Y: 0.26, Initial Y: 0.2563004195690155, Position: up
# Angle: 177.43, Shoulder Y: 0.25, Initial Y: 0.2554202973842621, Position: up
# Angle: 177.51, Shoulder Y: 0.25, Initial Y: 0.2540568709373474, Position: up
# Angle: 177.59, Shoulder Y: 0.25, Initial Y: 0.2540740370750427, Position: up
# Angle: 177.61, Shoulder Y: 0.25, Initial Y: 0.2535957396030426, Position: up
# Angle: 177.71, Shoulder Y: 0.25, Initial Y: 0.25361332297325134, Position: up
# Angle: 178.25, Shoulder Y: 0.26, Initial Y: 0.25424593687057495, Position: up
# Angle: 178.56, Shoulder Y: 0.26, Initial Y: 0.2557190954685211, Position: up
# Angle: 178.86, Shoulder Y: 0.26, Initial Y: 0.25764939188957214, Position: up
# Angle: 179.09, Shoulder Y: 0.26, Initial Y: 0.2589249014854431, Position: up
# Angle: 179.73, Shoulder Y: 0.26, Initial Y: 0.25921517610549927, Position: up
# Angle: 179.87, Shoulder Y: 0.26, Initial Y: 0.25936368107795715, Position: up
# Angle: 179.80, Shoulder Y: 0.26, Initial Y: 0.2593494653701782, Position: up
# Angle: 179.77, Shoulder Y: 0.26, Initial Y: 0.2587928771972656, Position: up
# Angle: 180.00, Shoulder Y: 0.25, Initial Y: 0.25797080993652344, Position: up
# Angle: 179.96, Shoulder Y: 0.25, Initial Y: 0.2530403733253479, Position: up
# Angle: 179.96, Shoulder Y: 0.25, Initial Y: 0.25076431035995483, Position: up
# Angle: 179.90, Shoulder Y: 0.25, Initial Y: 0.24870683252811432, Position: up
# Angle: 179.85, Shoulder Y: 0.25, Initial Y: 0.24817150831222534, Position: up
# Angle: 179.84, Shoulder Y: 0.25, Initial Y: 0.24802805483341217, Position: up
# Angle: 179.84, Shoulder Y: 0.25, Initial Y: 0.24800615012645721, Position: up
# Angle: 179.83, Shoulder Y: 0.25, Initial Y: 0.24781107902526855, Position: up
# Angle: 179.81, Shoulder Y: 0.25, Initial Y: 0.24751101434230804, Position: up
# Angle: 179.74, Shoulder Y: 0.25, Initial Y: 0.2474648356437683, Position: up
# Angle: 179.69, Shoulder Y: 0.25, Initial Y: 0.2474575787782669, Position: up
# Angle: 179.70, Shoulder Y: 0.25, Initial Y: 0.24737539887428284, Position: up
# Angle: 179.72, Shoulder Y: 0.25, Initial Y: 0.24741695821285248, Position: up
# Angle: 179.98, Shoulder Y: 0.25, Initial Y: 0.24743078649044037, Position: up
# Angle: 179.90, Shoulder Y: 0.25, Initial Y: 0.2495531439781189, Position: up
# Angle: 179.84, Shoulder Y: 0.25, Initial Y: 0.25147953629493713, Position: up
# Angle: 179.45, Shoulder Y: 0.25, Initial Y: 0.25306305289268494, Position: up
# Angle: 179.11, Shoulder Y: 0.25, Initial Y: 0.25415194034576416, Position: up
# Angle: 179.03, Shoulder Y: 0.26, Initial Y: 0.2548580467700958, Position: up
# Angle: 179.03, Shoulder Y: 0.26, Initial Y: 0.25542351603507996, Position: up
# Angle: 179.02, Shoulder Y: 0.26, Initial Y: 0.2563192844390869, Position: up
# Angle: 179.14, Shoulder Y: 0.26, Initial Y: 0.25659555196762085, Position: up
# Angle: 179.09, Shoulder Y: 0.26, Initial Y: 0.256559282541275, Position: up
# Angle: 179.20, Shoulder Y: 0.26, Initial Y: 0.2565372586250305, Position: up
# Angle: 179.25, Shoulder Y: 0.26, Initial Y: 0.2564922869205475, Position: up
# Angle: 179.35, Shoulder Y: 0.26, Initial Y: 0.25586313009262085, Position: up
# Angle: 179.44, Shoulder Y: 0.25, Initial Y: 0.2553655207157135, Position: up
# Angle: 179.60, Shoulder Y: 0.25, Initial Y: 0.2543480098247528, Position: up
# Angle: 179.65, Shoulder Y: 0.25, Initial Y: 0.2533508241176605, Position: up
# Angle: 179.64, Shoulder Y: 0.25, Initial Y: 0.2522884011268616, Position: up
# Angle: 179.70, Shoulder Y: 0.25, Initial Y: 0.2519072890281677, Position: up
# Angle: 179.86, Shoulder Y: 0.25, Initial Y: 0.25126832723617554, Position: up
# Angle: 179.85, Shoulder Y: 0.25, Initial Y: 0.2496872991323471, Position: up
# Angle: 179.77, Shoulder Y: 0.25, Initial Y: 0.24792638421058655, Position: up
# Angle: 179.67, Shoulder Y: 0.25, Initial Y: 0.24707169830799103, Position: up
# Angle: 179.65, Shoulder Y: 0.25, Initial Y: 0.24601849913597107, Position: up
# Angle: 179.65, Shoulder Y: 0.24, Initial Y: 0.24526838958263397, Position: up
# Angle: 179.64, Shoulder Y: 0.24, Initial Y: 0.24478666484355927, Position: up
# Angle: 179.63, Shoulder Y: 0.24, Initial Y: 0.24459604918956757, Position: up
# Angle: 179.61, Shoulder Y: 0.24, Initial Y: 0.24438327550888062, Position: up
# Angle: 179.61, Shoulder Y: 0.24, Initial Y: 0.24432091414928436, Position: up
# Angle: 179.61, Shoulder Y: 0.24, Initial Y: 0.2442551553249359, Position: up
# Angle: 179.60, Shoulder Y: 0.24, Initial Y: 0.2441064715385437, Position: up
# Angle: 179.55, Shoulder Y: 0.24, Initial Y: 0.2440963089466095, Position: up
# Angle: 179.37, Shoulder Y: 0.24, Initial Y: 0.2441260814666748, Position: up
# Angle: 179.00, Shoulder Y: 0.24, Initial Y: 0.24413397908210754, Position: up
# Angle: 178.93, Shoulder Y: 0.24, Initial Y: 0.244406595826149, Position: up
# Angle: 178.86, Shoulder Y: 0.25, Initial Y: 0.24486342072486877, Position: up
# Angle: 178.82, Shoulder Y: 0.25, Initial Y: 0.2459152489900589, Position: up
# Angle: 178.70, Shoulder Y: 0.25, Initial Y: 0.24668192863464355, Position: up
# Angle: 178.56, Shoulder Y: 0.25, Initial Y: 0.2507595419883728, Position: up
# Angle: 178.13, Shoulder Y: 0.26, Initial Y: 0.2538214325904846, Position: up
# Angle: 177.41, Shoulder Y: 0.27, Initial Y: 0.25990864634513855, Position: up
# Angle: 171.58, Shoulder Y: 0.28, Initial Y: 0.2669979929924011, Position: up
# Angle: 166.68, Shoulder Y: 0.30, Initial Y: 0.28411513566970825, Position: up
# Angle: 164.82, Shoulder Y: 0.32, Initial Y: 0.3006913959980011, Position: up
# Angle: 163.90, Shoulder Y: 0.34, Initial Y: 0.3161838948726654, Position: up
# Angle: 163.76, Shoulder Y: 0.34, Initial Y: 0.33580201864242554, Position: up
# Angle: 163.46, Shoulder Y: 0.36, Initial Y: 0.33952629566192627, Position: up
# Angle: 163.01, Shoulder Y: 0.38, Initial Y: 0.35680273175239563, Position: up
# Angle: 162.68, Shoulder Y: 0.40, Initial Y: 0.3751045763492584, Position: up
# Angle: 161.04, Shoulder Y: 0.41, Initial Y: 0.39864376187324524, Position: up
# Angle: 159.28, Shoulder Y: 0.43, Initial Y: 0.41439488530158997, Position: up
# Angle: 157.26, Shoulder Y: 0.45, Initial Y: 0.41439488530158997, Position: up
# Angle: 155.26, Shoulder Y: 0.47, Initial Y: 0.41439488530158997, Position: up
# Angle: 148.23, Shoulder Y: 0.50, Initial Y: 0.41439488530158997, Position: up
# Angle: 100.60, Shoulder Y: 0.56, Initial Y: 0.41439488530158997, Position: up
# Angle: 99.90, Shoulder Y: 0.56, Initial Y: 0.41439488530158997, Position: up
# Angle: 95.21, Shoulder Y: 0.58, Initial Y: 0.41439488530158997, Position: up
# Angle: 94.96, Shoulder Y: 0.59, Initial Y: 0.41439488530158997, Position: up
# Angle: 91.01, Shoulder Y: 0.60, Initial Y: 0.41439488530158997, Position: up
# Angle: 75.97, Shoulder Y: 0.60, Initial Y: 0.41439488530158997, Position: up
# ✅ Squat Counted! Total: 5
# Angle: 74.35, Shoulder Y: 0.59, Initial Y: 0.41439488530158997, Position: down
# Angle: 74.10, Shoulder Y: 0.59, Initial Y: 0.41439488530158997, Position: down
# Angle: 79.18, Shoulder Y: 0.57, Initial Y: 0.41439488530158997, Position: down
# Angle: 96.27, Shoulder Y: 0.56, Initial Y: 0.41439488530158997, Position: down
# Angle: 102.61, Shoulder Y: 0.54, Initial Y: 0.41439488530158997, Position: down
# Angle: 126.72, Shoulder Y: 0.48, Initial Y: 0.41439488530158997, Position: down
# Angle: 137.78, Shoulder Y: 0.46, Initial Y: 0.41439488530158997, Position: down
# Angle: 141.89, Shoulder Y: 0.44, Initial Y: 0.41439488530158997, Position: down
# Angle: 146.87, Shoulder Y: 0.42, Initial Y: 0.41439488530158997, Position: down
# Angle: 148.47, Shoulder Y: 0.40, Initial Y: 0.41439488530158997, Position: down
# Angle: 151.78, Shoulder Y: 0.38, Initial Y: 0.41439488530158997, Position: down
# Angle: 156.72, Shoulder Y: 0.34, Initial Y: 0.41439488530158997, Position: down
# Angle: 159.40, Shoulder Y: 0.32, Initial Y: 0.41439488530158997, Position: down
# Angle: 161.91, Shoulder Y: 0.30, Initial Y: 0.41439488530158997, Position: down
# Angle: 165.13, Shoulder Y: 0.29, Initial Y: 0.3043772280216217, Position: up
# Angle: 168.11, Shoulder Y: 0.27, Initial Y: 0.288083016872406, Position: up
# Angle: 171.04, Shoulder Y: 0.26, Initial Y: 0.2743426561355591, Position: up
# Angle: 171.21, Shoulder Y: 0.26, Initial Y: 0.263388454914093, Position: up
# Angle: 173.75, Shoulder Y: 0.26, Initial Y: 0.26271218061447144, Position: up
# Angle: 177.15, Shoulder Y: 0.25, Initial Y: 0.25611940026283264, Position: up
# Angle: 178.99, Shoulder Y: 0.25, Initial Y: 0.25222650170326233, Position: up
# Angle: 179.89, Shoulder Y: 0.25, Initial Y: 0.25090473890304565, Position: up
# Angle: 179.85, Shoulder Y: 0.25, Initial Y: 0.2520240545272827, Position: up
# Angle: 179.86, Shoulder Y: 0.25, Initial Y: 0.2543160021305084, Position: up
# Angle: 179.44, Shoulder Y: 0.25, Initial Y: 0.25339069962501526, Position: up
# Angle: 179.26, Shoulder Y: 0.25, Initial Y: 0.2542310953140259, Position: up
# Angle: 179.07, Shoulder Y: 0.25, Initial Y: 0.2538925111293793, Position: up
# Angle: 178.93, Shoulder Y: 0.25, Initial Y: 0.2544604241847992, Position: up
# Angle: 178.91, Shoulder Y: 0.25, Initial Y: 0.25459471344947815, Position: up
# Angle: 178.88, Shoulder Y: 0.25, Initial Y: 0.25418099761009216, Position: up
# Angle: 178.83, Shoulder Y: 0.25, Initial Y: 0.2537354826927185, Position: up
# Angle: 178.82, Shoulder Y: 0.25, Initial Y: 0.25354665517807007, Position: up
# Angle: 178.92, Shoulder Y: 0.25, Initial Y: 0.2538157105445862, Position: up
# Angle: 179.12, Shoulder Y: 0.25, Initial Y: 0.2533813714981079, Position: up
# Angle: 179.34, Shoulder Y: 0.25, Initial Y: 0.2531473636627197, Position: up
# Angle: 179.45, Shoulder Y: 0.25, Initial Y: 0.2530890703201294, Position: up
# Angle: 179.49, Shoulder Y: 0.25, Initial Y: 0.2518290877342224, Position: up
# Angle: 179.50, Shoulder Y: 0.25, Initial Y: 0.2509353756904602, Position: up
# Angle: 179.52, Shoulder Y: 0.25, Initial Y: 0.25044378638267517, Position: up
# Angle: 179.51, Shoulder Y: 0.25, Initial Y: 0.2502516508102417, Position: up
# Angle: 179.51, Shoulder Y: 0.25, Initial Y: 0.25029346346855164, Position: up
# Angle: 179.09, Shoulder Y: 0.25, Initial Y: 0.2500416338443756, Position: up
# Angle: 177.56, Shoulder Y: 0.25, Initial Y: 0.2501085698604584, Position: up
# Angle: 174.49, Shoulder Y: 0.25, Initial Y: 0.25070375204086304, Position: up
# Angle: 171.55, Shoulder Y: 0.26, Initial Y: 0.2530757486820221, Position: up
# Angle: 168.72, Shoulder Y: 0.27, Initial Y: 0.25829002261161804, Position: up
# Angle: 166.99, Shoulder Y: 0.28, Initial Y: 0.2662477195262909, Position: up
# Angle: 160.19, Shoulder Y: 0.32, Initial Y: 0.27787715196609497, Position: up
# Angle: 157.71, Shoulder Y: 0.35, Initial Y: 0.32496243715286255, Position: up
# Angle: 155.57, Shoulder Y: 0.38, Initial Y: 0.32496243715286255, Position: up
# Angle: 153.22, Shoulder Y: 0.42, Initial Y: 0.32496243715286255, Position: up
# Angle: 150.03, Shoulder Y: 0.44, Initial Y: 0.32496243715286255, Position: up
# Angle: 145.49, Shoulder Y: 0.46, Initial Y: 0.32496243715286255, Position: up
# Angle: 140.49, Shoulder Y: 0.48, Initial Y: 0.32496243715286255, Position: up
# Angle: 135.11, Shoulder Y: 0.50, Initial Y: 0.32496243715286255, Position: up
# Angle: 129.14, Shoulder Y: 0.52, Initial Y: 0.32496243715286255, Position: up
# Angle: 113.12, Shoulder Y: 0.54, Initial Y: 0.32496243715286255, Position: up
# Angle: 113.46, Shoulder Y: 0.55, Initial Y: 0.32496243715286255, Position: up
# Angle: 95.39, Shoulder Y: 0.59, Initial Y: 0.32496243715286255, Position: up
# Angle: 88.42, Shoulder Y: 0.60, Initial Y: 0.32496243715286255, Position: up
# ✅ Squat Counted! Total: 6
# Angle: 85.06, Shoulder Y: 0.60, Initial Y: 0.32496243715286255, Position: down
# Angle: 89.94, Shoulder Y: 0.59, Initial Y: 0.32496243715286255, Position: down
# Angle: 97.55, Shoulder Y: 0.58, Initial Y: 0.32496243715286255, Position: down
# Angle: 96.53, Shoulder Y: 0.57, Initial Y: 0.32496243715286255, Position: down
# Angle: 100.15, Shoulder Y: 0.56, Initial Y: 0.32496243715286255, Position: down
# Angle: 118.84, Shoulder Y: 0.53, Initial Y: 0.32496243715286255, Position: down
# Angle: 142.45, Shoulder Y: 0.46, Initial Y: 0.32496243715286255, Position: down
# Angle: 147.01, Shoulder Y: 0.44, Initial Y: 0.32496243715286255, Position: down
# Angle: 152.95, Shoulder Y: 0.40, Initial Y: 0.32496243715286255, Position: down
# Angle: 155.91, Shoulder Y: 0.38, Initial Y: 0.32496243715286255, Position: down
# Angle: 158.05, Shoulder Y: 0.36, Initial Y: 0.32496243715286255, Position: down
# Angle: 159.94, Shoulder Y: 0.34, Initial Y: 0.32496243715286255, Position: down
# Angle: 162.37, Shoulder Y: 0.32, Initial Y: 0.32496243715286255, Position: down
# Angle: 165.31, Shoulder Y: 0.30, Initial Y: 0.31604379415512085, Position: up
# Angle: 167.47, Shoulder Y: 0.28, Initial Y: 0.29907873272895813, Position: up
# Angle: 170.16, Shoulder Y: 0.27, Initial Y: 0.2839188575744629, Position: up
# Angle: 173.03, Shoulder Y: 0.26, Initial Y: 0.2722015380859375, Position: up
# Angle: 175.87, Shoulder Y: 0.26, Initial Y: 0.26452508568763733, Position: up
# Angle: 177.83, Shoulder Y: 0.25, Initial Y: 0.25647565722465515, Position: up
# Angle: 177.76, Shoulder Y: 0.25, Initial Y: 0.25117596983909607, Position: up
# Angle: 179.61, Shoulder Y: 0.25, Initial Y: 0.2516418397426605, Position: up
# Angle: 178.78, Shoulder Y: 0.25, Initial Y: 0.24901466071605682, Position: up
# Angle: 177.52, Shoulder Y: 0.25, Initial Y: 0.24816563725471497, Position: up
# Angle: 179.31, Shoulder Y: 0.25, Initial Y: 0.2497618943452835, Position: up
# Angle: 178.83, Shoulder Y: 0.25, Initial Y: 0.24852623045444489, Position: up
# Angle: 177.43, Shoulder Y: 0.24, Initial Y: 0.24500417709350586, Position: up
# Angle: 175.95, Shoulder Y: 0.25, Initial Y: 0.24467292428016663, Position: up
# Angle: 175.25, Shoulder Y: 0.24, Initial Y: 0.24528463184833527, Position: up
# Angle: 173.00, Shoulder Y: 0.24, Initial Y: 0.24445049464702606, Position: up
# Angle: 172.29, Shoulder Y: 0.24, Initial Y: 0.2437567263841629, Position: up
# Angle: 172.65, Shoulder Y: 0.24, Initial Y: 0.24291373789310455, Position: up
# Angle: 175.32, Shoulder Y: 0.24, Initial Y: 0.2422313094139099, Position: up
# Angle: 177.90, Shoulder Y: 0.24, Initial Y: 0.24055443704128265, Position: up
# Angle: 178.52, Shoulder Y: 0.24, Initial Y: 0.24009115993976593, Position: up
# Angle: 174.84, Shoulder Y: 0.24, Initial Y: 0.24017618596553802, Position: up
# Angle: 167.93, Shoulder Y: 0.24, Initial Y: 0.24053683876991272, Position: up
# Angle: 156.04, Shoulder Y: 0.24, Initial Y: 0.24051260948181152, Position: up
# Angle: 139.94, Shoulder Y: 0.24, Initial Y: 0.24051260948181152, Position: up
# Angle: 121.89, Shoulder Y: 0.24, Initial Y: 0.24051260948181152, Position: up
# Angle: 15.70, Shoulder Y: 0.24, Initial Y: 0.24051260948181152, Position: up
# Angle: 16.00, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 80.36, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 105.19, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 129.18, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 145.99, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 158.30, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 169.15, Shoulder Y: 0.23, Initial Y: 0.24051260948181152, Position: up
# Angle: 176.02, Shoulder Y: 0.23, Initial Y: 0.23030896484851837, Position: up
# Angle: 176.52, Shoulder Y: 0.23, Initial Y: 0.23013180494308472, Position: up
# Angle: 172.43, Shoulder Y: 0.23, Initial Y: 0.23023229837417603, Position: up
# Angle: 163.68, Shoulder Y: 0.23, Initial Y: 0.23029977083206177, Position: up
# Angle: 95.22, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 42.61, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 18.68, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 15.73, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 43.49, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 61.57, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 110.95, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 136.22, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 151.82, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 163.70, Shoulder Y: 0.23, Initial Y: 0.23038004338741302, Position: up
# Angle: 173.32, Shoulder Y: 0.23, Initial Y: 0.2311086505651474, Position: up
# Angle: 179.47, Shoulder Y: 0.23, Initial Y: 0.2311200350522995, Position: up
# Angle: 171.92, Shoulder Y: 0.23, Initial Y: 0.23146213591098785, Position: up
# Angle: 151.96, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 129.86, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 104.03, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 44.06, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 17.26, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 8.37, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 10.05, Shoulder Y: 0.23, Initial Y: 0.23184329271316528, Position: up
# Angle: 19.16, Shoulder Y: 0.24, Initial Y: 0.23184329271316528, Position: up
# Angle: 24.94, Shoulder Y: 0.24, Initial Y: 0.23184329271316528, Position: up
# Angle: 83.87, Shoulder Y: 0.24, Initial Y: 0.23184329271316528, Position: up
# Angle: 164.74, Shoulder Y: 0.24, Initial Y: 0.23184329271316528, Position: up
# Angle: 170.83, Shoulder Y: 0.24, Initial Y: 0.23686251044273376, Position: up
# Angle: 174.85, Shoulder Y: 0.24, Initial Y: 0.23914074897766113, Position: up
# Angle: 176.55, Shoulder Y: 0.24, Initial Y: 0.24167890846729279, Position: up
# Angle: 177.37, Shoulder Y: 0.25, Initial Y: 0.24464604258537292, Position: up
# Angle: 176.87, Shoulder Y: 0.25, Initial Y: 0.24947698414325714, Position: up
# Angle: 176.84, Shoulder Y: 0.26, Initial Y: 0.25230079889297485, Position: up
# Angle: 176.28, Shoulder Y: 0.26, Initial Y: 0.2550466060638428, Position: up
# Angle: 176.89, Shoulder Y: 0.26, Initial Y: 0.2587064802646637, Position: up
# Angle: 177.69, Shoulder Y: 0.26, Initial Y: 0.26076656579971313, Position: up
# Angle: 177.95, Shoulder Y: 0.26, Initial Y: 0.2625594437122345, Position: up
# Angle: 177.47, Shoulder Y: 0.26, Initial Y: 0.2626192569732666, Position: up
# Angle: 177.34, Shoulder Y: 0.26, Initial Y: 0.26252883672714233, Position: up
# Angle: 178.21, Shoulder Y: 0.26, Initial Y: 0.2632451355457306, Position: up
# Angle: 177.88, Shoulder Y: 0.26, Initial Y: 0.26353636384010315, Position: up
# Angle: 177.85, Shoulder Y: 0.27, Initial Y: 0.2644836902618408, Position: up
# Angle: 178.79, Shoulder Y: 0.27, Initial Y: 0.2655790448188782, Position: up
# Angle: 179.97, Shoulder Y: 0.27, Initial Y: 0.26627984642982483, Position: up
# Angle: 179.60, Shoulder Y: 0.27, Initial Y: 0.2666133642196655, Position: up
# Angle: 179.20, Shoulder Y: 0.27, Initial Y: 0.26645949482917786, Position: up
# Angle: 178.16, Shoulder Y: 0.26, Initial Y: 0.2660694420337677, Position: up
# Angle: 176.79, Shoulder Y: 0.26, Initial Y: 0.2648986876010895, Position: up
# Angle: 175.69, Shoulder Y: 0.26, Initial Y: 0.26362544298171997, Position: up
# Angle: 175.56, Shoulder Y: 0.26, Initial Y: 0.2622836232185364, Position: up
# Angle: 175.32, Shoulder Y: 0.26, Initial Y: 0.26029807329177856, Position: up
# Angle: 174.74, Shoulder Y: 0.26, Initial Y: 0.25915178656578064, Position: up
# Angle: 174.28, Shoulder Y: 0.26, Initial Y: 0.25835052132606506, Position: up
# Angle: 173.88, Shoulder Y: 0.26, Initial Y: 0.25778424739837646, Position: up
# Angle: 173.95, Shoulder Y: 0.26, Initial Y: 0.2576387822628021, Position: up
# Angle: 174.08, Shoulder Y: 0.26, Initial Y: 0.25738614797592163, Position: up
# Angle: 174.46, Shoulder Y: 0.25, Initial Y: 0.2555052936077118, Position: up
# Angle: 174.56, Shoulder Y: 0.25, Initial Y: 0.2541373670101166, Position: up
# Angle: 174.59, Shoulder Y: 0.25, Initial Y: 0.25364822149276733, Position: up
# Angle: 174.60, Shoulder Y: 0.25, Initial Y: 0.2536962628364563, Position: up
# Angle: 174.57, Shoulder Y: 0.25, Initial Y: 0.25386378169059753, Position: up
# Angle: 174.42, Shoulder Y: 0.26, Initial Y: 0.25418516993522644, Position: up
# Angle: 174.32, Shoulder Y: 0.26, Initial Y: 0.25587350130081177, Position: up
# Angle: 174.62, Shoulder Y: 0.26, Initial Y: 0.258944571018219, Position: up
# Angle: 174.31, Shoulder Y: 0.26, Initial Y: 0.2603321671485901, Position: up
# Angle: 174.24, Shoulder Y: 0.26, Initial Y: 0.2610493302345276, Position: up
# Angle: 174.38, Shoulder Y: 0.26, Initial Y: 0.2616828382015228, Position: up
# Angle: 174.56, Shoulder Y: 0.26, Initial Y: 0.26300594210624695, Position: up
# Angle: 175.16, Shoulder Y: 0.26, Initial Y: 0.2634918987751007, Position: up
# Angle: 175.10, Shoulder Y: 0.26, Initial Y: 0.2643797695636749, Position: up
# Angle: 176.06, Shoulder Y: 0.26, Initial Y: 0.26479372382164, Position: up
# Angle: 176.73, Shoulder Y: 0.27, Initial Y: 0.26493188738822937, Position: up
# Angle: 176.78, Shoulder Y: 0.27, Initial Y: 0.2654706537723541, Position: up
# Angle: 175.95, Shoulder Y: 0.27, Initial Y: 0.26567769050598145, Position: up
# Angle: 175.42, Shoulder Y: 0.27, Initial Y: 0.26789775490760803, Position: up
# Angle: 174.71, Shoulder Y: 0.27, Initial Y: 0.2699466943740845, Position: up
# Angle: 173.70, Shoulder Y: 0.27, Initial Y: 0.27093082666397095, Position: up
# Angle: 173.67, Shoulder Y: 0.27, Initial Y: 0.27229925990104675, Position: up
# Angle: 173.65, Shoulder Y: 0.27, Initial Y: 0.27279332280158997, Position: up
# ...
# Angle: 128.25, Shoulder Y: 0.44, Initial Y: 0.22153736650943756, Position: down
# Angle: 134.99, Shoulder Y: 0.42, Initial Y: 0.22153736650943756, Position: down
# Angle: 139.82, Shoulder Y: 0.38, Initial Y: 0.22153736650943756, Position: down
# Angle: 141.66, Shoulder Y: 0.35, Initial Y: 0.22153736650943756, Position: down
# Angle: 141.47, Shoulder Y: 0.35, Initial Y: 0.22153736650943756, Position: down
# Angle: 145.33, Shoulder Y: 0.31, Initial Y: 0.22153736650943756, Position: down
# Angle: 151.20, Shoulder Y: 0.28, Initial Y: 0.22153736650943756, Position: down
# Angle: 156.35, Shoulder Y: 0.26, Initial Y: 0.22153736650943756, Position: down
# Angle: 174.65, Shoulder Y: 0.19, Initial Y: 0.22153736650943756, Position: down
# Angle: 177.83, Shoulder Y: 0.20, Initial Y: 0.19325047731399536, Position: up
# Angle: 178.56, Shoulder Y: 0.20, Initial Y: 0.19527260959148407, Position: up
# Angle: 179.45, Shoulder Y: 0.20, Initial Y: 0.19678233563899994, Position: up
# Angle: 179.41, Shoulder Y: 0.20, Initial Y: 0.19921547174453735, Position: up
# Angle: 179.45, Shoulder Y: 0.20, Initial Y: 0.20008303225040436, Position: up
# Angle: 178.54, Shoulder Y: 0.20, Initial Y: 0.20217646658420563, Position: up
# Angle: 178.88, Shoulder Y: 0.20, Initial Y: 0.2004009336233139, Position: up
# Angle: 178.68, Shoulder Y: 0.20, Initial Y: 0.20151619613170624, Position: up
# Angle: 178.26, Shoulder Y: 0.20, Initial Y: 0.20263388752937317, Position: up
# Angle: 178.32, Shoulder Y: 0.20, Initial Y: 0.20330139994621277, Position: up
# Angle: 179.29, Shoulder Y: 0.20, Initial Y: 0.203693687915802, Position: up
# Angle: 179.58, Shoulder Y: 0.20, Initial Y: 0.20394229888916016, Position: up
# Angle: 179.19, Shoulder Y: 0.20, Initial Y: 0.2030971199274063, Position: up
# Angle: 179.43, Shoulder Y: 0.20, Initial Y: 0.2034725397825241, Position: up
# Angle: 179.83, Shoulder Y: 0.20, Initial Y: 0.2039518803358078, Position: up
# Angle: 179.97, Shoulder Y: 0.21, Initial Y: 0.20477056503295898, Position: up
# Angle: 179.91, Shoulder Y: 0.21, Initial Y: 0.2057727873325348, Position: up
# Angle: 179.86, Shoulder Y: 0.21, Initial Y: 0.20605286955833435, Position: up
# Angle: 179.81, Shoulder Y: 0.21, Initial Y: 0.2059626430273056, Position: up
# Angle: 179.73, Shoulder Y: 0.21, Initial Y: 0.20589770376682281, Position: up
# Angle: 179.64, Shoulder Y: 0.21, Initial Y: 0.2061271220445633, Position: up
# Angle: 179.56, Shoulder Y: 0.21, Initial Y: 0.206142857670784, Position: up
# Angle: 179.49, Shoulder Y: 0.21, Initial Y: 0.20622730255126953, Position: up
# Angle: 179.41, Shoulder Y: 0.21, Initial Y: 0.20628127455711365, Position: up
# Angle: 179.34, Shoulder Y: 0.21, Initial Y: 0.20603801310062408, Position: up
# Angle: 179.39, Shoulder Y: 0.21, Initial Y: 0.2056213766336441, Position: up
# Angle: 179.40, Shoulder Y: 0.21, Initial Y: 0.2053893506526947, Position: up
# Angle: 179.38, Shoulder Y: 0.21, Initial Y: 0.20524254441261292, Position: up
# Angle: 179.34, Shoulder Y: 0.21, Initial Y: 0.20514820516109467, Position: up
# Angle: 179.28, Shoulder Y: 0.20, Initial Y: 0.2051180899143219, Position: up
# Angle: 179.15, Shoulder Y: 0.20, Initial Y: 0.20426177978515625, Position: up
# Angle: 178.83, Shoulder Y: 0.20, Initial Y: 0.20284637808799744, Position: up
# Angle: 178.75, Shoulder Y: 0.20, Initial Y: 0.20143809914588928, Position: up
# Angle: 178.70, Shoulder Y: 0.20, Initial Y: 0.20097719132900238, Position: up
# Angle: 178.66, Shoulder Y: 0.20, Initial Y: 0.20100878179073334, Position: up
# Angle: 178.72, Shoulder Y: 0.20, Initial Y: 0.2005738765001297, Position: up
# Angle: 178.77, Shoulder Y: 0.20, Initial Y: 0.20017269253730774, Position: up
# Angle: 178.69, Shoulder Y: 0.20, Initial Y: 0.20036865770816803, Position: up
# Angle: 178.54, Shoulder Y: 0.20, Initial Y: 0.20044901967048645, Position: up
# Angle: 178.22, Shoulder Y: 0.20, Initial Y: 0.20070579648017883, Position: up
# Angle: 178.04, Shoulder Y: 0.20, Initial Y: 0.2006891816854477, Position: up
# Angle: 177.88, Shoulder Y: 0.20, Initial Y: 0.20070526003837585, Position: up
# Angle: 177.66, Shoulder Y: 0.20, Initial Y: 0.20049484074115753, Position: up
# Angle: 177.57, Shoulder Y: 0.20, Initial Y: 0.19935864210128784, Position: up
# Angle: 177.49, Shoulder Y: 0.20, Initial Y: 0.19701403379440308, Position: up
# Angle: 177.88, Shoulder Y: 0.20, Initial Y: 0.19670651853084564, Position: up
# Angle: 178.00, Shoulder Y: 0.20, Initial Y: 0.19610530138015747, Position: up
# Angle: 178.04, Shoulder Y: 0.20, Initial Y: 0.19533881545066833, Position: up
# Angle: 178.07, Shoulder Y: 0.20, Initial Y: 0.19534769654273987, Position: up
# Angle: 178.15, Shoulder Y: 0.20, Initial Y: 0.1953573077917099, Position: up
# Angle: 178.20, Shoulder Y: 0.20, Initial Y: 0.19529303908348083, Position: up
# Angle: 178.44, Shoulder Y: 0.20, Initial Y: 0.19536598026752472, Position: up
# Angle: 178.73, Shoulder Y: 0.20, Initial Y: 0.19539619982242584, Position: up
# Angle: 179.01, Shoulder Y: 0.20, Initial Y: 0.1954660266637802, Position: up
# Angle: 179.41, Shoulder Y: 0.20, Initial Y: 0.19559018313884735, Position: up
# Angle: 179.38, Shoulder Y: 0.20, Initial Y: 0.19564804434776306, Position: up
# Angle: 179.21, Shoulder Y: 0.20, Initial Y: 0.195970356464386, Position: up
# Angle: 178.91, Shoulder Y: 0.20, Initial Y: 0.1960272192955017, Position: up
# Angle: 178.60, Shoulder Y: 0.20, Initial Y: 0.19633235037326813, Position: up
# Angle: 178.51, Shoulder Y: 0.20, Initial Y: 0.19731074571609497, Position: up
# Angle: 178.44, Shoulder Y: 0.20, Initial Y: 0.19852524995803833, Position: up
# Angle: 178.37, Shoulder Y: 0.20, Initial Y: 0.1991768479347229, Position: up
# Angle: 178.19, Shoulder Y: 0.20, Initial Y: 0.19963930547237396, Position: up
# Angle: 177.90, Shoulder Y: 0.20, Initial Y: 0.1998472809791565, Position: up
# Angle: 178.18, Shoulder Y: 0.20, Initial Y: 0.19983287155628204, Position: up
# Angle: 178.45, Shoulder Y: 0.20, Initial Y: 0.19983839988708496, Position: up
# Angle: 177.91, Shoulder Y: 0.20, Initial Y: 0.19978417456150055, Position: up
# Angle: 176.72, Shoulder Y: 0.20, Initial Y: 0.19978255033493042, Position: up
# Angle: 176.91, Shoulder Y: 0.20, Initial Y: 0.1999364197254181, Position: up
# Angle: 176.47, Shoulder Y: 0.21, Initial Y: 0.20214097201824188, Position: up
# Angle: 176.01, Shoulder Y: 0.21, Initial Y: 0.20611785352230072, Position: up
# Angle: 175.98, Shoulder Y: 0.21, Initial Y: 0.21042969822883606, Position: up
# Angle: 176.44, Shoulder Y: 0.21, Initial Y: 0.21349318325519562, Position: up
# Angle: 177.34, Shoulder Y: 0.21, Initial Y: 0.21443729102611542, Position: up
# Angle: 177.28, Shoulder Y: 0.21, Initial Y: 0.21462371945381165, Position: up
# Angle: 176.66, Shoulder Y: 0.22, Initial Y: 0.2143997699022293, Position: up
# Angle: 176.29, Shoulder Y: 0.22, Initial Y: 0.21849267184734344, Position: up
# Angle: 174.69, Shoulder Y: 0.22, Initial Y: 0.21981146931648254, Position: up
# Angle: 174.25, Shoulder Y: 0.22, Initial Y: 0.21953554451465607, Position: up
# Angle: 175.18, Shoulder Y: 0.22, Initial Y: 0.21926018595695496, Position: up
# Angle: 174.92, Shoulder Y: 0.22, Initial Y: 0.21922394633293152, Position: up
# Angle: 174.65, Shoulder Y: 0.22, Initial Y: 0.21914201974868774, Position: up
# Angle: 174.80, Shoulder Y: 0.22, Initial Y: 0.2193121612071991, Position: up
# Angle: 174.73, Shoulder Y: 0.22, Initial Y: 0.2192106992006302, Position: up
# Angle: 174.64, Shoulder Y: 0.22, Initial Y: 0.2191353291273117, Position: up
# Angle: 174.71, Shoulder Y: 0.22, Initial Y: 0.2191080003976822, Position: up
# Angle: 174.50, Shoulder Y: 0.22, Initial Y: 0.2186536341905594, Position: up
# Angle: 174.08, Shoulder Y: 0.22, Initial Y: 0.21819910407066345, Position: up
# Angle: 175.10, Shoulder Y: 0.22, Initial Y: 0.21805478632450104, Position: up
# Angle: 175.56, Shoulder Y: 0.22, Initial Y: 0.22015118598937988, Position: up
# Angle: 176.79, Shoulder Y: 0.22, Initial Y: 0.22369562089443207, Position: up
# Angle: 178.31, Shoulder Y: 0.21, Initial Y: 0.21682044863700867, Position: up
# Angle: 178.51, Shoulder Y: 0.21, Initial Y: 0.21207167208194733, Position: up
# Angle: 178.12, Shoulder Y: 0.20, Initial Y: 0.20632921159267426, Position: up
# Angle: 177.63, Shoulder Y: 0.20, Initial Y: 0.20067089796066284, Position: up
# Angle: 175.52, Shoulder Y: 0.20, Initial Y: 0.1985716074705124, Position: up
# Angle: 173.74, Shoulder Y: 0.19, Initial Y: 0.1955879181623459, Position: up
# Angle: 171.76, Shoulder Y: 0.19, Initial Y: 0.19287104904651642, Position: up
# Angle: 170.35, Shoulder Y: 0.19, Initial Y: 0.18850873410701752, Position: up
# Angle: 169.71, Shoulder Y: 0.19, Initial Y: 0.1864902228116989, Position: up
# Angle: 168.87, Shoulder Y: 0.19, Initial Y: 0.18631935119628906, Position: up
# Angle: 168.66, Shoulder Y: 0.18, Initial Y: 0.18520870804786682, Position: up
# Angle: 169.44, Shoulder Y: 0.18, Initial Y: 0.18354178965091705, Position: up
# Angle: 172.56, Shoulder Y: 0.18, Initial Y: 0.18376632034778595, Position: up
# Angle: 174.04, Shoulder Y: 0.18, Initial Y: 0.1841042935848236, Position: up
# Angle: 174.73, Shoulder Y: 0.18, Initial Y: 0.1845695525407791, Position: up
# Angle: 175.36, Shoulder Y: 0.18, Initial Y: 0.18495242297649384, Position: up
# Angle: 175.59, Shoulder Y: 0.18, Initial Y: 0.18453826010227203, Position: up
# Angle: 176.14, Shoulder Y: 0.18, Initial Y: 0.18429726362228394, Position: up
# Angle: 176.29, Shoulder Y: 0.18, Initial Y: 0.18024852871894836, Position: up
# Angle: 175.86, Shoulder Y: 0.17, Initial Y: 0.17567038536071777, Position: up
# Angle: 176.67, Shoulder Y: 0.17, Initial Y: 0.17382508516311646, Position: up
# Angle: 178.32, Shoulder Y: 0.17, Initial Y: 0.17159566283226013, Position: up
# Angle: 177.85, Shoulder Y: 0.17, Initial Y: 0.17066283524036407, Position: up
# Angle: 177.28, Shoulder Y: 0.17, Initial Y: 0.17079013586044312, Position: up
# Angle: 177.60, Shoulder Y: 0.17, Initial Y: 0.17115668952465057, Position: up
# Angle: 177.77, Shoulder Y: 0.17, Initial Y: 0.17224834859371185, Position: up
# Angle: 177.99, Shoulder Y: 0.18, Initial Y: 0.17483176290988922, Position: up
# Angle: 177.32, Shoulder Y: 0.18, Initial Y: 0.17670100927352905, Position: up
# Angle: 176.75, Shoulder Y: 0.18, Initial Y: 0.17797352373600006, Position: up
# Angle: 174.01, Shoulder Y: 0.18, Initial Y: 0.17869165539741516, Position: up
# Angle: 173.90, Shoulder Y: 0.18, Initial Y: 0.17989923059940338, Position: up
# Angle: 174.76, Shoulder Y: 0.18, Initial Y: 0.1807209998369217, Position: up
# Angle: 174.64, Shoulder Y: 0.18, Initial Y: 0.1808331310749054, Position: up
# Angle: 173.36, Shoulder Y: 0.18, Initial Y: 0.18079811334609985, Position: up
# Angle: 172.83, Shoulder Y: 0.18, Initial Y: 0.18061408400535583, Position: up
# Angle: 172.08, Shoulder Y: 0.18, Initial Y: 0.18070581555366516, Position: up
# Angle: 171.92, Shoulder Y: 0.18, Initial Y: 0.1807277798652649, Position: up
# Angle: 172.03, Shoulder Y: 0.18, Initial Y: 0.18026967346668243, Position: up
# Angle: 172.57, Shoulder Y: 0.18, Initial Y: 0.1792580634355545, Position: up
# Angle: 173.15, Shoulder Y: 0.18, Initial Y: 0.17890363931655884, Position: up
# Angle: 173.23, Shoulder Y: 0.17, Initial Y: 0.17688874900341034, Position: up
# Angle: 173.25, Shoulder Y: 0.17, Initial Y: 0.17424635589122772, Position: up
# Angle: 173.38, Shoulder Y: 0.17, Initial Y: 0.1724345088005066, Position: up
# Angle: 173.23, Shoulder Y: 0.17, Initial Y: 0.17000751197338104, Position: up
# Angle: 174.03, Shoulder Y: 0.17, Initial Y: 0.16951178014278412, Position: up
# Angle: 174.65, Shoulder Y: 0.17, Initial Y: 0.16758640110492706, Position: up
# Angle: 174.17, Shoulder Y: 0.17, Initial Y: 0.16729238629341125, Position: up
# Angle: 174.57, Shoulder Y: 0.17, Initial Y: 0.16682188212871552, Position: up
# Angle: 177.47, Shoulder Y: 0.16, Initial Y: 0.1667497307062149, Position: up
# Angle: 178.73, Shoulder Y: 0.16, Initial Y: 0.15833011269569397, Position: up
# Angle: 178.41, Shoulder Y: 0.16, Initial Y: 0.15673942863941193, Position: up
# Angle: 177.83, Shoulder Y: 0.16, Initial Y: 0.15720993280410767, Position: up
# Angle: 177.97, Shoulder Y: 0.16, Initial Y: 0.15723325312137604, Position: up
# Angle: 178.69, Shoulder Y: 0.16, Initial Y: 0.1565493643283844, Position: up
# Angle: 178.95, Shoulder Y: 0.15, Initial Y: 0.15519163012504578, Position: up
# Angle: 179.21, Shoulder Y: 0.15, Initial Y: 0.15478597581386566, Position: up
# Angle: 178.94, Shoulder Y: 0.15, Initial Y: 0.15397848188877106, Position: up
# Angle: 178.71, Shoulder Y: 0.15, Initial Y: 0.15057237446308136, Position: up
# Angle: 178.41, Shoulder Y: 0.15, Initial Y: 0.1495816558599472, Position: up
# Angle: 178.16, Shoulder Y: 0.15, Initial Y: 0.14778754115104675, Position: up
# Angle: 178.18, Shoulder Y: 0.15, Initial Y: 0.14682625234127045, Position: up
# Angle: 178.00, Shoulder Y: 0.14, Initial Y: 0.14542318880558014, Position: up
# Angle: 177.70, Shoulder Y: 0.14, Initial Y: 0.14447881281375885, Position: up
# Angle: 177.26, Shoulder Y: 0.14, Initial Y: 0.14355014264583588, Position: up
# Angle: 177.08, Shoulder Y: 0.14, Initial Y: 0.1396304816007614, Position: up
# Angle: 176.78, Shoulder Y: 0.14, Initial Y: 0.13664433360099792, Position: up
# Angle: 176.58, Shoulder Y: 0.14, Initial Y: 0.13700821995735168, Position: up
# Angle: 176.31, Shoulder Y: 0.14, Initial Y: 0.13746502995491028, Position: up
# Angle: 176.15, Shoulder Y: 0.14, Initial Y: 0.13779203593730927, Position: up
# Angle: 176.04, Shoulder Y: 0.14, Initial Y: 0.13713456690311432, Position: up
# Angle: 176.01, Shoulder Y: 0.14, Initial Y: 0.13666240870952606, Position: up
# Angle: 175.45, Shoulder Y: 0.14, Initial Y: 0.13681776821613312, Position: up
# Angle: 175.04, Shoulder Y: 0.14, Initial Y: 0.13748236000537872, Position: up
# Angle: 174.74, Shoulder Y: 0.14, Initial Y: 0.13769355416297913, Position: up
# Angle: 174.57, Shoulder Y: 0.14, Initial Y: 0.13836675882339478, Position: up
# Angle: 175.52, Shoulder Y: 0.14, Initial Y: 0.13845306634902954, Position: up
# Angle: 176.25, Shoulder Y: 0.14, Initial Y: 0.13965106010437012, Position: up
# Angle: 178.36, Shoulder Y: 0.14, Initial Y: 0.13968484103679657, Position: up
# Angle: 179.86, Shoulder Y: 0.14, Initial Y: 0.14023734629154205, Position: up
# Angle: 179.89, Shoulder Y: 0.14, Initial Y: 0.14161285758018494, Position: up
# Angle: 179.96, Shoulder Y: 0.15, Initial Y: 0.14407990872859955, Position: up
# Angle: 179.73, Shoulder Y: 0.15, Initial Y: 0.1483207494020462, Position: up
# Angle: 178.11, Shoulder Y: 0.15, Initial Y: 0.14960967004299164, Position: up
# Angle: 178.76, Shoulder Y: 0.15, Initial Y: 0.1505415439605713, Position: up
# Angle: 176.98, Shoulder Y: 0.15, Initial Y: 0.15179443359375, Position: up
# Angle: 175.03, Shoulder Y: 0.15, Initial Y: 0.15170864760875702, Position: up
# Angle: 172.78, Shoulder Y: 0.15, Initial Y: 0.1503903567790985, Position: up
# Angle: 171.07, Shoulder Y: 0.15, Initial Y: 0.15032024681568146, Position: up
# Angle: 171.58, Shoulder Y: 0.15, Initial Y: 0.15029673278331757, Position: up
# Angle: 171.79, Shoulder Y: 0.15, Initial Y: 0.15025731921195984, Position: up
# Angle: 170.48, Shoulder Y: 0.15, Initial Y: 0.15154145658016205, Position: up
# Angle: 171.66, Shoulder Y: 0.15, Initial Y: 0.15164890885353088, Position: up
# Angle: 172.51, Shoulder Y: 0.15, Initial Y: 0.15162168443202972, Position: up
# Angle: 168.52, Shoulder Y: 0.15, Initial Y: 0.15158148109912872, Position: up
# Angle: 167.49, Shoulder Y: 0.15, Initial Y: 0.15110506117343903, Position: up
# Angle: 171.28, Shoulder Y: 0.15, Initial Y: 0.15174944698810577, Position: up
# Angle: 172.70, Shoulder Y: 0.16, Initial Y: 0.1534058004617691, Position: up
# Angle: 174.96, Shoulder Y: 0.16, Initial Y: 0.15623293817043304, Position: up
# Angle: 174.61, Shoulder Y: 0.16, Initial Y: 0.16017742455005646, Position: up
# Angle: 174.92, Shoulder Y: 0.16, Initial Y: 0.16273754835128784, Position: up
# Angle: 174.36, Shoulder Y: 0.16, Initial Y: 0.1634821742773056, Position: up
# Angle: 174.39, Shoulder Y: 0.16, Initial Y: 0.16312739253044128, Position: up
# Angle: 174.51, Shoulder Y: 0.16, Initial Y: 0.1629723608493805, Position: up
# Angle: 174.05, Shoulder Y: 0.16, Initial Y: 0.16277284920215607, Position: up
# Angle: 173.95, Shoulder Y: 0.16, Initial Y: 0.16213801503181458, Position: up

# %% [markdown]
# import cv2
# import mediapipe as mp
# import numpy as np
#
# # Initialize MediaPipe Pose
# mp_drawing = mp.solutions.drawing_utils
# mp_pose = mp.solutions.pose
# pose = mp_pose.Pose()
#
# # Initialize video capture
# cap = cv2.VideoCapture(0)
#
# # Function to calculate the angle between three points
# def calculate_angle(a, b, c):
#     a = np.array(a)  # Hip
#     b = np.array(b)  # Knee
#     c = np.array(c)  # Ankle
#
#     # Vector calculations
#     ba = a - b
#     bc = c - b
#
#     # Calculate angle
#     cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
#     angle = np.arccos(cosine_angle)
#     return np.degrees(angle)
#
# # Squat detection function
# def squat():
#     count = 0
#     position = "up"
#     shoulder_initial_y = None  # Stores the reference height of the shoulder
#
#     while cap.isOpened():
#         ret, frame = cap.read()
#         if not ret:
#             break
#
#         frame = cv2.flip(frame, 1)
#         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#         results = pose.process(image)
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
#         try:
#             if results.pose_landmarks:
#                 landmarks = results.pose_landmarks.landmark
#
#                 # Get keypoints
#                 hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,
#                        landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
#                 knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,
#                         landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]
#                 ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,
#                          landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]
#                 shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,
#                             landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
#
#                 angle = calculate_angle(hip, knee, ankle)
#
#                 # Initialize shoulder reference height when standing straight
#                 if position == "up" and shoulder_initial_y is None:
#                     shoulder_initial_y = shoulder[1]
#
#                 # DEBUG: Print values
#                 print(f"Angle: {angle:.2f}, Shoulder Y: {shoulder[1]:.2f}, Initial Y: {shoulder_initial_y}, Position: {position}")
#
#                 # Check squat position logic
#                 if angle > 160:  # Standing position
#                     position = "up"
#                     shoulder_initial_y = shoulder[1]  # Reset shoulder reference when standing
#
#                 if angle < 90 and position == "up" and shoulder[1] > shoulder_initial_y + 0.02:
#                     # Ensure the shoulder moves down before counting the squat
#                     position = "down"
#                     count += 1
#                     print(f"✅ Squat Counted! Total: {count}")  # Debugging line
#
#                 # Provide feedback
#                 if angle > 160:
#                     feedback = "Stand tall!"
#                 elif angle < 90:
#                     feedback = "Squat low!"
#                 else:
#                     feedback = "Good depth!"
#
#                 # Display feedback
#                 cv2.putText(image, f"Squat Reps: {count}", (30, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)
#                 cv2.putText(image, feedback, (30, 80), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
#
#         except Exception as e:
#             print(f"Error: {e}")
#
#         # Draw landmarks
#         if results.pose_landmarks:
#             mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)
#
#         cv2.imshow("Squat", image)
#         if cv2.waitKey(10) & 0xFF == ord('q'):
#             break
#
#     cap.release()
#     cv2.destroyAllWindows()
#
# # Run the squat function
# squat()
